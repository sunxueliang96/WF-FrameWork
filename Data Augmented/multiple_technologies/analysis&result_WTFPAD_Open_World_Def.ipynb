# %% [markdown]
# <a href="https://colab.research.google.com/github/sunxueliang96/WF-FrameWork/blob/master/Data%20Augmented/multiple_technologies/analysis%26result_WTFPAD_Open_World_Def.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/'My Drive'/deep_firger/dataset/OpenWorld/WTFPAD
# Out:
# /content/drive/My Drive/deep_firger/dataset/OpenWorld/WTFPAD

# %%
datatype_Close = False   #Flase is Open_World, True is Closed World.

# %%
#cd /content/drive/'My Drive'/datasets/no_paded/close_world/walkiebatch

# %%
#datatype_Close = True   #Flase is Open_World, True is Closed World.

# %%
ls
# Out:
# X_test_Mon_WTFPAD.pkl    X_valid_WTFPAD.pkl       y_train_WTFPAD.pkl
# X_test_Unmon_WTFPAD.pkl  y_test_Mon_WTFPAD.pkl    y_valid_WTFPAD.pkl
# X_train_WTFPAD.pkl       y_test_Unmon_WTFPAD.pkl

# %%
import numpy as np
import pickle

print('loading data...')
with open('X_train_WTFPAD.pkl','rb') as handle:
    X_1 = np.array(pickle.load(handle,encoding='iso-8859-1'))
with open('y_train_WTFPAD.pkl','rb') as handle:
    y_1 = np.array(pickle.load(handle,encoding='iso-8859-1'))
    '''
with open('y_train_WTFPAD.pkl','rb') as handle:
    y_1 = np.array(pickle.load(handle,encoding='iso-8859-1'))
with open('y_valid_WTFPAD.pkl','rb') as handle:
    y_2 = np.array(pickle.load(handle,encoding='iso-8859-1'))

print('the shape of X_1',X_1.shape)
print('the shape of X_2',X_2.shape)
print('the shape of y_1',y_1.shape)
print('the shape of y_2',y_2.shape)
'''
# Out:
# loading data...

# %%
X = []
y = []
X.extend(X_1)
y.extend(y_1)

# %%
#deal x and y
k=0
for seq,i in zip(X,range(len(X))):
    X[i] = list(filter(lambda x:x!=0, seq))
    if(i in list(range(0,len(X),len(X)//10))):
        print("{}0% data has been dealed".format(k),flush = True)
        k +=1
y = [-1 if x==95 else x for x in y]

print ('shape of X',np.shape(X))
print ('shape of y',np.shape(y))
# Out:
# 00% data has been dealed
# 10% data has been dealed
# 20% data has been dealed
# 30% data has been dealed
# 40% data has been dealed
# 50% data has been dealed
# 60% data has been dealed
# 70% data has been dealed
# 80% data has been dealed
# 90% data has been dealed
# shape of X (96000,)
# shape of y (96000,)

# %%
import math 
import random
def fun_noise(X,y,PERCENT_NOISE,TIMES_NOISE): 
    X = list(X)
    y = list(y)
    X_sum = []
    y_sum = []
    #X_sum = X.copy()
    #y_sum = y.copy()
    #print("{} samples has beed add to X_train, {}% of noise for each sample".format(math.ceil(len(X)*TIMES_NOISE),PERCENT_NOISE))
    k=0
    for i in range(math.ceil(len(X)*TIMES_NOISE)): #ADDING NOISE from here 
        if(i in list(range(0,math.ceil(len(X)*TIMES_NOISE),math.ceil(len(X)*TIMES_NOISE)//10))):
            print("{}0% data has been dealed".format(k),flush = True)
            k +=1
        while(True):
            p = random.choice(range(len(X)))
            if(y[p]!=-1):
                break
            else:
                pass
        X_new = X[p].copy()
        y_new = y[p]
        for n in range(math.ceil(PERCENT_NOISE*len(X_new)/100)):#dealing X_new
            noise = random.choice([1,-1])       #noise could only be 1 or -1
            pos = random.choice(range(len(X_new)))  #position belong to (0,len(sequence))
            X_new.insert(pos,noise)
            #print('insert {} at position {} in sequence {} now len of sequence is {}, the tag of sequence is {}'.format(noise,pos,p,len(X_new),y_new)) #for test
        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum
def fun_delete(X,y,PERCENT_DELETE,TIMES_DELETE): 
    X = list(X)
    y = list(y)
    X_sum = []
    y_sum = []
    #X_sum = X.copy()
    #y_sum = y.copy()
    k = 0
    for i in range(math.ceil(len(X)*TIMES_DELETE)): #RANDOM DELETE from here
        if(i in list(range(0,math.ceil(len(X)*TIMES_DELETE),math.ceil(len(X)*TIMES_DELETE)//10))):
            print("{}0% data has been dealed".format(k),flush = True)
            k +=1
        while(True):
            p = random.choice(range(len(X)))
            if(y[p]!=-1):
                break
            else:
                #print('-1 detected')
                pass
        X_new = X[p].copy()
        y_new = y[p]
        for n in range(math.ceil(PERCENT_DELETE*len(X_new)/100)):#dealing X_new
            pos = random.choice(range(len(X_new)))  #position belong to (0,len(sequence))
            del X_new[pos]
            #print('insert {} at position {} in sequence {} now len of sequence is {}'.format(noise,pos,p,len(X_new))) #for test
        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum
def fun_shuffle(X,y,PERCENT_CHANGED,TIMES_SHUFFLE): 
    X = list(X)
    y = list(y)
    #X_sum = X.copy()
    #y_sum = y.copy()
    X_sum = []
    y_sum = []
    k=0
    for i in range(math.ceil(len(X)*TIMES_SHUFFLE)):             #LOCALLY CHANGE from here
        if(i in list(range(0,math.ceil(len(X)*TIMES_SHUFFLE),math.ceil(len(X)*TIMES_SHUFFLE)//10))):
            print("{}0% data has been dealed".format(k),flush = True)
            k +=1
        while(True):
            p = random.choice(range(len(X)))
            if(y[p]!=-1):
                break
            else:
                #print('-1 detected')
                pass
        X_new = X[p].copy()
        y_new = y[p]
        length = math.ceil(PERCENT_CHANGED*len(X_new)/100)
        start = random.choice(range(len(X_new)-length))
        temp = X_new[start:start+length]
        random.shuffle(temp)
        X_new[start:start+length] = temp

        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum
def fun_transplant(X,y,PERCENT_TRANSPLANT,NB_TIMES):        #Magnificate dataset by adding noising randomly
    global datatype_Close
    X = list(X)
    y = list(y)
    X_sum = []
    y_sum = []
    #X_sum = X.copy()
    #y_sum = y.copy()
    #print("{} samples has beed add to X_train, {}% of noise for each sample".format(math.ceil(len(X)*NB_TIMES),PERCENT_TRANSPLANT))
    k=0
    print('When the process freezing, please check that datatype_Close has been set correctly')
    for i in range(math.ceil(len(X)*NB_TIMES)):
        if(i in list(range(0,math.ceil(len(X)*NB_TIMES),math.ceil(len(X)*NB_TIMES)//10))):
            print("{}0% data has been dealed".format(k),flush = True)
            k +=1
        #print(datatype_Close)    
        while(datatype_Close):                               # target pos p (sensitive website), pos q (non-sensitive website)
            p = random.choice(range(len(X)))
            q = random.choice(range(len(X)))
            if(p != q):                           # Closed_World
                break
            else:
                #print('-1 detected')
                pass
        while(not datatype_Close):                               # target pos p (sensitive website), pos q (non-sensitive website)
            p = random.choice(range(len(X)))
            q = random.choice(range(len(X)))
            if(y[p]!=-1 and y[q]==-1):               # open_world
                break
            else:
                #print('-1 detected')
                pass
        X_new = X[p].copy()
        target = X[q].copy()
        y_new = y[p]

        length_X = math.ceil(PERCENT_TRANSPLANT*len(X_new)/100)
        length_target =  math.ceil(PERCENT_TRANSPLANT*len(target)/100)
        start_X = random.choice(range(len(X_new)-length_X))
        start_target = random.choice(range(len(target)-length_target))
        temp = target[start_target:start_target+length_target]
        X_new[start_X:start_X+length_X] = temp
     
        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum

def random_launch(X,y,NB_tech):
    X = list(X)
    y = list(y)
    X_sum = X.copy()
    y_sum = y.copy()
    launch_list = random.sample(range(4),NB_tech)             #return [0,1,....]....depending on NB_tech
    for i in launch_list:
        if (i==0):
            print('adding noise...')
            X_new,y_new = fun_noise(X,y,PERCENT_NOISE=20,TIMES_NOISE=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==1):
            print('deleting...')
            X_new,y_new = fun_delete(X,y,PERCENT_DELETE=20,TIMES_DELETE=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==2):
            print('shuffling...')
            X_new,y_new = fun_shuffle(X,y,PERCENT_CHANGED=20,TIMES_SHUFFLE=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==3):
            print('transplanting...')
            X_new,y_new = fun_transplant(X,y,PERCENT_TRANSPLANT=20,NB_TIMES=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
    return np.array(X_sum),np.array(y_sum)                        #return two array of X, y

# %%
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing import sequence
from collections import Counter
#CLASSES_KNN = 101########################################################################################################################################################################################################
#CLASSES_WAKIE = 100########################################################################################################################################################################################################
MAXLEN_KNN = 2000
MAXLEN_WAKIE =5000

maxlen = 5000
NB_CLASSES = 0

def choose():
    global maxlen,NB_CLASSES
    print('if padding, the max of length of seq is {}'.format(maxlen))
    NB_CLASSES = len(Counter(y).keys())
    print('number of classes is {}'.format(NB_CLASSES))

choose()################################################################################################################################################################################################################

print('Average sequence length: {}'.format(np.mean(list(map(len, X)), dtype=int)))
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# if padding, the max of length of seq is 5000
# number of classes is 96
# Average sequence length: 2773

# %%
#FCN
from keras import Sequential
from keras.layers.core import Activation, Flatten, Dense, Dropout
from keras.optimizers import Adamax
def DNN(input_shape,classes):
    model = Sequential()
    model.add(Dense(128, input_shape=(input_shape,)))
    model.add(Activation('relu'))
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dense(512))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dense(classes))
    model.add(Activation('softmax'))
    return model

# %%
#CNN
from keras import Input,Model,Sequential
from keras.layers import Embedding,GlobalAveragePooling1D,Dense,Dropout
from keras.layers import Conv1D, MaxPooling1D, BatchNormalization
from keras.layers.core import Activation, Flatten, Dense, Dropout
from keras.layers.advanced_activations import ELU
from keras.initializers import glorot_uniform
from keras.optimizers import Adamax
def CNN(input_shape, classes):
    model = Sequential()
    #Block1
    filter_num = ['None',32,64,128,256]
    kernel_size = ['None',8,8,8,8]
    conv_stride_size = ['None',1,1,1,1]
    pool_stride_size = ['None',4,4,4,4]
    pool_size = ['None',8,8,8,8]

    model.add(Conv1D(filters=filter_num[1], kernel_size=kernel_size[1], input_shape=(input_shape,1),
                      strides=conv_stride_size[1], padding='same',
                      name='block1_conv1'))
    model.add(BatchNormalization(axis=-1))
    model.add(ELU(alpha=1.0, name='block1_adv_act1'))
    model.add(Conv1D(filters=filter_num[1], kernel_size=kernel_size[1],
                      strides=conv_stride_size[1], padding='same',
                      name='block1_conv2'))
    model.add(BatchNormalization(axis=-1))
    model.add(ELU(alpha=1.0, name='block1_adv_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[1], strides=pool_stride_size[1],
                            padding='same', name='block1_pool'))
    model.add(Dropout(0.1, name='block1_dropout'))

    model.add(Conv1D(filters=filter_num[2], kernel_size=kernel_size[2],
                      strides=conv_stride_size[2], padding='same',
                      name='block2_conv1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block2_act1'))

    model.add(Conv1D(filters=filter_num[2], kernel_size=kernel_size[2],
                      strides=conv_stride_size[2], padding='same',
                      name='block2_conv2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block2_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[2], strides=pool_stride_size[3],
                            padding='same', name='block2_pool'))
    model.add(Dropout(0.1, name='block2_dropout'))

    model.add(Conv1D(filters=filter_num[3], kernel_size=kernel_size[3],
                      strides=conv_stride_size[3], padding='same',
                      name='block3_conv1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block3_act1'))
    model.add(Conv1D(filters=filter_num[3], kernel_size=kernel_size[3],
                      strides=conv_stride_size[3], padding='same',
                      name='block3_conv2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block3_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[3], strides=pool_stride_size[3],
                            padding='same', name='block3_pool'))
    model.add(Dropout(0.1, name='block3_dropout'))

    model.add(Conv1D(filters=filter_num[4], kernel_size=kernel_size[4],
                      strides=conv_stride_size[4], padding='same',
                      name='block4_conv1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block4_act1'))
    model.add(Conv1D(filters=filter_num[4], kernel_size=kernel_size[4],
                      strides=conv_stride_size[4], padding='same',
                      name='block4_conv2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block4_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[4], strides=pool_stride_size[4],
                            padding='same', name='block4_pool'))
    model.add(Dropout(0.1, name='block4_dropout'))

    model.add(Flatten(name='flatten'))
    model.add(Dense(512, kernel_initializer=glorot_uniform(seed=0), name='fc1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='fc1_act'))

    model.add(Dropout(0.7, name='fc1_dropout'))

    model.add(Dense(512, kernel_initializer=glorot_uniform(seed=0), name='fc2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='fc2_act'))

    model.add(Dropout(0.5, name='fc2_dropout'))

    model.add(Dense(classes, kernel_initializer=glorot_uniform(seed=0), name='fc3'))
    model.add(Activation('softmax', name="softmax"))
    return model

# %%
import keras
from keras import backend as K

def precision(y_true, y_pred):
    # Calculates the precision
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    # Calculates the recall
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def fbeta_score(y_true, y_pred, beta=1):
    # Calculates the F score, the weighted harmonic mean of precision and recall.
    if beta < 0:
        raise ValueError('The lowest choosable beta is zero (only precision).')
 
    # If there are no true positives, fix the F score at 0 like sklearn.
    if K.sum(K.round(K.clip(y_true, 0, 1))) == 0:
        return 0

    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    bb = beta ** 2
    fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
    return fbeta_score

def fmeasure(y_true, y_pred):
    # Calculates the f-measure, the harmonic mean of precision and recall.
    return fbeta_score(y_true, y_pred, beta=1)

# %%
#DNN               ############# test for noise adding  , function :: creat_data############

BATCH_SIZE = 64
NB_EPOCHS = 50
VALIDATION_SPLIT = 0.3

OPTIMIZER = Adamax()

historys_DNN = []
NB_tech = [4,4,4,4]

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)


print('Pad sequences to ',maxlen)
print('ready for 4')
X_4,y_4 = random_launch(X_train,y_train,NB_tech[0])
X_4 = sequence.pad_sequences(X_4, maxlen=maxlen,padding='post',truncating='post')
y_4 = np_utils.to_categorical(y_4, NB_CLASSES)
'''
print('ready for 3')
X_3,y_3 = random_launch(X_train,y_train,NB_tech[1])
X_3 = sequence.pad_sequences(X_3, maxlen=maxlen,padding='post',truncating='post')
X_3 = X_3[:,:,np.newaxis]
y_3 = np_utils.to_categorical(y_3, NB_CLASSES)
print('ready for 2')
X_2,y_2 = random_launch(X_train,y_train,NB_tech[2])
X_2 = sequence.pad_sequences(X_2, maxlen=maxlen,padding='post',truncating='post')
X_2 = X_2[:,:,np.newaxis]
y_2 = np_utils.to_categorical(y_2, NB_CLASSES)
print('ready for 1')
X_1,y_1 = random_launch(X_train,y_train,NB_tech[3])
X_1 = sequence.pad_sequences(X_1, maxlen=maxlen,padding='post',truncating='post')
X_1 = X_1[:,:,np.newaxis]
y_1 = np_utils.to_categorical(y_1, NB_CLASSES)

'''
X_train = sequence.pad_sequences(X_train, maxlen=maxlen,padding='post',truncating='post')
y_train = np_utils.to_categorical(y_train, NB_CLASSES)
X_test = sequence.pad_sequences(X_test, maxlen=maxlen,padding='post',truncating='post')
y_test = np_utils.to_categorical(y_test, NB_CLASSES)

print('the shape of x_train',X_train.shape)
print('the shape of y_train',y_train.shape)
print('the shape of x_test',X_test.shape)
print('the shape of y_test',y_test.shape)

model_DNN = DNN(maxlen,NB_CLASSES)
model_DNN.summary()
model_DNN.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])


history_DNN_loss = []
history_DNN_acc = []
history_DNN_precision = []
history_DNN_recall = []
history_DNN_fmeasure = []
history_DNN_val_loss = []
history_DNN_val_acc = []
history_DNN_val_precision = []
history_DNN_val_recall = []
history_DNN_val_fmeasure = []

def recorder_DNN(history):
    history_DNN_loss.append(history.history['loss'][0])
    history_DNN_acc.append(history.history['acc'][0])
    history_DNN_precision.append(history.history['precision'][0])
    history_DNN_recall.append(history.history['recall'][0])
    history_DNN_fmeasure.append(history.history['fmeasure'][0])
    history_DNN_val_loss.append(history.history['val_loss'][0])
    history_DNN_val_acc.append(history.history['val_acc'][0])
    history_DNN_val_precision.append(history.history['val_precision'][0])
    history_DNN_val_recall.append(history.history['val_recall'][0])
    history_DNN_val_fmeasure.append(history.history['val_fmeasure'][0])


for i in range(NB_EPOCHS):
    if (i<=NB_EPOCHS/5):
        history = model_DNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)
    elif (NB_EPOCHS/5<i and i%2==1 and i<(NB_EPOCHS*4/5)):
        history = model_DNN.fit(X_4,y_4,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)
    elif (NB_EPOCHS/5<i and i%2==0 and i<(NB_EPOCHS*4/5)):
        history = model_DNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)
    else:
        history = model_DNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)

print('base_line_now#######################################################################################################################################################################################################')
model_DNN_org = DNN(maxlen,NB_CLASSES)
model_DNN_org.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])
history_DNN_org = model_DNN_org.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=50,validation_data=(X_test,y_test),verbose=1)
# Out:
# Pad sequences to  5000
# ready for 4
# deleting...
# 00% data has been dealed
# 10% data has been dealed
# 20% data has been dealed
# 30% data has been dealed
# 40% data has been dealed
# 50% data has been dealed
# 60% data has been dealed
# 70% data has been dealed
# 80% data has been dealed
# 90% data has been dealed
# transplanting...
# When the process freezing, please check that datatype_Close has been set correctly
# 00% data has been dealed
# 10% data has been dealed
# 20% data has been dealed
# 30% data has been dealed
# 40% data has been dealed
# 50% data has been dealed
# 60% data has been dealed
# 70% data has been dealed
# 80% data has been dealed
# 90% data has been dealed
# adding noise...
# 00% data has been dealed
# 10% data has been dealed
# 20% data has been dealed
# 30% data has been dealed
# 40% data has been dealed
# 50% data has been dealed
# 60% data has been dealed
# 70% data has been dealed
# 80% data has been dealed
# 90% data has been dealed
# shuffling...
# 00% data has been dealed
# 10% data has been dealed
# 20% data has been dealed
# 30% data has been dealed
# 40% data has been dealed
# 50% data has been dealed
# 60% data has been dealed
# 70% data has been dealed
# 80% data has been dealed
# 90% data has been dealed
# the shape of x_train (67200, 5000)
# the shape of y_train (67200, 96)
# the shape of x_test (28800, 5000)
# the shape of y_test (28800, 96)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               640128
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               131584
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# activation_4 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 96)                49248
# _________________________________________________________________
# activation_6 (Activation)    (None, 96)                0
# =================================================================
# Total params: 1,904,096
# Trainable params: 1,904,096
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 67200/67200 [==============================] - 18s 261us/step - loss: 3.4938 - acc: 0.2005 - precision: 0.2908 - recall: 0.0109 - fmeasure: 0.0206 - val_loss: 3.0226 - val_acc: 0.2153 - val_precision: 0.2525 - val_recall: 0.0058 - val_fmeasure: 0.0112
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 116us/step - loss: 2.9549 - acc: 0.2160 - precision: 0.4781 - recall: 0.0203 - fmeasure: 0.0386 - val_loss: 2.8128 - val_acc: 0.2451 - val_precision: 0.4549 - val_recall: 0.0147 - val_fmeasure: 0.0282
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 117us/step - loss: 2.6822 - acc: 0.2506 - precision: 0.5830 - recall: 0.0403 - fmeasure: 0.0744 - val_loss: 2.7200 - val_acc: 0.2573 - val_precision: 0.5334 - val_recall: 0.0291 - val_fmeasure: 0.0545
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 117us/step - loss: 2.4874 - acc: 0.2841 - precision: 0.6212 - recall: 0.0634 - fmeasure: 0.1136 - val_loss: 2.6906 - val_acc: 0.2661 - val_precision: 0.5528 - val_recall: 0.0299 - val_fmeasure: 0.0560
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 117us/step - loss: 2.3133 - acc: 0.3149 - precision: 0.6387 - recall: 0.0892 - fmeasure: 0.1549 - val_loss: 2.7319 - val_acc: 0.2650 - val_precision: 0.4759 - val_recall: 0.0439 - val_fmeasure: 0.0795
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 118us/step - loss: 2.1791 - acc: 0.3453 - precision: 0.6474 - recall: 0.1170 - fmeasure: 0.1962 - val_loss: 2.8031 - val_acc: 0.2679 - val_precision: 0.4499 - val_recall: 0.0616 - val_fmeasure: 0.1072
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 117us/step - loss: 2.0498 - acc: 0.3743 - precision: 0.6613 - recall: 0.1471 - fmeasure: 0.2386 - val_loss: 2.8017 - val_acc: 0.2683 - val_precision: 0.4594 - val_recall: 0.0677 - val_fmeasure: 0.1166
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 117us/step - loss: 1.9438 - acc: 0.4004 - precision: 0.6760 - recall: 0.1758 - fmeasure: 0.2767 - val_loss: 2.9126 - val_acc: 0.2599 - val_precision: 0.4083 - val_recall: 0.0790 - val_fmeasure: 0.1312
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 117us/step - loss: 1.8469 - acc: 0.4261 - precision: 0.6809 - recall: 0.2084 - fmeasure: 0.3171 - val_loss: 2.9956 - val_acc: 0.2629 - val_precision: 0.3861 - val_recall: 0.0951 - val_fmeasure: 0.1513
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 118us/step - loss: 1.7574 - acc: 0.4512 - precision: 0.6886 - recall: 0.2390 - fmeasure: 0.3528 - val_loss: 3.1152 - val_acc: 0.2567 - val_precision: 0.3676 - val_recall: 0.1067 - val_fmeasure: 0.1642
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 117us/step - loss: 1.6743 - acc: 0.4765 - precision: 0.7020 - recall: 0.2725 - fmeasure: 0.3907 - val_loss: 3.2145 - val_acc: 0.2591 - val_precision: 0.3619 - val_recall: 0.1172 - val_fmeasure: 0.1760
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 18s 105us/step - loss: 2.8021 - acc: 0.2881 - precision: 0.6491 - recall: 0.0709 - fmeasure: 0.1263 - val_loss: 2.7005 - val_acc: 0.2546 - val_precision: 0.5144 - val_recall: 0.0490 - val_fmeasure: 0.0883
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 121us/step - loss: 1.7097 - acc: 0.4729 - precision: 0.6996 - recall: 0.2674 - fmeasure: 0.3843 - val_loss: 2.9702 - val_acc: 0.2657 - val_precision: 0.3778 - val_recall: 0.1109 - val_fmeasure: 0.1703
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 18s 105us/step - loss: 2.5938 - acc: 0.3270 - precision: 0.6634 - recall: 0.1080 - fmeasure: 0.1839 - val_loss: 2.7367 - val_acc: 0.2475 - val_precision: 0.4649 - val_recall: 0.0644 - val_fmeasure: 0.1120
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 117us/step - loss: 1.6104 - acc: 0.5033 - precision: 0.7129 - recall: 0.3100 - fmeasure: 0.4299 - val_loss: 3.0139 - val_acc: 0.2630 - val_precision: 0.3676 - val_recall: 0.1195 - val_fmeasure: 0.1792
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 18s 105us/step - loss: 2.4507 - acc: 0.3561 - precision: 0.6788 - recall: 0.1422 - fmeasure: 0.2329 - val_loss: 2.7967 - val_acc: 0.2430 - val_precision: 0.4376 - val_recall: 0.0669 - val_fmeasure: 0.1150
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 116us/step - loss: 1.5205 - acc: 0.5292 - precision: 0.7279 - recall: 0.3495 - fmeasure: 0.4701 - val_loss: 3.1003 - val_acc: 0.2668 - val_precision: 0.3584 - val_recall: 0.1420 - val_fmeasure: 0.2024
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 18s 105us/step - loss: 2.3336 - acc: 0.3844 - precision: 0.6960 - recall: 0.1745 - fmeasure: 0.2767 - val_loss: 2.8628 - val_acc: 0.2414 - val_precision: 0.4106 - val_recall: 0.0827 - val_fmeasure: 0.1364
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 118us/step - loss: 1.4322 - acc: 0.5563 - precision: 0.7420 - recall: 0.3900 - fmeasure: 0.5093 - val_loss: 3.1791 - val_acc: 0.2623 - val_precision: 0.3381 - val_recall: 0.1379 - val_fmeasure: 0.1950
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 18s 105us/step - loss: 2.2337 - acc: 0.4085 - precision: 0.7090 - recall: 0.2053 - fmeasure: 0.3162 - val_loss: 2.9420 - val_acc: 0.2368 - val_precision: 0.3830 - val_recall: 0.0938 - val_fmeasure: 0.1495
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 118us/step - loss: 1.3523 - acc: 0.5819 - precision: 0.7533 - recall: 0.4260 - fmeasure: 0.5425 - val_loss: 3.2589 - val_acc: 0.2618 - val_precision: 0.3348 - val_recall: 0.1520 - val_fmeasure: 0.2082
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 19s 107us/step - loss: 2.1554 - acc: 0.4287 - precision: 0.7127 - recall: 0.2304 - fmeasure: 0.3460 - val_loss: 2.9748 - val_acc: 0.2320 - val_precision: 0.3692 - val_recall: 0.0911 - val_fmeasure: 0.1451
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 116us/step - loss: 1.2821 - acc: 0.6029 - precision: 0.7675 - recall: 0.4583 - fmeasure: 0.5721 - val_loss: 3.4328 - val_acc: 0.2577 - val_precision: 0.3239 - val_recall: 0.1620 - val_fmeasure: 0.2152
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 19s 106us/step - loss: 2.0777 - acc: 0.4489 - precision: 0.7235 - recall: 0.2554 - fmeasure: 0.3752 - val_loss: 3.0263 - val_acc: 0.2342 - val_precision: 0.3557 - val_recall: 0.0958 - val_fmeasure: 0.1500
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 117us/step - loss: 1.2181 - acc: 0.6248 - precision: 0.7779 - recall: 0.4872 - fmeasure: 0.5975 - val_loss: 3.5586 - val_acc: 0.2524 - val_precision: 0.3119 - val_recall: 0.1629 - val_fmeasure: 0.2132
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 18s 105us/step - loss: 2.0096 - acc: 0.4656 - precision: 0.7327 - recall: 0.2790 - fmeasure: 0.4019 - val_loss: 3.1122 - val_acc: 0.2310 - val_precision: 0.3471 - val_recall: 0.1105 - val_fmeasure: 0.1666
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 117us/step - loss: 1.1605 - acc: 0.6390 - precision: 0.7853 - recall: 0.5112 - fmeasure: 0.6177 - val_loss: 3.6155 - val_acc: 0.2528 - val_precision: 0.3070 - val_recall: 0.1704 - val_fmeasure: 0.2186
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 18s 105us/step - loss: 1.9552 - acc: 0.4808 - precision: 0.7382 - recall: 0.2984 - fmeasure: 0.4227 - val_loss: 3.1676 - val_acc: 0.2276 - val_precision: 0.3302 - val_recall: 0.1100 - val_fmeasure: 0.1640
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 116us/step - loss: 1.1178 - acc: 0.6536 - precision: 0.7939 - recall: 0.5319 - fmeasure: 0.6357 - val_loss: 3.7007 - val_acc: 0.2523 - val_precision: 0.3038 - val_recall: 0.1720 - val_fmeasure: 0.2191
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 18s 105us/step - loss: 1.8971 - acc: 0.4950 - precision: 0.7472 - recall: 0.3193 - fmeasure: 0.4453 - val_loss: 3.2456 - val_acc: 0.2280 - val_precision: 0.3247 - val_recall: 0.1138 - val_fmeasure: 0.1676
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 117us/step - loss: 1.0705 - acc: 0.6677 - precision: 0.8022 - recall: 0.5527 - fmeasure: 0.6532 - val_loss: 3.7660 - val_acc: 0.2454 - val_precision: 0.2958 - val_recall: 0.1705 - val_fmeasure: 0.2158
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 18s 105us/step - loss: 1.8506 - acc: 0.5071 - precision: 0.7516 - recall: 0.3355 - fmeasure: 0.4617 - val_loss: 3.2745 - val_acc: 0.2244 - val_precision: 0.3215 - val_recall: 0.1164 - val_fmeasure: 0.1700
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 117us/step - loss: 1.0332 - acc: 0.6788 - precision: 0.8075 - recall: 0.5699 - fmeasure: 0.6670 - val_loss: 3.8506 - val_acc: 0.2501 - val_precision: 0.2959 - val_recall: 0.1792 - val_fmeasure: 0.2227
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 18s 105us/step - loss: 1.8020 - acc: 0.5208 - precision: 0.7586 - recall: 0.3527 - fmeasure: 0.4794 - val_loss: 3.3754 - val_acc: 0.2199 - val_precision: 0.3026 - val_recall: 0.1157 - val_fmeasure: 0.1665
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 116us/step - loss: 0.9964 - acc: 0.6937 - precision: 0.8140 - recall: 0.5881 - fmeasure: 0.6816 - val_loss: 3.9580 - val_acc: 0.2420 - val_precision: 0.2840 - val_recall: 0.1717 - val_fmeasure: 0.2134
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 18s 106us/step - loss: 1.7589 - acc: 0.5312 - precision: 0.7637 - recall: 0.3674 - fmeasure: 0.4941 - val_loss: 3.4822 - val_acc: 0.2195 - val_precision: 0.3023 - val_recall: 0.1216 - val_fmeasure: 0.1725
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 116us/step - loss: 0.9658 - acc: 0.7024 - precision: 0.8193 - recall: 0.6032 - fmeasure: 0.6938 - val_loss: 4.0080 - val_acc: 0.2409 - val_precision: 0.2838 - val_recall: 0.1729 - val_fmeasure: 0.2144
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 18s 106us/step - loss: 1.7273 - acc: 0.5403 - precision: 0.7683 - recall: 0.3790 - fmeasure: 0.5055 - val_loss: 3.4622 - val_acc: 0.2230 - val_precision: 0.3022 - val_recall: 0.1229 - val_fmeasure: 0.1739
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 117us/step - loss: 0.9321 - acc: 0.7126 - precision: 0.8250 - recall: 0.6183 - fmeasure: 0.7058 - val_loss: 4.0790 - val_acc: 0.2441 - val_precision: 0.2863 - val_recall: 0.1800 - val_fmeasure: 0.2205
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 18s 106us/step - loss: 1.6845 - acc: 0.5529 - precision: 0.7751 - recall: 0.3965 - fmeasure: 0.5227 - val_loss: 3.6477 - val_acc: 0.2194 - val_precision: 0.2892 - val_recall: 0.1283 - val_fmeasure: 0.1770
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 116us/step - loss: 0.9067 - acc: 0.7211 - precision: 0.8285 - recall: 0.6294 - fmeasure: 0.7143 - val_loss: 4.2753 - val_acc: 0.2391 - val_precision: 0.2759 - val_recall: 0.1818 - val_fmeasure: 0.2188
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 116us/step - loss: 0.8247 - acc: 0.7433 - precision: 0.8401 - recall: 0.6642 - fmeasure: 0.7411 - val_loss: 4.4394 - val_acc: 0.2347 - val_precision: 0.2689 - val_recall: 0.1823 - val_fmeasure: 0.2169
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 117us/step - loss: 0.7840 - acc: 0.7577 - precision: 0.8480 - recall: 0.6834 - fmeasure: 0.7561 - val_loss: 4.4295 - val_acc: 0.2326 - val_precision: 0.2652 - val_recall: 0.1806 - val_fmeasure: 0.2145
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 118us/step - loss: 0.7505 - acc: 0.7679 - precision: 0.8531 - recall: 0.6984 - fmeasure: 0.7674 - val_loss: 4.7579 - val_acc: 0.2347 - val_precision: 0.2623 - val_recall: 0.1915 - val_fmeasure: 0.2210
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 116us/step - loss: 0.7219 - acc: 0.7783 - precision: 0.8576 - recall: 0.7118 - fmeasure: 0.7773 - val_loss: 4.7425 - val_acc: 0.2339 - val_precision: 0.2611 - val_recall: 0.1889 - val_fmeasure: 0.2189
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 117us/step - loss: 0.6969 - acc: 0.7842 - precision: 0.8626 - recall: 0.7213 - fmeasure: 0.7850 - val_loss: 4.8830 - val_acc: 0.2325 - val_precision: 0.2576 - val_recall: 0.1904 - val_fmeasure: 0.2187
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 9s 127us/step - loss: 0.6751 - acc: 0.7909 - precision: 0.8666 - recall: 0.7309 - fmeasure: 0.7923 - val_loss: 5.0395 - val_acc: 0.2313 - val_precision: 0.2557 - val_recall: 0.1949 - val_fmeasure: 0.2209
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 123us/step - loss: 0.6555 - acc: 0.7980 - precision: 0.8698 - recall: 0.7401 - fmeasure: 0.7992 - val_loss: 4.9444 - val_acc: 0.2271 - val_precision: 0.2510 - val_recall: 0.1872 - val_fmeasure: 0.2141
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 118us/step - loss: 0.6344 - acc: 0.8059 - precision: 0.8739 - recall: 0.7501 - fmeasure: 0.8067 - val_loss: 5.0295 - val_acc: 0.2262 - val_precision: 0.2488 - val_recall: 0.1897 - val_fmeasure: 0.2150
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 8s 119us/step - loss: 0.6201 - acc: 0.8098 - precision: 0.8742 - recall: 0.7568 - fmeasure: 0.8107 - val_loss: 5.1762 - val_acc: 0.2254 - val_precision: 0.2496 - val_recall: 0.1916 - val_fmeasure: 0.2166
# base_line_now#######################################################################################################################################################################################################
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/50
# 67200/67200 [==============================] - 9s 129us/step - loss: 3.5174 - acc: 0.1995 - precision: 0.2912 - recall: 0.0107 - fmeasure: 0.0202 - val_loss: 3.0147 - val_acc: 0.2205 - val_precision: 0.2422 - val_recall: 0.0053 - val_fmeasure: 0.0103
# Epoch 2/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 2.9615 - acc: 0.2185 - precision: 0.4836 - recall: 0.0223 - fmeasure: 0.0421 - val_loss: 2.8034 - val_acc: 0.2423 - val_precision: 0.3374 - val_recall: 0.0080 - val_fmeasure: 0.0155
# Epoch 3/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 2.6871 - acc: 0.2528 - precision: 0.5759 - recall: 0.0420 - fmeasure: 0.0774 - val_loss: 2.7118 - val_acc: 0.2591 - val_precision: 0.5382 - val_recall: 0.0238 - val_fmeasure: 0.0451
# Epoch 4/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 2.4864 - acc: 0.2846 - precision: 0.6143 - recall: 0.0655 - fmeasure: 0.1171 - val_loss: 2.7062 - val_acc: 0.2654 - val_precision: 0.5184 - val_recall: 0.0405 - val_fmeasure: 0.0741
# Epoch 5/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 2.3110 - acc: 0.3193 - precision: 0.6493 - recall: 0.0949 - fmeasure: 0.1638 - val_loss: 2.7296 - val_acc: 0.2723 - val_precision: 0.5247 - val_recall: 0.0427 - val_fmeasure: 0.0780
# Epoch 6/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 2.1619 - acc: 0.3522 - precision: 0.6650 - recall: 0.1278 - fmeasure: 0.2126 - val_loss: 2.7964 - val_acc: 0.2636 - val_precision: 0.4398 - val_recall: 0.0653 - val_fmeasure: 0.1126
# Epoch 7/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 2.0431 - acc: 0.3810 - precision: 0.6766 - recall: 0.1589 - fmeasure: 0.2554 - val_loss: 2.8322 - val_acc: 0.2673 - val_precision: 0.4265 - val_recall: 0.0730 - val_fmeasure: 0.1235
# Epoch 8/50
# 67200/67200 [==============================] - 8s 121us/step - loss: 1.9244 - acc: 0.4104 - precision: 0.6850 - recall: 0.1913 - fmeasure: 0.2968 - val_loss: 2.9060 - val_acc: 0.2650 - val_precision: 0.4190 - val_recall: 0.0831 - val_fmeasure: 0.1374
# Epoch 9/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 1.8317 - acc: 0.4352 - precision: 0.6956 - recall: 0.2210 - fmeasure: 0.3333 - val_loss: 3.0400 - val_acc: 0.2538 - val_precision: 0.3842 - val_recall: 0.0917 - val_fmeasure: 0.1468
# Epoch 10/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 1.7385 - acc: 0.4589 - precision: 0.7115 - recall: 0.2551 - fmeasure: 0.3734 - val_loss: 3.1119 - val_acc: 0.2532 - val_precision: 0.3621 - val_recall: 0.1009 - val_fmeasure: 0.1568
# Epoch 11/50
# 67200/67200 [==============================] - 8s 119us/step - loss: 1.6589 - acc: 0.4847 - precision: 0.7195 - recall: 0.2856 - fmeasure: 0.4068 - val_loss: 3.2662 - val_acc: 0.2531 - val_precision: 0.3461 - val_recall: 0.1180 - val_fmeasure: 0.1750
# Epoch 12/50
# 67200/67200 [==============================] - 8s 119us/step - loss: 1.5871 - acc: 0.5014 - precision: 0.7244 - recall: 0.3146 - fmeasure: 0.4368 - val_loss: 3.3500 - val_acc: 0.2519 - val_precision: 0.3352 - val_recall: 0.1247 - val_fmeasure: 0.1809
# Epoch 13/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 1.5180 - acc: 0.5232 - precision: 0.7360 - recall: 0.3435 - fmeasure: 0.4664 - val_loss: 3.4451 - val_acc: 0.2495 - val_precision: 0.3343 - val_recall: 0.1375 - val_fmeasure: 0.1940
# Epoch 14/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 1.4526 - acc: 0.5445 - precision: 0.7434 - recall: 0.3705 - fmeasure: 0.4928 - val_loss: 3.5526 - val_acc: 0.2488 - val_precision: 0.3215 - val_recall: 0.1417 - val_fmeasure: 0.1958
# Epoch 15/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 1.3948 - acc: 0.5616 - precision: 0.7510 - recall: 0.3973 - fmeasure: 0.5179 - val_loss: 3.5854 - val_acc: 0.2464 - val_precision: 0.3152 - val_recall: 0.1420 - val_fmeasure: 0.1950
# Epoch 16/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 1.3353 - acc: 0.5784 - precision: 0.7611 - recall: 0.4232 - fmeasure: 0.5423 - val_loss: 3.7411 - val_acc: 0.2377 - val_precision: 0.3007 - val_recall: 0.1483 - val_fmeasure: 0.1980
# Epoch 17/50
# 67200/67200 [==============================] - 8s 119us/step - loss: 1.2803 - acc: 0.5955 - precision: 0.7665 - recall: 0.4495 - fmeasure: 0.5651 - val_loss: 3.8470 - val_acc: 0.2393 - val_precision: 0.2991 - val_recall: 0.1572 - val_fmeasure: 0.2054
# Epoch 18/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 1.2313 - acc: 0.6105 - precision: 0.7738 - recall: 0.4706 - fmeasure: 0.5838 - val_loss: 4.0359 - val_acc: 0.2318 - val_precision: 0.2812 - val_recall: 0.1560 - val_fmeasure: 0.2002
# Epoch 19/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 1.1875 - acc: 0.6225 - precision: 0.7811 - recall: 0.4918 - fmeasure: 0.6022 - val_loss: 4.1001 - val_acc: 0.2333 - val_precision: 0.2847 - val_recall: 0.1623 - val_fmeasure: 0.2061
# Epoch 20/50
# 67200/67200 [==============================] - 8s 119us/step - loss: 1.1465 - acc: 0.6383 - precision: 0.7887 - recall: 0.5129 - fmeasure: 0.6203 - val_loss: 4.1574 - val_acc: 0.2301 - val_precision: 0.2790 - val_recall: 0.1614 - val_fmeasure: 0.2040
# Epoch 21/50
# 67200/67200 [==============================] - 8s 122us/step - loss: 1.1007 - acc: 0.6535 - precision: 0.7944 - recall: 0.5314 - fmeasure: 0.6355 - val_loss: 4.3206 - val_acc: 0.2283 - val_precision: 0.2697 - val_recall: 0.1671 - val_fmeasure: 0.2059
# Epoch 22/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 1.0697 - acc: 0.6620 - precision: 0.7999 - recall: 0.5459 - fmeasure: 0.6477 - val_loss: 4.3770 - val_acc: 0.2283 - val_precision: 0.2729 - val_recall: 0.1700 - val_fmeasure: 0.2090
# Epoch 23/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 1.0370 - acc: 0.6717 - precision: 0.8026 - recall: 0.5610 - fmeasure: 0.6592 - val_loss: 4.4597 - val_acc: 0.2297 - val_precision: 0.2674 - val_recall: 0.1691 - val_fmeasure: 0.2067
# Epoch 24/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 0.9964 - acc: 0.6825 - precision: 0.8082 - recall: 0.5791 - fmeasure: 0.6736 - val_loss: 4.6377 - val_acc: 0.2270 - val_precision: 0.2622 - val_recall: 0.1764 - val_fmeasure: 0.2105
# Epoch 25/50
# 67200/67200 [==============================] - 8s 119us/step - loss: 0.9639 - acc: 0.6923 - precision: 0.8129 - recall: 0.5940 - fmeasure: 0.6854 - val_loss: 4.6644 - val_acc: 0.2232 - val_precision: 0.2573 - val_recall: 0.1721 - val_fmeasure: 0.2059
# Epoch 26/50
# 67200/67200 [==============================] - 8s 119us/step - loss: 0.9349 - acc: 0.7048 - precision: 0.8208 - recall: 0.6081 - fmeasure: 0.6976 - val_loss: 4.7734 - val_acc: 0.2225 - val_precision: 0.2553 - val_recall: 0.1742 - val_fmeasure: 0.2067
# Epoch 27/50
# 67200/67200 [==============================] - 8s 119us/step - loss: 0.9091 - acc: 0.7107 - precision: 0.8211 - recall: 0.6206 - fmeasure: 0.7060 - val_loss: 4.8684 - val_acc: 0.2237 - val_precision: 0.2556 - val_recall: 0.1776 - val_fmeasure: 0.2092
# Epoch 28/50
# 67200/67200 [==============================] - 8s 121us/step - loss: 0.8781 - acc: 0.7217 - precision: 0.8286 - recall: 0.6340 - fmeasure: 0.7175 - val_loss: 4.9879 - val_acc: 0.2209 - val_precision: 0.2496 - val_recall: 0.1776 - val_fmeasure: 0.2072
# Epoch 29/50
# 67200/67200 [==============================] - 8s 119us/step - loss: 0.8470 - acc: 0.7311 - precision: 0.8335 - recall: 0.6473 - fmeasure: 0.7278 - val_loss: 5.0311 - val_acc: 0.2179 - val_precision: 0.2502 - val_recall: 0.1771 - val_fmeasure: 0.2071
# Epoch 30/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 0.8264 - acc: 0.7393 - precision: 0.8351 - recall: 0.6589 - fmeasure: 0.7359 - val_loss: 5.1537 - val_acc: 0.2156 - val_precision: 0.2435 - val_recall: 0.1782 - val_fmeasure: 0.2055
# Epoch 31/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 0.8064 - acc: 0.7440 - precision: 0.8391 - recall: 0.6670 - fmeasure: 0.7425 - val_loss: 5.1792 - val_acc: 0.2167 - val_precision: 0.2436 - val_recall: 0.1791 - val_fmeasure: 0.2062
# Epoch 32/50
# 67200/67200 [==============================] - 8s 119us/step - loss: 0.7886 - acc: 0.7522 - precision: 0.8422 - recall: 0.6767 - fmeasure: 0.7498 - val_loss: 5.2727 - val_acc: 0.2154 - val_precision: 0.2406 - val_recall: 0.1798 - val_fmeasure: 0.2056
# Epoch 33/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 0.7627 - acc: 0.7596 - precision: 0.8464 - recall: 0.6897 - fmeasure: 0.7593 - val_loss: 5.3482 - val_acc: 0.2206 - val_precision: 0.2444 - val_recall: 0.1862 - val_fmeasure: 0.2111
# Epoch 34/50
# 67200/67200 [==============================] - 8s 119us/step - loss: 0.7414 - acc: 0.7659 - precision: 0.8478 - recall: 0.6973 - fmeasure: 0.7646 - val_loss: 5.4942 - val_acc: 0.2176 - val_precision: 0.2411 - val_recall: 0.1855 - val_fmeasure: 0.2094
# Epoch 35/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 0.7261 - acc: 0.7702 - precision: 0.8498 - recall: 0.7027 - fmeasure: 0.7686 - val_loss: 5.3520 - val_acc: 0.2163 - val_precision: 0.2411 - val_recall: 0.1831 - val_fmeasure: 0.2079
# Epoch 36/50
# 67200/67200 [==============================] - 8s 124us/step - loss: 0.7049 - acc: 0.7788 - precision: 0.8551 - recall: 0.7156 - fmeasure: 0.7785 - val_loss: 5.6922 - val_acc: 0.2138 - val_precision: 0.2356 - val_recall: 0.1853 - val_fmeasure: 0.2073
# Epoch 37/50
# 67200/67200 [==============================] - 8s 121us/step - loss: 0.6868 - acc: 0.7836 - precision: 0.8567 - recall: 0.7220 - fmeasure: 0.7830 - val_loss: 5.6890 - val_acc: 0.2166 - val_precision: 0.2375 - val_recall: 0.1886 - val_fmeasure: 0.2100
# Epoch 38/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 0.6699 - acc: 0.7906 - precision: 0.8619 - recall: 0.7312 - fmeasure: 0.7906 - val_loss: 5.6286 - val_acc: 0.2121 - val_precision: 0.2343 - val_recall: 0.1837 - val_fmeasure: 0.2057
# Epoch 39/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 0.6561 - acc: 0.7941 - precision: 0.8628 - recall: 0.7375 - fmeasure: 0.7947 - val_loss: 5.8219 - val_acc: 0.2086 - val_precision: 0.2283 - val_recall: 0.1822 - val_fmeasure: 0.2024
# Epoch 40/50
# 67200/67200 [==============================] - 8s 121us/step - loss: 0.6375 - acc: 0.8009 - precision: 0.8669 - recall: 0.7455 - fmeasure: 0.8011 - val_loss: 5.8163 - val_acc: 0.2113 - val_precision: 0.2304 - val_recall: 0.1845 - val_fmeasure: 0.2047
# Epoch 41/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 0.6227 - acc: 0.8039 - precision: 0.8683 - recall: 0.7511 - fmeasure: 0.8050 - val_loss: 5.8450 - val_acc: 0.2134 - val_precision: 0.2325 - val_recall: 0.1885 - val_fmeasure: 0.2080
# Epoch 42/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 0.6100 - acc: 0.8066 - precision: 0.8701 - recall: 0.7573 - fmeasure: 0.8093 - val_loss: 5.9641 - val_acc: 0.2114 - val_precision: 0.2302 - val_recall: 0.1874 - val_fmeasure: 0.2064
# Epoch 43/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 0.5943 - acc: 0.8131 - precision: 0.8740 - recall: 0.7636 - fmeasure: 0.8147 - val_loss: 6.1056 - val_acc: 0.2091 - val_precision: 0.2256 - val_recall: 0.1864 - val_fmeasure: 0.2040
# Epoch 44/50
# 67200/67200 [==============================] - 8s 119us/step - loss: 0.5804 - acc: 0.8182 - precision: 0.8769 - recall: 0.7710 - fmeasure: 0.8200 - val_loss: 6.1576 - val_acc: 0.2121 - val_precision: 0.2296 - val_recall: 0.1914 - val_fmeasure: 0.2086
# Epoch 45/50
# 67200/67200 [==============================] - 8s 121us/step - loss: 0.5666 - acc: 0.8218 - precision: 0.8791 - recall: 0.7762 - fmeasure: 0.8240 - val_loss: 6.1089 - val_acc: 0.2133 - val_precision: 0.2309 - val_recall: 0.1918 - val_fmeasure: 0.2094
# Epoch 46/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 0.5519 - acc: 0.8270 - precision: 0.8807 - recall: 0.7833 - fmeasure: 0.8287 - val_loss: 6.0546 - val_acc: 0.2102 - val_precision: 0.2280 - val_recall: 0.1874 - val_fmeasure: 0.2055
# Epoch 47/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 0.5421 - acc: 0.8308 - precision: 0.8840 - recall: 0.7872 - fmeasure: 0.8324 - val_loss: 6.1932 - val_acc: 0.2119 - val_precision: 0.2286 - val_recall: 0.1898 - val_fmeasure: 0.2073
# Epoch 48/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 0.5327 - acc: 0.8339 - precision: 0.8853 - recall: 0.7928 - fmeasure: 0.8361 - val_loss: 6.3032 - val_acc: 0.2077 - val_precision: 0.2240 - val_recall: 0.1874 - val_fmeasure: 0.2039
# Epoch 49/50
# 67200/67200 [==============================] - 8s 119us/step - loss: 0.5235 - acc: 0.8374 - precision: 0.8862 - recall: 0.7963 - fmeasure: 0.8384 - val_loss: 6.3276 - val_acc: 0.2073 - val_precision: 0.2231 - val_recall: 0.1879 - val_fmeasure: 0.2039
# Epoch 50/50
# 67200/67200 [==============================] - 8s 120us/step - loss: 0.5175 - acc: 0.8368 - precision: 0.8854 - recall: 0.7983 - fmeasure: 0.8392 - val_loss: 6.3620 - val_acc: 0.2073 - val_precision: 0.2218 - val_recall: 0.1878 - val_fmeasure: 0.2033

# %%
#CNN               ############# test for noise adding  , function :: creat_data############
import gc

BATCH_SIZE = 64
NB_EPOCHS = 50
VALIDATION_SPLIT = 0.3

OPTIMIZER = Adamax()

historys_DNN = []
NB_tech = [4,4,4,4]

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

del X
del y
del X_1
del y_1
gc.collect()
print('Pad sequences to ',maxlen)
print('ready for 4')
#X_4,y_4 = random_launch(X_train,y_train,NB_tech[0])
#X_4 = sequence.pad_sequences(X_4, maxlen=maxlen,padding='post',truncating='post')
X_4 = X_4[:,:,np.newaxis]
#y_4 = np_utils.to_categorical(y_4, NB_CLASSES)
#X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

'''
print('ready for 3')
X_3,y_3 = random_launch(X_train,y_train,NB_tech[1])
X_3 = sequence.pad_sequences(X_3, maxlen=maxlen,padding='post',truncating='post')
X_3 = X_3[:,:,np.newaxis]
y_3 = np_utils.to_categorical(y_3, NB_CLASSES)
print('ready for 2')
X_2,y_2 = random_launch(X_train,y_train,NB_tech[2])
X_2 = sequence.pad_sequences(X_2, maxlen=maxlen,padding='post',truncating='post')
X_2 = X_2[:,:,np.newaxis]
y_2 = np_utils.to_categorical(y_2, NB_CLASSES)
print('ready for 1')
X_1,y_1 = random_launch(X_train,y_train,NB_tech[3])
X_1 = sequence.pad_sequences(X_1, maxlen=maxlen,padding='post',truncating='post')
X_1 = X_1[:,:,np.newaxis]
y_1 = np_utils.to_categorical(y_1, NB_CLASSES)

'''
X_train = sequence.pad_sequences(X_train, maxlen=maxlen,padding='post',truncating='post')
X_train = X_train[:,:,np.newaxis]
y_train = np_utils.to_categorical(y_train, NB_CLASSES)
X_test = sequence.pad_sequences(X_test, maxlen=maxlen,padding='post',truncating='post')
X_test = X_test[:,:,np.newaxis]

y_test = np_utils.to_categorical(y_test, NB_CLASSES)

print('the shape of x_train',X_train.shape)
print('the shape of y_train',y_train.shape)
print('the shape of x_test',X_test.shape)
print('the shape of y_test',y_test.shape)
model_CNN = CNN(maxlen,NB_CLASSES)
model_CNN.summary()
model_CNN.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])




history_CNN_loss = []
history_CNN_acc = []
history_CNN_precision = []
history_CNN_recall = []
history_CNN_fmeasure = []
history_CNN_val_loss = []
history_CNN_val_acc = []
history_CNN_val_precision = []
history_CNN_val_recall = []
history_CNN_val_fmeasure = []

def recorder_CNN(history):
    history_CNN_loss.append(history.history['loss'][0])
    history_CNN_acc.append(history.history['acc'][0])
    history_CNN_precision.append(history.history['precision'][0])
    history_CNN_recall.append(history.history['recall'][0])
    history_CNN_fmeasure.append(history.history['fmeasure'][0])
    history_CNN_val_loss.append(history.history['val_loss'][0])
    history_CNN_val_acc.append(history.history['val_acc'][0])
    history_CNN_val_precision.append(history.history['val_precision'][0])
    history_CNN_val_recall.append(history.history['val_recall'][0])
    history_CNN_val_fmeasure.append(history.history['val_fmeasure'][0])


for i in range(NB_EPOCHS):
    if (i<=NB_EPOCHS/5):
        history = model_CNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)
    elif (NB_EPOCHS/5<i and i%2==1 and i<(NB_EPOCHS*4/5)):
        history = model_CNN.fit(X_4,y_4,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)
    elif (NB_EPOCHS/5<i and i%2==0 and i<(NB_EPOCHS*4/5)):
        history = model_CNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)
    else:
        history = model_CNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)

print('base_line_now')
model_CNN_org = CNN(maxlen,NB_CLASSES)
model_CNN_org.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])
history_CNN_org = model_CNN_org.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=50,validation_data=(X_test,y_test),verbose=1)
# Out:
# Pad sequences to  5000
# ready for 4
# the shape of x_train (67200, 5000, 1)
# the shape of y_train (67200, 96)
# the shape of x_test (28800, 5000, 1)
# the shape of y_test (28800, 96)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv1D)        (None, 5000, 32)          288
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 5000, 32)          128
# _________________________________________________________________
# block1_adv_act1 (ELU)        (None, 5000, 32)          0
# _________________________________________________________________
# block1_conv2 (Conv1D)        (None, 5000, 32)          8224
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 5000, 32)          128
# _________________________________________________________________
# block1_adv_act2 (ELU)        (None, 5000, 32)          0
# _________________________________________________________________
# block1_pool (MaxPooling1D)   (None, 1250, 32)          0
# _________________________________________________________________
# block1_dropout (Dropout)     (None, 1250, 32)          0
# _________________________________________________________________
# block2_conv1 (Conv1D)        (None, 1250, 64)          16448
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1250, 64)          256
# _________________________________________________________________
# block2_act1 (Activation)     (None, 1250, 64)          0
# _________________________________________________________________
# block2_conv2 (Conv1D)        (None, 1250, 64)          32832
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1250, 64)          256
# _________________________________________________________________
# block2_act2 (Activation)     (None, 1250, 64)          0
# _________________________________________________________________
# block2_pool (MaxPooling1D)   (None, 313, 64)           0
# _________________________________________________________________
# block2_dropout (Dropout)     (None, 313, 64)           0
# _________________________________________________________________
# block3_conv1 (Conv1D)        (None, 313, 128)          65664
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 313, 128)          512
# _________________________________________________________________
# block3_act1 (Activation)     (None, 313, 128)          0
# _________________________________________________________________
# block3_conv2 (Conv1D)        (None, 313, 128)          131200
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 313, 128)          512
# _________________________________________________________________
# block3_act2 (Activation)     (None, 313, 128)          0
# _________________________________________________________________
# block3_pool (MaxPooling1D)   (None, 79, 128)           0
# _________________________________________________________________
# block3_dropout (Dropout)     (None, 79, 128)           0
# _________________________________________________________________
# block4_conv1 (Conv1D)        (None, 79, 256)           262400
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 79, 256)           1024
# _________________________________________________________________
# block4_act1 (Activation)     (None, 79, 256)           0
# _________________________________________________________________
# block4_conv2 (Conv1D)        (None, 79, 256)           524544
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 79, 256)           1024
# _________________________________________________________________
# block4_act2 (Activation)     (None, 79, 256)           0
# _________________________________________________________________
# block4_pool (MaxPooling1D)   (None, 20, 256)           0
# _________________________________________________________________
# block4_dropout (Dropout)     (None, 20, 256)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 5120)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 512)               2621952
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 512)               2048
# _________________________________________________________________
# fc1_act (Activation)         (None, 512)               0
# _________________________________________________________________
# fc1_dropout (Dropout)        (None, 512)               0
# _________________________________________________________________
# fc2 (Dense)                  (None, 512)               262656
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# fc2_act (Activation)         (None, 512)               0
# _________________________________________________________________
# fc2_dropout (Dropout)        (None, 512)               0
# _________________________________________________________________
# fc3 (Dense)                  (None, 96)                49248
# _________________________________________________________________
# softmax (Activation)         (None, 96)                0
# =================================================================
# Total params: 3,983,392
# Trainable params: 3,979,424
# Non-trainable params: 3,968
# _________________________________________________________________
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 74s 1ms/step - loss: 3.0458 - acc: 0.2360 - precision: 0.4341 - recall: 0.0451 - fmeasure: 0.0805 - val_loss: 2.0464 - val_acc: 0.4203 - val_precision: 0.7949 - val_recall: 0.1675 - val_fmeasure: 0.2742
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 986us/step - loss: 2.0247 - acc: 0.4200 - precision: 0.6805 - recall: 0.1893 - fmeasure: 0.2920 - val_loss: 1.5252 - val_acc: 0.5558 - val_precision: 0.7564 - val_recall: 0.3849 - val_fmeasure: 0.5086
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 984us/step - loss: 1.6026 - acc: 0.5365 - precision: 0.7439 - recall: 0.3428 - fmeasure: 0.4670 - val_loss: 1.1878 - val_acc: 0.6558 - val_precision: 0.8314 - val_recall: 0.4915 - val_fmeasure: 0.6165
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 984us/step - loss: 1.3425 - acc: 0.6109 - precision: 0.7752 - recall: 0.4504 - fmeasure: 0.5682 - val_loss: 1.0621 - val_acc: 0.6961 - val_precision: 0.8237 - val_recall: 0.5882 - val_fmeasure: 0.6854
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 984us/step - loss: 1.1767 - acc: 0.6588 - precision: 0.8010 - recall: 0.5274 - fmeasure: 0.6348 - val_loss: 0.9611 - val_acc: 0.7189 - val_precision: 0.8466 - val_recall: 0.6077 - val_fmeasure: 0.7066
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 984us/step - loss: 1.0580 - acc: 0.6958 - precision: 0.8196 - recall: 0.5818 - fmeasure: 0.6796 - val_loss: 0.8057 - val_acc: 0.7713 - val_precision: 0.8784 - val_recall: 0.6770 - val_fmeasure: 0.7639
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 986us/step - loss: 0.9669 - acc: 0.7204 - precision: 0.8331 - recall: 0.6209 - fmeasure: 0.7106 - val_loss: 0.7224 - val_acc: 0.7918 - val_precision: 0.8934 - val_recall: 0.7076 - val_fmeasure: 0.7889
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 985us/step - loss: 0.8951 - acc: 0.7406 - precision: 0.8448 - recall: 0.6525 - fmeasure: 0.7355 - val_loss: 0.7397 - val_acc: 0.7876 - val_precision: 0.8943 - val_recall: 0.6973 - val_fmeasure: 0.7828
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 986us/step - loss: 0.8342 - acc: 0.7584 - precision: 0.8525 - recall: 0.6748 - fmeasure: 0.7526 - val_loss: 0.6722 - val_acc: 0.8090 - val_precision: 0.9010 - val_recall: 0.7211 - val_fmeasure: 0.8004
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 985us/step - loss: 0.7820 - acc: 0.7739 - precision: 0.8621 - recall: 0.6995 - fmeasure: 0.7717 - val_loss: 0.6945 - val_acc: 0.8004 - val_precision: 0.8977 - val_recall: 0.7162 - val_fmeasure: 0.7960
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 983us/step - loss: 0.7363 - acc: 0.7867 - precision: 0.8680 - recall: 0.7160 - fmeasure: 0.7841 - val_loss: 0.6352 - val_acc: 0.8167 - val_precision: 0.9008 - val_recall: 0.7459 - val_fmeasure: 0.8155
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 160s 913us/step - loss: 1.3905 - acc: 0.6425 - precision: 0.8075 - recall: 0.5306 - fmeasure: 0.6393 - val_loss: 0.7471 - val_acc: 0.7934 - val_precision: 0.9168 - val_recall: 0.6948 - val_fmeasure: 0.7896
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 984us/step - loss: 0.7016 - acc: 0.8005 - precision: 0.8886 - recall: 0.7187 - fmeasure: 0.7939 - val_loss: 0.5697 - val_acc: 0.8385 - val_precision: 0.9153 - val_recall: 0.7760 - val_fmeasure: 0.8393
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 160s 913us/step - loss: 1.2048 - acc: 0.6842 - precision: 0.8356 - recall: 0.5802 - fmeasure: 0.6839 - val_loss: 0.7004 - val_acc: 0.7998 - val_precision: 0.9105 - val_recall: 0.7151 - val_fmeasure: 0.8003
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 983us/step - loss: 0.6447 - acc: 0.8148 - precision: 0.8953 - recall: 0.7451 - fmeasure: 0.8126 - val_loss: 0.5140 - val_acc: 0.8514 - val_precision: 0.9136 - val_recall: 0.8031 - val_fmeasure: 0.8543
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 159s 912us/step - loss: 1.0920 - acc: 0.7116 - precision: 0.8496 - recall: 0.6164 - fmeasure: 0.7135 - val_loss: 0.6458 - val_acc: 0.8228 - val_precision: 0.9298 - val_recall: 0.7347 - val_fmeasure: 0.8200
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 985us/step - loss: 0.5873 - acc: 0.8327 - precision: 0.9030 - recall: 0.7692 - fmeasure: 0.8302 - val_loss: 0.4692 - val_acc: 0.8667 - val_precision: 0.9273 - val_recall: 0.8178 - val_fmeasure: 0.8687
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 159s 912us/step - loss: 1.0187 - acc: 0.7280 - precision: 0.8576 - recall: 0.6420 - fmeasure: 0.7334 - val_loss: 0.5889 - val_acc: 0.8347 - val_precision: 0.9307 - val_recall: 0.7545 - val_fmeasure: 0.8327
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 984us/step - loss: 0.5471 - acc: 0.8444 - precision: 0.9090 - recall: 0.7851 - fmeasure: 0.8419 - val_loss: 0.4418 - val_acc: 0.8733 - val_precision: 0.9333 - val_recall: 0.8262 - val_fmeasure: 0.8760
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 160s 915us/step - loss: 0.9489 - acc: 0.7464 - precision: 0.8669 - recall: 0.6660 - fmeasure: 0.7525 - val_loss: 0.5909 - val_acc: 0.8323 - val_precision: 0.9250 - val_recall: 0.7612 - val_fmeasure: 0.8345
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 986us/step - loss: 0.5100 - acc: 0.8534 - precision: 0.9131 - recall: 0.8012 - fmeasure: 0.8530 - val_loss: 0.4406 - val_acc: 0.8717 - val_precision: 0.9248 - val_recall: 0.8308 - val_fmeasure: 0.8749
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 160s 916us/step - loss: 0.8954 - acc: 0.7596 - precision: 0.8722 - recall: 0.6834 - fmeasure: 0.7656 - val_loss: 0.5179 - val_acc: 0.8582 - val_precision: 0.9409 - val_recall: 0.7897 - val_fmeasure: 0.8581
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 984us/step - loss: 0.4857 - acc: 0.8604 - precision: 0.9166 - recall: 0.8126 - fmeasure: 0.8610 - val_loss: 0.3911 - val_acc: 0.8904 - val_precision: 0.9416 - val_recall: 0.8491 - val_fmeasure: 0.8926
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 159s 911us/step - loss: 0.8492 - acc: 0.7704 - precision: 0.8769 - recall: 0.6990 - fmeasure: 0.7772 - val_loss: 0.5252 - val_acc: 0.8494 - val_precision: 0.9276 - val_recall: 0.7894 - val_fmeasure: 0.8524
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 985us/step - loss: 0.4520 - acc: 0.8696 - precision: 0.9217 - recall: 0.8256 - fmeasure: 0.8705 - val_loss: 0.3765 - val_acc: 0.8912 - val_precision: 0.9391 - val_recall: 0.8562 - val_fmeasure: 0.8954
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 159s 910us/step - loss: 0.8076 - acc: 0.7805 - precision: 0.8818 - recall: 0.7127 - fmeasure: 0.7876 - val_loss: 0.4101 - val_acc: 0.8842 - val_precision: 0.9442 - val_recall: 0.8383 - val_fmeasure: 0.8877
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 981us/step - loss: 0.4331 - acc: 0.8753 - precision: 0.9234 - recall: 0.8354 - fmeasure: 0.8768 - val_loss: 0.3383 - val_acc: 0.9050 - val_precision: 0.9387 - val_recall: 0.8818 - val_fmeasure: 0.9091
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 159s 911us/step - loss: 0.7750 - acc: 0.7898 - precision: 0.8854 - recall: 0.7248 - fmeasure: 0.7965 - val_loss: 0.4318 - val_acc: 0.8819 - val_precision: 0.9429 - val_recall: 0.8310 - val_fmeasure: 0.8830
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 66s 981us/step - loss: 0.4115 - acc: 0.8811 - precision: 0.9270 - recall: 0.8418 - fmeasure: 0.8820 - val_loss: 0.3541 - val_acc: 0.9015 - val_precision: 0.9451 - val_recall: 0.8667 - val_fmeasure: 0.9039
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 159s 910us/step - loss: 0.7392 - acc: 0.7978 - precision: 0.8901 - recall: 0.7371 - fmeasure: 0.8058 - val_loss: 0.3948 - val_acc: 0.8920 - val_precision: 0.9461 - val_recall: 0.8478 - val_fmeasure: 0.8938
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 35904/67200 [===============>..............] - ETA: 27s - loss: 0.3945 - acc: 0.8855 - precision: 0.9313 - recall: 0.8456 - fmeasure: 0.8860Buffered data was truncated after reaching the output size limit.

# %%
import matplotlib.pylab as plt


fig,axs = plt.subplots(1,5,figsize=(30,10))
axs[0].plot(range(NB_EPOCHS),history_DNN_org.history['val_loss'],label='before')
axs[0].plot(range(NB_EPOCHS),history_DNN_val_loss,label='after')
axs[0].set_title('val_loss')

axs[1].plot(range(NB_EPOCHS),history_DNN_org.history['val_acc'],label='before')
axs[1].plot(range(NB_EPOCHS),history_DNN_val_acc,label='after')
axs[1].set_title('val_acc')

axs[2].plot(range(NB_EPOCHS),history_DNN_org.history['val_precision'],label='before')
axs[2].plot(range(NB_EPOCHS),history_DNN_val_precision,label='after')
axs[2].set_title('val_precision')

axs[3].plot(range(NB_EPOCHS),history_DNN_org.history['val_recall'],label='before')
axs[3].plot(range(NB_EPOCHS),history_DNN_val_recall,label='after')
axs[3].set_title('val_recall')

axs[4].plot(range(NB_EPOCHS),history_DNN_org.history['val_fmeasure'],label='before')
axs[4].plot(range(NB_EPOCHS),history_DNN_val_fmeasure,label='after')
axs[4].set_title('val_fmeasure')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center')

plt.show()

# %%
import matplotlib.pylab as plt


fig,axs = plt.subplots(1,5,figsize=(30,10))
axs[0].plot(range(NB_EPOCHS),history_CNN_org.history['val_loss'],label='before')
axs[0].plot(range(NB_EPOCHS),history_CNN_val_loss,label='after')
axs[0].set_title('val_loss')

axs[1].plot(range(NB_EPOCHS),history_CNN_org.history['val_acc'],label='before')
axs[1].plot(range(NB_EPOCHS),history_CNN_val_acc,label='after')
axs[1].set_title('val_acc')

axs[2].plot(range(NB_EPOCHS),history_CNN_org.history['val_precision'],label='before')
axs[2].plot(range(NB_EPOCHS),history_CNN_val_precision,label='after')
axs[2].set_title('val_precision')

axs[3].plot(range(NB_EPOCHS),history_CNN_org.history['val_recall'],label='before')
axs[3].plot(range(NB_EPOCHS),history_CNN_val_recall,label='after')
axs[3].set_title('val_recall')

axs[4].plot(range(NB_EPOCHS),history_CNN_org.history['val_fmeasure'],label='before')
axs[4].plot(range(NB_EPOCHS),history_CNN_val_fmeasure,label='after')
axs[4].set_title('val_fmeasure')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center')

plt.show()
