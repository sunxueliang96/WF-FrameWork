# %% [markdown]
# <a href="https://colab.research.google.com/github/sunxueliang96/WF-FrameWork/blob/master/Data%20Augmented/multiple_technologies/analysis%26result_WTFPAD_Open_World_Def.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/'My Drive'/deep_firger/dataset/OpenWorld/WTFPAD
# Out:
# /content/drive/My Drive/deep_firger/dataset/OpenWorld/WTFPAD

# %%
datatype_Close = False   #Flase is Open_World, True is Closed World.

# %%
#cd /content/drive/'My Drive'/datasets/no_paded/close_world/walkiebatch

# %%
#datatype_Close = True   #Flase is Open_World, True is Closed World.

# %%
ls
# Out:
# X_test_Mon_WTFPAD.pkl    X_valid_WTFPAD.pkl       y_train_WTFPAD.pkl
# X_test_Unmon_WTFPAD.pkl  y_test_Mon_WTFPAD.pkl    y_valid_WTFPAD.pkl
# X_train_WTFPAD.pkl       y_test_Unmon_WTFPAD.pkl

# %%
import numpy as np
import pickle

print('loading data...')
with open('X_train_WTFPAD.pkl','rb') as handle:
    X_1 = np.array(pickle.load(handle,encoding='iso-8859-1'))
with open('y_train_WTFPAD.pkl','rb') as handle:
    y_1 = np.array(pickle.load(handle,encoding='iso-8859-1'))
    '''
with open('y_train_WTFPAD.pkl','rb') as handle:
    y_1 = np.array(pickle.load(handle,encoding='iso-8859-1'))
with open('y_valid_WTFPAD.pkl','rb') as handle:
    y_2 = np.array(pickle.load(handle,encoding='iso-8859-1'))

print('the shape of X_1',X_1.shape)
print('the shape of X_2',X_2.shape)
print('the shape of y_1',y_1.shape)
print('the shape of y_2',y_2.shape)
'''
# Out:
# loading data...

# %%
X = []
y = []
X.extend(X_1)
y.extend(y_1)

# %%
#deal x and y
k=0
for seq,i in zip(X,range(len(X))):
    X[i] = list(filter(lambda x:x!=0, seq))
    if(i in list(range(0,len(X),len(X)//10))):
        print("{}0% data has been dealed".format(k),flush = True)
        k +=1
y = [-1 if x==95 else x for x in y]

print ('shape of X',np.shape(X))
print ('shape of y',np.shape(y))
# Out:
# 00% data has been dealed
# 10% data has been dealed
# 20% data has been dealed
# 30% data has been dealed
# 40% data has been dealed
# 50% data has been dealed
# 60% data has been dealed
# 70% data has been dealed
# 80% data has been dealed
# 90% data has been dealed
# shape of X (96000,)
# shape of y (96000,)

# %%
import math 
import random
def fun_noise(X,y,PERCENT_NOISE,TIMES_NOISE): 
    X = list(X)
    y = list(y)
    X_sum = []
    y_sum = []
    #X_sum = X.copy()
    #y_sum = y.copy()
    #print("{} samples has beed add to X_train, {}% of noise for each sample".format(math.ceil(len(X)*TIMES_NOISE),PERCENT_NOISE))
    k=0
    for i in range(math.ceil(len(X)*TIMES_NOISE)): #ADDING NOISE from here 
        if(i in list(range(0,math.ceil(len(X)*TIMES_NOISE),math.ceil(len(X)*TIMES_NOISE)//10))):
            print("{}0% data has been dealed".format(k),flush = True)
            k +=1
        while(True):
            p = random.choice(range(len(X)))
            if(y[p]!=-1):
                break
            else:
                pass
        X_new = X[p].copy()
        y_new = y[p]
        for n in range(math.ceil(PERCENT_NOISE*len(X_new)/100)):#dealing X_new
            noise = random.choice([1,-1])       #noise could only be 1 or -1
            pos = random.choice(range(len(X_new)))  #position belong to (0,len(sequence))
            X_new.insert(pos,noise)
            #print('insert {} at position {} in sequence {} now len of sequence is {}, the tag of sequence is {}'.format(noise,pos,p,len(X_new),y_new)) #for test
        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum
def fun_delete(X,y,PERCENT_DELETE,TIMES_DELETE): 
    X = list(X)
    y = list(y)
    X_sum = []
    y_sum = []
    #X_sum = X.copy()
    #y_sum = y.copy()
    k = 0
    for i in range(math.ceil(len(X)*TIMES_DELETE)): #RANDOM DELETE from here
        if(i in list(range(0,math.ceil(len(X)*TIMES_DELETE),math.ceil(len(X)*TIMES_DELETE)//10))):
            print("{}0% data has been dealed".format(k),flush = True)
            k +=1
        while(True):
            p = random.choice(range(len(X)))
            if(y[p]!=-1):
                break
            else:
                #print('-1 detected')
                pass
        X_new = X[p].copy()
        y_new = y[p]
        for n in range(math.ceil(PERCENT_DELETE*len(X_new)/100)):#dealing X_new
            pos = random.choice(range(len(X_new)))  #position belong to (0,len(sequence))
            del X_new[pos]
            #print('insert {} at position {} in sequence {} now len of sequence is {}'.format(noise,pos,p,len(X_new))) #for test
        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum
def fun_shuffle(X,y,PERCENT_CHANGED,TIMES_SHUFFLE): 
    X = list(X)
    y = list(y)
    #X_sum = X.copy()
    #y_sum = y.copy()
    X_sum = []
    y_sum = []
    k=0
    for i in range(math.ceil(len(X)*TIMES_SHUFFLE)):             #LOCALLY CHANGE from here
        if(i in list(range(0,math.ceil(len(X)*TIMES_SHUFFLE),math.ceil(len(X)*TIMES_SHUFFLE)//10))):
            print("{}0% data has been dealed".format(k),flush = True)
            k +=1
        while(True):
            p = random.choice(range(len(X)))
            if(y[p]!=-1):
                break
            else:
                #print('-1 detected')
                pass
        X_new = X[p].copy()
        y_new = y[p]
        length = math.ceil(PERCENT_CHANGED*len(X_new)/100)
        start = random.choice(range(len(X_new)-length))
        temp = X_new[start:start+length]
        random.shuffle(temp)
        X_new[start:start+length] = temp

        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum
def fun_transplant(X,y,PERCENT_TRANSPLANT,NB_TIMES):        #Magnificate dataset by adding noising randomly
    global datatype_Close
    X = list(X)
    y = list(y)
    X_sum = []
    y_sum = []
    #X_sum = X.copy()
    #y_sum = y.copy()
    #print("{} samples has beed add to X_train, {}% of noise for each sample".format(math.ceil(len(X)*NB_TIMES),PERCENT_TRANSPLANT))
    k=0
    print('When the process freezing, please check that datatype_Close has been set correctly')
    for i in range(math.ceil(len(X)*NB_TIMES)):
        if(i in list(range(0,math.ceil(len(X)*NB_TIMES),math.ceil(len(X)*NB_TIMES)//10))):
            print("{}0% data has been dealed".format(k),flush = True)
            k +=1
        #print(datatype_Close)    
        while(datatype_Close):                               # target pos p (sensitive website), pos q (non-sensitive website)
            p = random.choice(range(len(X)))
            q = random.choice(range(len(X)))
            if(p != q):                           # Closed_World
                break
            else:
                #print('-1 detected')
                pass
        while(not datatype_Close):                               # target pos p (sensitive website), pos q (non-sensitive website)
            p = random.choice(range(len(X)))
            q = random.choice(range(len(X)))
            if(y[p]!=-1 and y[q]==-1):               # open_world
                break
            else:
                #print('-1 detected')
                pass
        X_new = X[p].copy()
        target = X[q].copy()
        y_new = y[p]

        length_X = math.ceil(PERCENT_TRANSPLANT*len(X_new)/100)
        length_target =  math.ceil(PERCENT_TRANSPLANT*len(target)/100)
        start_X = random.choice(range(len(X_new)-length_X))
        start_target = random.choice(range(len(target)-length_target))
        temp = target[start_target:start_target+length_target]
        X_new[start_X:start_X+length_X] = temp
     
        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum

def random_launch(X,y,NB_tech):
    X = list(X)
    y = list(y)
    X_sum = X.copy()
    y_sum = y.copy()
    launch_list = random.sample(range(4),NB_tech)             #return [0,1,....]....depending on NB_tech
    for i in launch_list:
        if (i==0):
            print('adding noise...')
            X_new,y_new = fun_noise(X,y,PERCENT_NOISE=20,TIMES_NOISE=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==1):
            print('deleting...')
            X_new,y_new = fun_delete(X,y,PERCENT_DELETE=20,TIMES_DELETE=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==2):
            print('shuffling...')
            X_new,y_new = fun_shuffle(X,y,PERCENT_CHANGED=20,TIMES_SHUFFLE=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==3):
            print('transplanting...')
            X_new,y_new = fun_transplant(X,y,PERCENT_TRANSPLANT=20,NB_TIMES=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
    return np.array(X_sum),np.array(y_sum)                        #return two array of X, y

# %%
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing import sequence
from collections import Counter
#CLASSES_KNN = 101########################################################################################################################################################################################################
#CLASSES_WAKIE = 100########################################################################################################################################################################################################
MAXLEN_KNN = 2000
MAXLEN_WAKIE =5000

maxlen = 5000
NB_CLASSES = 0

def choose():
    global maxlen,NB_CLASSES
    print('if padding, the max of length of seq is {}'.format(maxlen))
    NB_CLASSES = len(Counter(y).keys())
    print('number of classes is {}'.format(NB_CLASSES))

choose()################################################################################################################################################################################################################

print('Average sequence length: {}'.format(np.mean(list(map(len, X)), dtype=int)))
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# if padding, the max of length of seq is 5000
# number of classes is 96
# Average sequence length: 2773

# %%
#FCN
from keras import Sequential
from keras.layers.core import Activation, Flatten, Dense, Dropout
from keras.optimizers import Adamax
def DNN(input_shape,classes):
    model = Sequential()
    model.add(Dense(128, input_shape=(input_shape,)))
    model.add(Activation('relu'))
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dense(512))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dense(classes))
    model.add(Activation('softmax'))
    return model

# %%
#CNN
from keras import Input,Model,Sequential
from keras.layers import Embedding,GlobalAveragePooling1D,Dense,Dropout
from keras.layers import Conv1D, MaxPooling1D, BatchNormalization
from keras.layers.core import Activation, Flatten, Dense, Dropout
from keras.layers.advanced_activations import ELU
from keras.initializers import glorot_uniform
from keras.optimizers import Adamax
def CNN(input_shape, classes):
    model = Sequential()
    #Block1
    filter_num = ['None',32,64,128,256]
    kernel_size = ['None',8,8,8,8]
    conv_stride_size = ['None',1,1,1,1]
    pool_stride_size = ['None',4,4,4,4]
    pool_size = ['None',8,8,8,8]

    model.add(Conv1D(filters=filter_num[1], kernel_size=kernel_size[1], input_shape=(input_shape,1),
                      strides=conv_stride_size[1], padding='same',
                      name='block1_conv1'))
    model.add(BatchNormalization(axis=-1))
    model.add(ELU(alpha=1.0, name='block1_adv_act1'))
    model.add(Conv1D(filters=filter_num[1], kernel_size=kernel_size[1],
                      strides=conv_stride_size[1], padding='same',
                      name='block1_conv2'))
    model.add(BatchNormalization(axis=-1))
    model.add(ELU(alpha=1.0, name='block1_adv_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[1], strides=pool_stride_size[1],
                            padding='same', name='block1_pool'))
    model.add(Dropout(0.1, name='block1_dropout'))

    model.add(Conv1D(filters=filter_num[2], kernel_size=kernel_size[2],
                      strides=conv_stride_size[2], padding='same',
                      name='block2_conv1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block2_act1'))

    model.add(Conv1D(filters=filter_num[2], kernel_size=kernel_size[2],
                      strides=conv_stride_size[2], padding='same',
                      name='block2_conv2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block2_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[2], strides=pool_stride_size[3],
                            padding='same', name='block2_pool'))
    model.add(Dropout(0.1, name='block2_dropout'))

    model.add(Conv1D(filters=filter_num[3], kernel_size=kernel_size[3],
                      strides=conv_stride_size[3], padding='same',
                      name='block3_conv1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block3_act1'))
    model.add(Conv1D(filters=filter_num[3], kernel_size=kernel_size[3],
                      strides=conv_stride_size[3], padding='same',
                      name='block3_conv2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block3_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[3], strides=pool_stride_size[3],
                            padding='same', name='block3_pool'))
    model.add(Dropout(0.1, name='block3_dropout'))

    model.add(Conv1D(filters=filter_num[4], kernel_size=kernel_size[4],
                      strides=conv_stride_size[4], padding='same',
                      name='block4_conv1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block4_act1'))
    model.add(Conv1D(filters=filter_num[4], kernel_size=kernel_size[4],
                      strides=conv_stride_size[4], padding='same',
                      name='block4_conv2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block4_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[4], strides=pool_stride_size[4],
                            padding='same', name='block4_pool'))
    model.add(Dropout(0.1, name='block4_dropout'))

    model.add(Flatten(name='flatten'))
    model.add(Dense(512, kernel_initializer=glorot_uniform(seed=0), name='fc1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='fc1_act'))

    model.add(Dropout(0.7, name='fc1_dropout'))

    model.add(Dense(512, kernel_initializer=glorot_uniform(seed=0), name='fc2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='fc2_act'))

    model.add(Dropout(0.5, name='fc2_dropout'))

    model.add(Dense(classes, kernel_initializer=glorot_uniform(seed=0), name='fc3'))
    model.add(Activation('softmax', name="softmax"))
    return model

# %%
import keras
from keras import backend as K

def precision(y_true, y_pred):
    # Calculates the precision
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    # Calculates the recall
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def fbeta_score(y_true, y_pred, beta=1):
    # Calculates the F score, the weighted harmonic mean of precision and recall.
    if beta < 0:
        raise ValueError('The lowest choosable beta is zero (only precision).')
 
    # If there are no true positives, fix the F score at 0 like sklearn.
    if K.sum(K.round(K.clip(y_true, 0, 1))) == 0:
        return 0

    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    bb = beta ** 2
    fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
    return fbeta_score

def fmeasure(y_true, y_pred):
    # Calculates the f-measure, the harmonic mean of precision and recall.
    return fbeta_score(y_true, y_pred, beta=1)

# %%
#DNN               ############# test for noise adding  , function :: creat_data############

BATCH_SIZE = 64
NB_EPOCHS = 50
VALIDATION_SPLIT = 0.3

OPTIMIZER = Adamax()

historys_DNN = []
NB_tech = [4,4,4,4]

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)


print('Pad sequences to ',maxlen)
print('ready for 4')
X_4,y_4 = random_launch(X_train,y_train,NB_tech[0])
X_4 = sequence.pad_sequences(X_4, maxlen=maxlen,padding='post',truncating='post')
y_4 = np_utils.to_categorical(y_4, NB_CLASSES)
'''
print('ready for 3')
X_3,y_3 = random_launch(X_train,y_train,NB_tech[1])
X_3 = sequence.pad_sequences(X_3, maxlen=maxlen,padding='post',truncating='post')
X_3 = X_3[:,:,np.newaxis]
y_3 = np_utils.to_categorical(y_3, NB_CLASSES)
print('ready for 2')
X_2,y_2 = random_launch(X_train,y_train,NB_tech[2])
X_2 = sequence.pad_sequences(X_2, maxlen=maxlen,padding='post',truncating='post')
X_2 = X_2[:,:,np.newaxis]
y_2 = np_utils.to_categorical(y_2, NB_CLASSES)
print('ready for 1')
X_1,y_1 = random_launch(X_train,y_train,NB_tech[3])
X_1 = sequence.pad_sequences(X_1, maxlen=maxlen,padding='post',truncating='post')
X_1 = X_1[:,:,np.newaxis]
y_1 = np_utils.to_categorical(y_1, NB_CLASSES)

'''
X_train = sequence.pad_sequences(X_train, maxlen=maxlen,padding='post',truncating='post')
y_train = np_utils.to_categorical(y_train, NB_CLASSES)
X_test = sequence.pad_sequences(X_test, maxlen=maxlen,padding='post',truncating='post')
y_test = np_utils.to_categorical(y_test, NB_CLASSES)

print('the shape of x_train',X_train.shape)
print('the shape of y_train',y_train.shape)
print('the shape of x_test',X_test.shape)
print('the shape of y_test',y_test.shape)

model_DNN = DNN(maxlen,NB_CLASSES)
model_DNN.summary()
model_DNN.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])


history_DNN_loss = []
history_DNN_acc = []
history_DNN_precision = []
history_DNN_recall = []
history_DNN_fmeasure = []
history_DNN_val_loss = []
history_DNN_val_acc = []
history_DNN_val_precision = []
history_DNN_val_recall = []
history_DNN_val_fmeasure = []

def recorder_DNN(history):
    history_DNN_loss.append(history.history['loss'][0])
    history_DNN_acc.append(history.history['acc'][0])
    history_DNN_precision.append(history.history['precision'][0])
    history_DNN_recall.append(history.history['recall'][0])
    history_DNN_fmeasure.append(history.history['fmeasure'][0])
    history_DNN_val_loss.append(history.history['val_loss'][0])
    history_DNN_val_acc.append(history.history['val_acc'][0])
    history_DNN_val_precision.append(history.history['val_precision'][0])
    history_DNN_val_recall.append(history.history['val_recall'][0])
    history_DNN_val_fmeasure.append(history.history['val_fmeasure'][0])


for i in range(NB_EPOCHS):
    if (i<=NB_EPOCHS/5):
        history = model_DNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)
    elif (NB_EPOCHS/5<i and i%2==1 and i<(NB_EPOCHS*4/5)):
        history = model_DNN.fit(X_4,y_4,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)
    elif (NB_EPOCHS/5<i and i%2==0 and i<(NB_EPOCHS*4/5)):
        history = model_DNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)
    else:
        history = model_DNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)

print('base_line_now#######################################################################################################################################################################################################')
model_DNN_org = DNN(maxlen,NB_CLASSES)
model_DNN_org.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])
history_DNN_org = model_DNN_org.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=50,validation_data=(X_test,y_test),verbose=1)
# Out:
# Pad sequences to  5000
# ready for 4
# deleting...
# transplanting...
# adding noise...
# shuffling...
# the shape of x_train (67200, 5000)
# the shape of y_train (67200, 96)
# the shape of x_test (28800, 5000)
# the shape of y_test (28800, 96)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               640128
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               131584
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# activation_4 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 96)                49248
# _________________________________________________________________
# activation_6 (Activation)    (None, 96)                0
# =================================================================
# Total params: 1,904,096
# Trainable params: 1,904,096
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 67200/67200 [==============================] - 21s 310us/step - loss: 3.5007 - acc: 0.2000 - precision: 0.2840 - recall: 0.0109 - fmeasure: 0.0207 - val_loss: 3.0190 - val_acc: 0.2218 - val_precision: 0.1589 - val_recall: 0.0028 - val_fmeasure: 0.0055
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 178us/step - loss: 2.9747 - acc: 0.2153 - precision: 0.4593 - recall: 0.0200 - fmeasure: 0.0379 - val_loss: 2.8158 - val_acc: 0.2375 - val_precision: 0.3185 - val_recall: 0.0068 - val_fmeasure: 0.0133
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 178us/step - loss: 2.7099 - acc: 0.2469 - precision: 0.5736 - recall: 0.0373 - fmeasure: 0.0692 - val_loss: 2.7255 - val_acc: 0.2588 - val_precision: 0.5407 - val_recall: 0.0209 - val_fmeasure: 0.0399
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 176us/step - loss: 2.5097 - acc: 0.2770 - precision: 0.6088 - recall: 0.0599 - fmeasure: 0.1076 - val_loss: 2.7162 - val_acc: 0.2624 - val_precision: 0.5297 - val_recall: 0.0333 - val_fmeasure: 0.0620
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 177us/step - loss: 2.3424 - acc: 0.3106 - precision: 0.6419 - recall: 0.0865 - fmeasure: 0.1506 - val_loss: 2.7477 - val_acc: 0.2637 - val_precision: 0.4868 - val_recall: 0.0436 - val_fmeasure: 0.0790
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 175us/step - loss: 2.2003 - acc: 0.3413 - precision: 0.6609 - recall: 0.1163 - fmeasure: 0.1957 - val_loss: 2.7605 - val_acc: 0.2658 - val_precision: 0.4781 - val_recall: 0.0512 - val_fmeasure: 0.0915
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 179us/step - loss: 2.0767 - acc: 0.3697 - precision: 0.6696 - recall: 0.1464 - fmeasure: 0.2382 - val_loss: 2.8473 - val_acc: 0.2628 - val_precision: 0.4278 - val_recall: 0.0633 - val_fmeasure: 0.1092
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 178us/step - loss: 1.9675 - acc: 0.3966 - precision: 0.6752 - recall: 0.1735 - fmeasure: 0.2739 - val_loss: 2.9023 - val_acc: 0.2622 - val_precision: 0.4215 - val_recall: 0.0758 - val_fmeasure: 0.1272
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 176us/step - loss: 1.8693 - acc: 0.4221 - precision: 0.6846 - recall: 0.2044 - fmeasure: 0.3127 - val_loss: 3.0378 - val_acc: 0.2569 - val_precision: 0.3729 - val_recall: 0.0920 - val_fmeasure: 0.1466
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 176us/step - loss: 1.7734 - acc: 0.4464 - precision: 0.6980 - recall: 0.2375 - fmeasure: 0.3521 - val_loss: 3.1283 - val_acc: 0.2505 - val_precision: 0.3597 - val_recall: 0.0997 - val_fmeasure: 0.1550
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 174us/step - loss: 1.6942 - acc: 0.4681 - precision: 0.7055 - recall: 0.2678 - fmeasure: 0.3862 - val_loss: 3.2642 - val_acc: 0.2499 - val_precision: 0.3427 - val_recall: 0.1068 - val_fmeasure: 0.1618
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 28s 162us/step - loss: 2.8160 - acc: 0.2829 - precision: 0.6531 - recall: 0.0674 - fmeasure: 0.1206 - val_loss: 2.7499 - val_acc: 0.2378 - val_precision: 0.5233 - val_recall: 0.0468 - val_fmeasure: 0.0849
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 175us/step - loss: 1.7251 - acc: 0.4687 - precision: 0.7057 - recall: 0.2641 - fmeasure: 0.3818 - val_loss: 3.0195 - val_acc: 0.2561 - val_precision: 0.3634 - val_recall: 0.1089 - val_fmeasure: 0.1666
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 28s 161us/step - loss: 2.6037 - acc: 0.3207 - precision: 0.6736 - recall: 0.1064 - fmeasure: 0.1818 - val_loss: 2.7826 - val_acc: 0.2381 - val_precision: 0.4584 - val_recall: 0.0590 - val_fmeasure: 0.1035
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 175us/step - loss: 1.6246 - acc: 0.4974 - precision: 0.7185 - recall: 0.3068 - fmeasure: 0.4278 - val_loss: 3.0834 - val_acc: 0.2602 - val_precision: 0.3522 - val_recall: 0.1248 - val_fmeasure: 0.1833
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 28s 160us/step - loss: 2.4541 - acc: 0.3529 - precision: 0.6855 - recall: 0.1410 - fmeasure: 0.2317 - val_loss: 2.8092 - val_acc: 0.2411 - val_precision: 0.4474 - val_recall: 0.0667 - val_fmeasure: 0.1150
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 175us/step - loss: 1.5283 - acc: 0.5265 - precision: 0.7329 - recall: 0.3463 - fmeasure: 0.4678 - val_loss: 3.1238 - val_acc: 0.2523 - val_precision: 0.3475 - val_recall: 0.1198 - val_fmeasure: 0.1772
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 28s 161us/step - loss: 2.3414 - acc: 0.3807 - precision: 0.6969 - recall: 0.1720 - fmeasure: 0.2736 - val_loss: 2.8459 - val_acc: 0.2331 - val_precision: 0.4187 - val_recall: 0.0775 - val_fmeasure: 0.1296
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 173us/step - loss: 1.4482 - acc: 0.5511 - precision: 0.7476 - recall: 0.3828 - fmeasure: 0.5043 - val_loss: 3.2409 - val_acc: 0.2572 - val_precision: 0.3405 - val_recall: 0.1446 - val_fmeasure: 0.2020
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 28s 160us/step - loss: 2.2416 - acc: 0.4033 - precision: 0.7075 - recall: 0.2013 - fmeasure: 0.3110 - val_loss: 2.9178 - val_acc: 0.2377 - val_precision: 0.3881 - val_recall: 0.0890 - val_fmeasure: 0.1437
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 174us/step - loss: 1.3591 - acc: 0.5768 - precision: 0.7587 - recall: 0.4219 - fmeasure: 0.5404 - val_loss: 3.2976 - val_acc: 0.2570 - val_precision: 0.3369 - val_recall: 0.1463 - val_fmeasure: 0.2031
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 28s 160us/step - loss: 2.1506 - acc: 0.4268 - precision: 0.7186 - recall: 0.2282 - fmeasure: 0.3440 - val_loss: 2.9960 - val_acc: 0.2315 - val_precision: 0.3704 - val_recall: 0.0945 - val_fmeasure: 0.1495
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 173us/step - loss: 1.2913 - acc: 0.5966 - precision: 0.7680 - recall: 0.4519 - fmeasure: 0.5672 - val_loss: 3.4120 - val_acc: 0.2471 - val_precision: 0.3149 - val_recall: 0.1482 - val_fmeasure: 0.2007
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 28s 160us/step - loss: 2.0726 - acc: 0.4461 - precision: 0.7294 - recall: 0.2552 - fmeasure: 0.3759 - val_loss: 3.0506 - val_acc: 0.2338 - val_precision: 0.3609 - val_recall: 0.0988 - val_fmeasure: 0.1540
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 11s 170us/step - loss: 1.2303 - acc: 0.6162 - precision: 0.7783 - recall: 0.4790 - fmeasure: 0.5913 - val_loss: 3.4821 - val_acc: 0.2488 - val_precision: 0.3093 - val_recall: 0.1535 - val_fmeasure: 0.2045
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 28s 158us/step - loss: 2.0065 - acc: 0.4633 - precision: 0.7339 - recall: 0.2771 - fmeasure: 0.3999 - val_loss: 3.1510 - val_acc: 0.2261 - val_precision: 0.3326 - val_recall: 0.1033 - val_fmeasure: 0.1567
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 11s 170us/step - loss: 1.1769 - acc: 0.6338 - precision: 0.7885 - recall: 0.5055 - fmeasure: 0.6146 - val_loss: 3.6383 - val_acc: 0.2439 - val_precision: 0.2973 - val_recall: 0.1593 - val_fmeasure: 0.2069
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 28s 159us/step - loss: 1.9426 - acc: 0.4797 - precision: 0.7447 - recall: 0.2997 - fmeasure: 0.4252 - val_loss: 3.2129 - val_acc: 0.2257 - val_precision: 0.3294 - val_recall: 0.1140 - val_fmeasure: 0.1685
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 172us/step - loss: 1.1322 - acc: 0.6489 - precision: 0.7979 - recall: 0.5249 - fmeasure: 0.6318 - val_loss: 3.7175 - val_acc: 0.2482 - val_precision: 0.3038 - val_recall: 0.1677 - val_fmeasure: 0.2155
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 28s 160us/step - loss: 1.8945 - acc: 0.4922 - precision: 0.7507 - recall: 0.3175 - fmeasure: 0.4441 - val_loss: 3.2767 - val_acc: 0.2215 - val_precision: 0.3210 - val_recall: 0.1106 - val_fmeasure: 0.1637
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 173us/step - loss: 1.0838 - acc: 0.6608 - precision: 0.8040 - recall: 0.5443 - fmeasure: 0.6476 - val_loss: 3.8553 - val_acc: 0.2439 - val_precision: 0.2933 - val_recall: 0.1714 - val_fmeasure: 0.2159
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 28s 160us/step - loss: 1.8426 - acc: 0.5052 - precision: 0.7542 - recall: 0.3356 - fmeasure: 0.4624 - val_loss: 3.2984 - val_acc: 0.2244 - val_precision: 0.3178 - val_recall: 0.1125 - val_fmeasure: 0.1654
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 173us/step - loss: 1.0461 - acc: 0.6753 - precision: 0.8100 - recall: 0.5635 - fmeasure: 0.6633 - val_loss: 3.9464 - val_acc: 0.2396 - val_precision: 0.2892 - val_recall: 0.1708 - val_fmeasure: 0.2142
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 28s 161us/step - loss: 1.8009 - acc: 0.5193 - precision: 0.7637 - recall: 0.3508 - fmeasure: 0.4786 - val_loss: 3.3583 - val_acc: 0.2215 - val_precision: 0.3121 - val_recall: 0.1155 - val_fmeasure: 0.1677
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 11s 171us/step - loss: 1.0061 - acc: 0.6895 - precision: 0.8200 - recall: 0.5851 - fmeasure: 0.6816 - val_loss: 3.9226 - val_acc: 0.2430 - val_precision: 0.2889 - val_recall: 0.1709 - val_fmeasure: 0.2142
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 28s 160us/step - loss: 1.7544 - acc: 0.5286 - precision: 0.7659 - recall: 0.3658 - fmeasure: 0.4931 - val_loss: 3.5027 - val_acc: 0.2140 - val_precision: 0.2968 - val_recall: 0.1174 - val_fmeasure: 0.1674
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 11s 171us/step - loss: 0.9742 - acc: 0.6983 - precision: 0.8210 - recall: 0.5971 - fmeasure: 0.6901 - val_loss: 4.0047 - val_acc: 0.2377 - val_precision: 0.2804 - val_recall: 0.1681 - val_fmeasure: 0.2096
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 27s 157us/step - loss: 1.7185 - acc: 0.5393 - precision: 0.7710 - recall: 0.3786 - fmeasure: 0.5058 - val_loss: 3.5930 - val_acc: 0.2194 - val_precision: 0.2900 - val_recall: 0.1237 - val_fmeasure: 0.1725
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 11s 171us/step - loss: 0.9407 - acc: 0.7077 - precision: 0.8293 - recall: 0.6104 - fmeasure: 0.7020 - val_loss: 4.1815 - val_acc: 0.2326 - val_precision: 0.2731 - val_recall: 0.1731 - val_fmeasure: 0.2114
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 27s 156us/step - loss: 1.6831 - acc: 0.5485 - precision: 0.7774 - recall: 0.3928 - fmeasure: 0.5200 - val_loss: 3.5632 - val_acc: 0.2160 - val_precision: 0.2948 - val_recall: 0.1163 - val_fmeasure: 0.1659
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 11s 168us/step - loss: 0.9239 - acc: 0.7123 - precision: 0.8292 - recall: 0.6189 - fmeasure: 0.7077 - val_loss: 4.2432 - val_acc: 0.2377 - val_precision: 0.2759 - val_recall: 0.1758 - val_fmeasure: 0.2143
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 11s 169us/step - loss: 0.8452 - acc: 0.7383 - precision: 0.8426 - recall: 0.6539 - fmeasure: 0.7355 - val_loss: 4.3878 - val_acc: 0.2332 - val_precision: 0.2702 - val_recall: 0.1807 - val_fmeasure: 0.2162
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 172us/step - loss: 0.7998 - acc: 0.7507 - precision: 0.8474 - recall: 0.6730 - fmeasure: 0.7495 - val_loss: 4.5863 - val_acc: 0.2299 - val_precision: 0.2629 - val_recall: 0.1788 - val_fmeasure: 0.2124
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 173us/step - loss: 0.7598 - acc: 0.7648 - precision: 0.8552 - recall: 0.6927 - fmeasure: 0.7647 - val_loss: 4.7137 - val_acc: 0.2303 - val_precision: 0.2623 - val_recall: 0.1852 - val_fmeasure: 0.2168
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 172us/step - loss: 0.7341 - acc: 0.7722 - precision: 0.8582 - recall: 0.7043 - fmeasure: 0.7730 - val_loss: 4.8927 - val_acc: 0.2286 - val_precision: 0.2567 - val_recall: 0.1869 - val_fmeasure: 0.2161
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 172us/step - loss: 0.7099 - acc: 0.7793 - precision: 0.8626 - recall: 0.7136 - fmeasure: 0.7804 - val_loss: 4.7772 - val_acc: 0.2316 - val_precision: 0.2575 - val_recall: 0.1850 - val_fmeasure: 0.2149
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 172us/step - loss: 0.6830 - acc: 0.7895 - precision: 0.8675 - recall: 0.7259 - fmeasure: 0.7898 - val_loss: 4.9670 - val_acc: 0.2267 - val_precision: 0.2495 - val_recall: 0.1822 - val_fmeasure: 0.2103
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 173us/step - loss: 0.6654 - acc: 0.7927 - precision: 0.8681 - recall: 0.7328 - fmeasure: 0.7941 - val_loss: 5.2300 - val_acc: 0.2265 - val_precision: 0.2471 - val_recall: 0.1903 - val_fmeasure: 0.2148
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 173us/step - loss: 0.6467 - acc: 0.8014 - precision: 0.8745 - recall: 0.7446 - fmeasure: 0.8038 - val_loss: 5.2302 - val_acc: 0.2242 - val_precision: 0.2490 - val_recall: 0.1905 - val_fmeasure: 0.2156
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 12s 172us/step - loss: 0.6298 - acc: 0.8048 - precision: 0.8768 - recall: 0.7498 - fmeasure: 0.8078 - val_loss: 5.2982 - val_acc: 0.2236 - val_precision: 0.2477 - val_recall: 0.1895 - val_fmeasure: 0.2145
# base_line_now#######################################################################################################################################################################################################
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/50
# 67200/67200 [==============================] - 12s 180us/step - loss: 3.4963 - acc: 0.2004 - precision: 0.2580 - recall: 0.0101 - fmeasure: 0.0191 - val_loss: 3.0194 - val_acc: 0.2190 - val_precision: 0.1304 - val_recall: 0.0025 - val_fmeasure: 0.0048
# Epoch 2/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 2.9560 - acc: 0.2157 - precision: 0.4706 - recall: 0.0203 - fmeasure: 0.0384 - val_loss: 2.7836 - val_acc: 0.2442 - val_precision: 0.4707 - val_recall: 0.0140 - val_fmeasure: 0.0269
# Epoch 3/50
# 67200/67200 [==============================] - 12s 173us/step - loss: 2.6757 - acc: 0.2515 - precision: 0.5749 - recall: 0.0410 - fmeasure: 0.0755 - val_loss: 2.7145 - val_acc: 0.2608 - val_precision: 0.5409 - val_recall: 0.0189 - val_fmeasure: 0.0361
# Epoch 4/50
# 67200/67200 [==============================] - 12s 174us/step - loss: 2.4724 - acc: 0.2880 - precision: 0.6213 - recall: 0.0650 - fmeasure: 0.1162 - val_loss: 2.6657 - val_acc: 0.2693 - val_precision: 0.5403 - val_recall: 0.0358 - val_fmeasure: 0.0664
# Epoch 5/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 2.3092 - acc: 0.3190 - precision: 0.6328 - recall: 0.0918 - fmeasure: 0.1586 - val_loss: 2.6778 - val_acc: 0.2706 - val_precision: 0.5116 - val_recall: 0.0485 - val_fmeasure: 0.0876
# Epoch 6/50
# 67200/67200 [==============================] - 12s 176us/step - loss: 2.1679 - acc: 0.3498 - precision: 0.6479 - recall: 0.1201 - fmeasure: 0.2006 - val_loss: 2.7789 - val_acc: 0.2656 - val_precision: 0.4521 - val_recall: 0.0710 - val_fmeasure: 0.1215
# Epoch 7/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 2.0431 - acc: 0.3799 - precision: 0.6678 - recall: 0.1533 - fmeasure: 0.2470 - val_loss: 2.7790 - val_acc: 0.2623 - val_precision: 0.4570 - val_recall: 0.0686 - val_fmeasure: 0.1181
# Epoch 8/50
# 67200/67200 [==============================] - 12s 173us/step - loss: 1.9368 - acc: 0.4062 - precision: 0.6790 - recall: 0.1845 - fmeasure: 0.2881 - val_loss: 2.8582 - val_acc: 0.2640 - val_precision: 0.4192 - val_recall: 0.0895 - val_fmeasure: 0.1462
# Epoch 9/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 1.8280 - acc: 0.4365 - precision: 0.6941 - recall: 0.2207 - fmeasure: 0.3327 - val_loss: 2.9617 - val_acc: 0.2527 - val_precision: 0.3851 - val_recall: 0.0880 - val_fmeasure: 0.1421
# Epoch 10/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 1.7351 - acc: 0.4612 - precision: 0.6990 - recall: 0.2533 - fmeasure: 0.3698 - val_loss: 3.1244 - val_acc: 0.2510 - val_precision: 0.3551 - val_recall: 0.0999 - val_fmeasure: 0.1549
# Epoch 11/50
# 67200/67200 [==============================] - 12s 173us/step - loss: 1.6541 - acc: 0.4850 - precision: 0.7115 - recall: 0.2863 - fmeasure: 0.4062 - val_loss: 3.2026 - val_acc: 0.2448 - val_precision: 0.3423 - val_recall: 0.1144 - val_fmeasure: 0.1705
# Epoch 12/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 1.5798 - acc: 0.5049 - precision: 0.7231 - recall: 0.3178 - fmeasure: 0.4396 - val_loss: 3.3726 - val_acc: 0.2408 - val_precision: 0.3264 - val_recall: 0.1189 - val_fmeasure: 0.1733
# Epoch 13/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 1.5107 - acc: 0.5272 - precision: 0.7319 - recall: 0.3485 - fmeasure: 0.4703 - val_loss: 3.4406 - val_acc: 0.2417 - val_precision: 0.3149 - val_recall: 0.1308 - val_fmeasure: 0.1841
# Epoch 14/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 1.4464 - acc: 0.5444 - precision: 0.7375 - recall: 0.3732 - fmeasure: 0.4936 - val_loss: 3.4833 - val_acc: 0.2412 - val_precision: 0.3113 - val_recall: 0.1286 - val_fmeasure: 0.1812
# Epoch 15/50
# 67200/67200 [==============================] - 11s 171us/step - loss: 1.3897 - acc: 0.5631 - precision: 0.7490 - recall: 0.3986 - fmeasure: 0.5187 - val_loss: 3.6714 - val_acc: 0.2349 - val_precision: 0.2929 - val_recall: 0.1392 - val_fmeasure: 0.1880
# Epoch 16/50
# 67200/67200 [==============================] - 12s 173us/step - loss: 1.3316 - acc: 0.5798 - precision: 0.7566 - recall: 0.4254 - fmeasure: 0.5430 - val_loss: 3.7535 - val_acc: 0.2402 - val_precision: 0.2926 - val_recall: 0.1490 - val_fmeasure: 0.1968
# Epoch 17/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 1.2815 - acc: 0.5954 - precision: 0.7632 - recall: 0.4477 - fmeasure: 0.5628 - val_loss: 3.8405 - val_acc: 0.2356 - val_precision: 0.2903 - val_recall: 0.1527 - val_fmeasure: 0.1995
# Epoch 18/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 1.2325 - acc: 0.6097 - precision: 0.7707 - recall: 0.4703 - fmeasure: 0.5828 - val_loss: 3.8968 - val_acc: 0.2360 - val_precision: 0.2910 - val_recall: 0.1564 - val_fmeasure: 0.2028
# Epoch 19/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 1.1878 - acc: 0.6236 - precision: 0.7777 - recall: 0.4914 - fmeasure: 0.6010 - val_loss: 4.0186 - val_acc: 0.2336 - val_precision: 0.2839 - val_recall: 0.1568 - val_fmeasure: 0.2013
# Epoch 20/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 1.1438 - acc: 0.6381 - precision: 0.7850 - recall: 0.5109 - fmeasure: 0.6177 - val_loss: 4.1409 - val_acc: 0.2247 - val_precision: 0.2695 - val_recall: 0.1545 - val_fmeasure: 0.1959
# Epoch 21/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 1.1019 - acc: 0.6509 - precision: 0.7888 - recall: 0.5306 - fmeasure: 0.6333 - val_loss: 4.1943 - val_acc: 0.2248 - val_precision: 0.2667 - val_recall: 0.1539 - val_fmeasure: 0.1947
# Epoch 22/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 1.0708 - acc: 0.6613 - precision: 0.7951 - recall: 0.5457 - fmeasure: 0.6461 - val_loss: 4.3039 - val_acc: 0.2258 - val_precision: 0.2665 - val_recall: 0.1621 - val_fmeasure: 0.2011
# Epoch 23/50
# 67200/67200 [==============================] - 12s 173us/step - loss: 1.0291 - acc: 0.6746 - precision: 0.8027 - recall: 0.5654 - fmeasure: 0.6623 - val_loss: 4.4330 - val_acc: 0.2327 - val_precision: 0.2735 - val_recall: 0.1787 - val_fmeasure: 0.2157
# Epoch 24/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 0.9958 - acc: 0.6837 - precision: 0.8071 - recall: 0.5794 - fmeasure: 0.6735 - val_loss: 4.5071 - val_acc: 0.2259 - val_precision: 0.2612 - val_recall: 0.1688 - val_fmeasure: 0.2046
# Epoch 25/50
# 67200/67200 [==============================] - 11s 170us/step - loss: 0.9593 - acc: 0.6978 - precision: 0.8145 - recall: 0.5982 - fmeasure: 0.6888 - val_loss: 4.6343 - val_acc: 0.2276 - val_precision: 0.2639 - val_recall: 0.1738 - val_fmeasure: 0.2092
# Epoch 26/50
# 67200/67200 [==============================] - 11s 170us/step - loss: 0.9259 - acc: 0.7044 - precision: 0.8145 - recall: 0.6107 - fmeasure: 0.6970 - val_loss: 4.6740 - val_acc: 0.2271 - val_precision: 0.2615 - val_recall: 0.1765 - val_fmeasure: 0.2104
# Epoch 27/50
# 67200/67200 [==============================] - 11s 169us/step - loss: 0.9056 - acc: 0.7126 - precision: 0.8189 - recall: 0.6220 - fmeasure: 0.7061 - val_loss: 4.7612 - val_acc: 0.2218 - val_precision: 0.2519 - val_recall: 0.1728 - val_fmeasure: 0.2046
# Epoch 28/50
# 67200/67200 [==============================] - 11s 171us/step - loss: 0.8787 - acc: 0.7222 - precision: 0.8246 - recall: 0.6354 - fmeasure: 0.7169 - val_loss: 4.8136 - val_acc: 0.2200 - val_precision: 0.2498 - val_recall: 0.1718 - val_fmeasure: 0.2033
# Epoch 29/50
# 67200/67200 [==============================] - 12s 174us/step - loss: 0.8434 - acc: 0.7344 - precision: 0.8302 - recall: 0.6510 - fmeasure: 0.7289 - val_loss: 5.0237 - val_acc: 0.2149 - val_precision: 0.2420 - val_recall: 0.1737 - val_fmeasure: 0.2020
# Epoch 30/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 0.8251 - acc: 0.7385 - precision: 0.8333 - recall: 0.6598 - fmeasure: 0.7357 - val_loss: 4.9785 - val_acc: 0.2200 - val_precision: 0.2475 - val_recall: 0.1764 - val_fmeasure: 0.2057
# Epoch 31/50
# 67200/67200 [==============================] - 12s 174us/step - loss: 0.8015 - acc: 0.7470 - precision: 0.8347 - recall: 0.6697 - fmeasure: 0.7424 - val_loss: 5.1496 - val_acc: 0.2179 - val_precision: 0.2433 - val_recall: 0.1778 - val_fmeasure: 0.2052
# Epoch 32/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 0.7778 - acc: 0.7540 - precision: 0.8390 - recall: 0.6809 - fmeasure: 0.7511 - val_loss: 5.2417 - val_acc: 0.2188 - val_precision: 0.2455 - val_recall: 0.1834 - val_fmeasure: 0.2097
# Epoch 33/50
# 67200/67200 [==============================] - 12s 174us/step - loss: 0.7570 - acc: 0.7608 - precision: 0.8441 - recall: 0.6899 - fmeasure: 0.7586 - val_loss: 5.2036 - val_acc: 0.2171 - val_precision: 0.2422 - val_recall: 0.1785 - val_fmeasure: 0.2052
# Epoch 34/50
# 67200/67200 [==============================] - 12s 171us/step - loss: 0.7366 - acc: 0.7676 - precision: 0.8488 - recall: 0.7003 - fmeasure: 0.7668 - val_loss: 5.4842 - val_acc: 0.2183 - val_precision: 0.2404 - val_recall: 0.1856 - val_fmeasure: 0.2092
# Epoch 35/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 0.7183 - acc: 0.7746 - precision: 0.8531 - recall: 0.7106 - fmeasure: 0.7747 - val_loss: 5.4832 - val_acc: 0.2149 - val_precision: 0.2362 - val_recall: 0.1814 - val_fmeasure: 0.2050
# Epoch 36/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 0.6957 - acc: 0.7812 - precision: 0.8541 - recall: 0.7189 - fmeasure: 0.7801 - val_loss: 5.5903 - val_acc: 0.2162 - val_precision: 0.2360 - val_recall: 0.1842 - val_fmeasure: 0.2067
# Epoch 37/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 0.6868 - acc: 0.7838 - precision: 0.8557 - recall: 0.7231 - fmeasure: 0.7832 - val_loss: 5.6596 - val_acc: 0.2120 - val_precision: 0.2327 - val_recall: 0.1843 - val_fmeasure: 0.2055
# Epoch 38/50
# 67200/67200 [==============================] - 11s 171us/step - loss: 0.6711 - acc: 0.7900 - precision: 0.8610 - recall: 0.7324 - fmeasure: 0.7909 - val_loss: 5.7358 - val_acc: 0.2110 - val_precision: 0.2302 - val_recall: 0.1819 - val_fmeasure: 0.2030
# Epoch 39/50
# 67200/67200 [==============================] - 12s 173us/step - loss: 0.6525 - acc: 0.7946 - precision: 0.8639 - recall: 0.7393 - fmeasure: 0.7962 - val_loss: 5.7978 - val_acc: 0.2107 - val_precision: 0.2293 - val_recall: 0.1809 - val_fmeasure: 0.2021
# Epoch 40/50
# 67200/67200 [==============================] - 12s 173us/step - loss: 0.6354 - acc: 0.8008 - precision: 0.8641 - recall: 0.7458 - fmeasure: 0.8002 - val_loss: 5.6823 - val_acc: 0.2144 - val_precision: 0.2345 - val_recall: 0.1840 - val_fmeasure: 0.2060
# Epoch 41/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 0.6237 - acc: 0.8047 - precision: 0.8671 - recall: 0.7531 - fmeasure: 0.8055 - val_loss: 5.7652 - val_acc: 0.2141 - val_precision: 0.2300 - val_recall: 0.1851 - val_fmeasure: 0.2049
# Epoch 42/50
# 67200/67200 [==============================] - 12s 173us/step - loss: 0.6087 - acc: 0.8108 - precision: 0.8706 - recall: 0.7611 - fmeasure: 0.8118 - val_loss: 5.8894 - val_acc: 0.2115 - val_precision: 0.2306 - val_recall: 0.1848 - val_fmeasure: 0.2050
# Epoch 43/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 0.5878 - acc: 0.8164 - precision: 0.8729 - recall: 0.7676 - fmeasure: 0.8164 - val_loss: 5.9209 - val_acc: 0.2092 - val_precision: 0.2275 - val_recall: 0.1834 - val_fmeasure: 0.2030
# Epoch 44/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 0.5775 - acc: 0.8192 - precision: 0.8748 - recall: 0.7740 - fmeasure: 0.8209 - val_loss: 6.1168 - val_acc: 0.2107 - val_precision: 0.2255 - val_recall: 0.1858 - val_fmeasure: 0.2035
# Epoch 45/50
# 67200/67200 [==============================] - 12s 171us/step - loss: 0.5585 - acc: 0.8261 - precision: 0.8799 - recall: 0.7819 - fmeasure: 0.8276 - val_loss: 6.2312 - val_acc: 0.2093 - val_precision: 0.2259 - val_recall: 0.1862 - val_fmeasure: 0.2040
# Epoch 46/50
# 67200/67200 [==============================] - 11s 169us/step - loss: 0.5531 - acc: 0.8265 - precision: 0.8788 - recall: 0.7831 - fmeasure: 0.8278 - val_loss: 6.3029 - val_acc: 0.2024 - val_precision: 0.2165 - val_recall: 0.1792 - val_fmeasure: 0.1959
# Epoch 47/50
# 67200/67200 [==============================] - 12s 171us/step - loss: 0.5455 - acc: 0.8294 - precision: 0.8802 - recall: 0.7886 - fmeasure: 0.8315 - val_loss: 6.1880 - val_acc: 0.2007 - val_precision: 0.2167 - val_recall: 0.1785 - val_fmeasure: 0.1956
# Epoch 48/50
# 67200/67200 [==============================] - 12s 172us/step - loss: 0.5286 - acc: 0.8354 - precision: 0.8837 - recall: 0.7951 - fmeasure: 0.8367 - val_loss: 6.4046 - val_acc: 0.2066 - val_precision: 0.2206 - val_recall: 0.1857 - val_fmeasure: 0.2015
# Epoch 49/50
# 67200/67200 [==============================] - 11s 170us/step - loss: 0.5131 - acc: 0.8385 - precision: 0.8859 - recall: 0.8000 - fmeasure: 0.8404 - val_loss: 6.3756 - val_acc: 0.2013 - val_precision: 0.2142 - val_recall: 0.1800 - val_fmeasure: 0.1955
# Epoch 50/50
# 67200/67200 [==============================] - 11s 168us/step - loss: 0.5048 - acc: 0.8428 - precision: 0.8877 - recall: 0.8042 - fmeasure: 0.8435 - val_loss: 6.4181 - val_acc: 0.2028 - val_precision: 0.2155 - val_recall: 0.1805 - val_fmeasure: 0.1963

# %%
#CNN               ############# test for noise adding  , function :: creat_data############

BATCH_SIZE = 64
NB_EPOCHS = 50
VALIDATION_SPLIT = 0.3

OPTIMIZER = Adamax()

historys_DNN = []
NB_tech = [4,4,4,4]

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)


print('Pad sequences to ',maxlen)
print('ready for 4')
X_4,y_4 = random_launch(X_train,y_train,NB_tech[0])
X_4 = sequence.pad_sequences(X_4, maxlen=maxlen,padding='post',truncating='post')
X_4 = X_4[:,:,np.newaxis]
y_4 = np_utils.to_categorical(y_4, NB_CLASSES)
'''
print('ready for 3')
X_3,y_3 = random_launch(X_train,y_train,NB_tech[1])
X_3 = sequence.pad_sequences(X_3, maxlen=maxlen,padding='post',truncating='post')
X_3 = X_3[:,:,np.newaxis]
y_3 = np_utils.to_categorical(y_3, NB_CLASSES)
print('ready for 2')
X_2,y_2 = random_launch(X_train,y_train,NB_tech[2])
X_2 = sequence.pad_sequences(X_2, maxlen=maxlen,padding='post',truncating='post')
X_2 = X_2[:,:,np.newaxis]
y_2 = np_utils.to_categorical(y_2, NB_CLASSES)
print('ready for 1')
X_1,y_1 = random_launch(X_train,y_train,NB_tech[3])
X_1 = sequence.pad_sequences(X_1, maxlen=maxlen,padding='post',truncating='post')
X_1 = X_1[:,:,np.newaxis]
y_1 = np_utils.to_categorical(y_1, NB_CLASSES)

'''
X_train = sequence.pad_sequences(X_train, maxlen=maxlen,padding='post',truncating='post')
X_train = X_train[:,:,np.newaxis]
y_train = np_utils.to_categorical(y_train, NB_CLASSES)
X_test = sequence.pad_sequences(X_test, maxlen=maxlen,padding='post',truncating='post')
X_test = X_test[:,:,np.newaxis]

y_test = np_utils.to_categorical(y_test, NB_CLASSES)

print('the shape of x_train',X_train.shape)
print('the shape of y_train',y_train.shape)
print('the shape of x_test',X_test.shape)
print('the shape of y_test',y_test.shape)
model_CNN = CNN(maxlen,NB_CLASSES)
model_CNN.summary()
model_CNN.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])




history_CNN_loss = []
history_CNN_acc = []
history_CNN_precision = []
history_CNN_recall = []
history_CNN_fmeasure = []
history_CNN_val_loss = []
history_CNN_val_acc = []
history_CNN_val_precision = []
history_CNN_val_recall = []
history_CNN_val_fmeasure = []

def recorder_CNN(history):
    history_CNN_loss.append(history.history['loss'][0])
    history_CNN_acc.append(history.history['acc'][0])
    history_CNN_precision.append(history.history['precision'][0])
    history_CNN_recall.append(history.history['recall'][0])
    history_CNN_fmeasure.append(history.history['fmeasure'][0])
    history_CNN_val_loss.append(history.history['val_loss'][0])
    history_CNN_val_acc.append(history.history['val_acc'][0])
    history_CNN_val_precision.append(history.history['val_precision'][0])
    history_CNN_val_recall.append(history.history['val_recall'][0])
    history_CNN_val_fmeasure.append(history.history['val_fmeasure'][0])


for i in range(NB_EPOCHS):
    if (i<=NB_EPOCHS/5):
        history = model_CNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)
    elif (NB_EPOCHS/5<i and i%2==1 and i<(NB_EPOCHS*4/5)):
        history = model_CNN.fit(X_4,y_4,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)
    elif (NB_EPOCHS/5<i and i%2==0 and i<(NB_EPOCHS*4/5)):
        history = model_CNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)
    else:
        history = model_CNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)

print('base_line_now')
model_CNN_org = CNN(maxlen,NB_CLASSES)
model_CNN_org.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])
history_CNN_org = model_CNN_org.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=50,validation_data=(X_test,y_test),verbose=1)
# Out:
# Pad sequences to  5000
# ready for 4
# transplanting...
# Pad sequences to  5000
# ready for 4
# transplanting...
# shuffling...
# shuffling...
# adding noise...
# adding noise...
# deleting...
# deleting...
# the shape of x_train (67200, 5000, 1)
# the shape of y_train (67200, 96)
# the shape of x_test (28800, 5000, 1)
# the shape of y_test (28800, 96)
# the shape of x_train (67200, 5000, 1)
# the shape of y_train (67200, 96)
# the shape of x_test (28800, 5000, 1)
# the shape of y_test (28800, 96)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv1D)        (None, 5000, 32)          288
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 5000, 32)          128
# _________________________________________________________________
# block1_adv_act1 (ELU)        (None, 5000, 32)          0
# _________________________________________________________________
# block1_conv2 (Conv1D)        (None, 5000, 32)          8224
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 5000, 32)          128
# _________________________________________________________________
# block1_adv_act2 (ELU)        (None, 5000, 32)          0
# _________________________________________________________________
# block1_pool (MaxPooling1D)   (None, 1250, 32)          0
# _________________________________________________________________
# block1_dropout (Dropout)     (None, 1250, 32)          0
# _________________________________________________________________
# block2_conv1 (Conv1D)        (None, 1250, 64)          16448
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1250, 64)          256
# _________________________________________________________________
# block2_act1 (Activation)     (None, 1250, 64)          0
# _________________________________________________________________
# block2_conv2 (Conv1D)        (None, 1250, 64)          32832
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1250, 64)          256
# _________________________________________________________________
# block2_act2 (Activation)     (None, 1250, 64)          0
# _________________________________________________________________
# block2_pool (MaxPooling1D)   (None, 313, 64)           0
# _________________________________________________________________
# block2_dropout (Dropout)     (None, 313, 64)           0
# _________________________________________________________________
# block3_conv1 (Conv1D)        (None, 313, 128)          65664
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 313, 128)          512
# _________________________________________________________________
# block3_act1 (Activation)     (None, 313, 128)          0
# _________________________________________________________________
# block3_conv2 (Conv1D)        (None, 313, 128)          131200
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 313, 128)          512
# _________________________________________________________________
# block3_act2 (Activation)     (None, 313, 128)          0
# _________________________________________________________________
# block3_pool (MaxPooling1D)   (None, 79, 128)           0
# _________________________________________________________________
# block3_dropout (Dropout)     (None, 79, 128)           0
# _________________________________________________________________
# block4_conv1 (Conv1D)        (None, 79, 256)           262400
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 79, 256)           1024
# _________________________________________________________________
# block4_act1 (Activation)     (None, 79, 256)           0
# _________________________________________________________________
# block4_conv2 (Conv1D)        (None, 79, 256)           524544
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 79, 256)           1024
# _________________________________________________________________
# block4_act2 (Activation)     (None, 79, 256)           0
# _________________________________________________________________
# block4_pool (MaxPooling1D)   (None, 20, 256)           0
# _________________________________________________________________
# block4_dropout (Dropout)     (None, 20, 256)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 5120)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 512)               2621952
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 512)               2048
# _________________________________________________________________
# fc1_act (Activation)         (None, 512)               0
# _________________________________________________________________
# fc1_dropout (Dropout)        (None, 512)               0
# _________________________________________________________________
# fc2 (Dense)                  (None, 512)               262656
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# fc2_act (Activation)         (None, 512)               0
# _________________________________________________________________
# fc2_dropout (Dropout)        (None, 512)               0
# _________________________________________________________________
# fc3 (Dense)                  (None, 96)                49248
# _________________________________________________________________
# softmax (Activation)         (None, 96)                0
# =================================================================
# Total params: 3,983,392
# Trainable params: 3,979,424
# Non-trainable params: 3,968
# _________________________________________________________________
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv1D)        (None, 5000, 32)          288
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 5000, 32)          128
# _________________________________________________________________
# block1_adv_act1 (ELU)        (None, 5000, 32)          0
# _________________________________________________________________
# block1_conv2 (Conv1D)        (None, 5000, 32)          8224
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 5000, 32)          128
# _________________________________________________________________
# block1_adv_act2 (ELU)        (None, 5000, 32)          0
# _________________________________________________________________
# block1_pool (MaxPooling1D)   (None, 1250, 32)          0
# _________________________________________________________________
# block1_dropout (Dropout)     (None, 1250, 32)          0
# _________________________________________________________________
# block2_conv1 (Conv1D)        (None, 1250, 64)          16448
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1250, 64)          256
# _________________________________________________________________
# block2_act1 (Activation)     (None, 1250, 64)          0
# _________________________________________________________________
# block2_conv2 (Conv1D)        (None, 1250, 64)          32832
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1250, 64)          256
# _________________________________________________________________
# block2_act2 (Activation)     (None, 1250, 64)          0
# _________________________________________________________________
# block2_pool (MaxPooling1D)   (None, 313, 64)           0
# _________________________________________________________________
# block2_dropout (Dropout)     (None, 313, 64)           0
# _________________________________________________________________
# block3_conv1 (Conv1D)        (None, 313, 128)          65664
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 313, 128)          512
# _________________________________________________________________
# block3_act1 (Activation)     (None, 313, 128)          0
# _________________________________________________________________
# block3_conv2 (Conv1D)        (None, 313, 128)          131200
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 313, 128)          512
# _________________________________________________________________
# block3_act2 (Activation)     (None, 313, 128)          0
# _________________________________________________________________
# block3_pool (MaxPooling1D)   (None, 79, 128)           0
# _________________________________________________________________
# block3_dropout (Dropout)     (None, 79, 128)           0
# _________________________________________________________________
# block4_conv1 (Conv1D)        (None, 79, 256)           262400
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 79, 256)           1024
# _________________________________________________________________
# block4_act1 (Activation)     (None, 79, 256)           0
# _________________________________________________________________
# block4_conv2 (Conv1D)        (None, 79, 256)           524544
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 79, 256)           1024
# _________________________________________________________________
# block4_act2 (Activation)     (None, 79, 256)           0
# _________________________________________________________________
# block4_pool (MaxPooling1D)   (None, 20, 256)           0
# _________________________________________________________________
# block4_dropout (Dropout)     (None, 20, 256)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 5120)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 512)               2621952
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 512)               2048
# _________________________________________________________________
# fc1_act (Activation)         (None, 512)               0
# _________________________________________________________________
# fc1_dropout (Dropout)        (None, 512)               0
# _________________________________________________________________
# fc2 (Dense)                  (None, 512)               262656
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# fc2_act (Activation)         (None, 512)               0
# _________________________________________________________________
# fc2_dropout (Dropout)        (None, 512)               0
# _________________________________________________________________
# fc3 (Dense)                  (None, 96)                49248
# _________________________________________________________________
# softmax (Activation)         (None, 96)                0
# =================================================================
# Total params: 3,983,392
# Trainable params: 3,979,424
# Non-trainable params: 3,968
# _________________________________________________________________
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 191s 3ms/step - loss: 3.0528 - acc: 0.2339 - precision: 0.4314 - recall: 0.0459 - fmeasure: 0.0816 - val_loss: 2.1512 - val_acc: 0.3882 - val_precision: 0.6453 - val_recall: 0.1663 - val_fmeasure: 0.2625
# 67200/67200 [==============================] - 191s 3ms/step - loss: 3.0528 - acc: 0.2339 - precision: 0.4314 - recall: 0.0459 - fmeasure: 0.0816 - val_loss: 2.1512 - val_acc: 0.3882 - val_precision: 0.6453 - val_recall: 0.1663 - val_fmeasure: 0.2625
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:41 - loss: 2.5761 - acc: 0.3125 - precision: 0.8000 - recall: 0.0625 - fmeasure: 0.1159Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 182s 3ms/step - loss: 2.0257 - acc: 0.4241 - precision: 0.6774 - recall: 0.1899 - fmeasure: 0.2926 - val_loss: 2.0473 - val_acc: 0.4118 - val_precision: 0.7019 - val_recall: 0.1517 - val_fmeasure: 0.2475
# 67200/67200 [==============================] - 182s 3ms/step - loss: 2.0257 - acc: 0.4241 - precision: 0.6774 - recall: 0.1899 - fmeasure: 0.2926 - val_loss: 2.0473 - val_acc: 0.4118 - val_precision: 0.7019 - val_recall: 0.1517 - val_fmeasure: 0.2475
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:41 - loss: 1.7784 - acc: 0.4844 - precision: 0.7143 - recall: 0.2344 - fmeasure: 0.3529Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 182s 3ms/step - loss: 1.6029 - acc: 0.5353 - precision: 0.7416 - recall: 0.3446 - fmeasure: 0.4684 - val_loss: 1.1117 - val_acc: 0.6773 - val_precision: 0.8590 - val_recall: 0.5115 - val_fmeasure: 0.6397
# 67200/67200 [==============================] - 182s 3ms/step - loss: 1.6029 - acc: 0.5353 - precision: 0.7416 - recall: 0.3446 - fmeasure: 0.4684 - val_loss: 1.1117 - val_acc: 0.6773 - val_precision: 0.8590 - val_recall: 0.5115 - val_fmeasure: 0.6397
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:39 - loss: 1.6399 - acc: 0.5781 - precision: 0.8387 - recall: 0.4062 - fmeasure: 0.5474Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 182s 3ms/step - loss: 1.3553 - acc: 0.6083 - precision: 0.7750 - recall: 0.4474 - fmeasure: 0.5658 - val_loss: 0.9727 - val_acc: 0.7163 - val_precision: 0.8433 - val_recall: 0.6018 - val_fmeasure: 0.7013
# 67200/67200 [==============================] - 182s 3ms/step - loss: 1.3553 - acc: 0.6083 - precision: 0.7750 - recall: 0.4474 - fmeasure: 0.5658 - val_loss: 0.9727 - val_acc: 0.7163 - val_precision: 0.8433 - val_recall: 0.6018 - val_fmeasure: 0.7013
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:42 - loss: 1.2830 - acc: 0.6406 - precision: 0.7209 - recall: 0.4844 - fmeasure: 0.5794Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 183s 3ms/step - loss: 1.1847 - acc: 0.6566 - precision: 0.8016 - recall: 0.5214 - fmeasure: 0.6307 - val_loss: 0.8597 - val_acc: 0.7531 - val_precision: 0.8709 - val_recall: 0.6455 - val_fmeasure: 0.7404
# 67200/67200 [==============================] - 183s 3ms/step - loss: 1.1847 - acc: 0.6566 - precision: 0.8016 - recall: 0.5214 - fmeasure: 0.6307 - val_loss: 0.8597 - val_acc: 0.7531 - val_precision: 0.8709 - val_recall: 0.6455 - val_fmeasure: 0.7404
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:38 - loss: 1.0121 - acc: 0.6875 - precision: 0.8085 - recall: 0.5938 - fmeasure: 0.6847Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 183s 3ms/step - loss: 1.0692 - acc: 0.6893 - precision: 0.8148 - recall: 0.5731 - fmeasure: 0.6719 - val_loss: 0.8045 - val_acc: 0.7715 - val_precision: 0.8871 - val_recall: 0.6631 - val_fmeasure: 0.7578
# 67200/67200 [==============================] - 183s 3ms/step - loss: 1.0692 - acc: 0.6893 - precision: 0.8148 - recall: 0.5731 - fmeasure: 0.6719 - val_loss: 0.8045 - val_acc: 0.7715 - val_precision: 0.8871 - val_recall: 0.6631 - val_fmeasure: 0.7578
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:39 - loss: 1.2580 - acc: 0.6094 - precision: 0.7778 - recall: 0.5469 - fmeasure: 0.6422Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.9814 - acc: 0.7138 - precision: 0.8288 - recall: 0.6113 - fmeasure: 0.7028 - val_loss: 0.8084 - val_acc: 0.7623 - val_precision: 0.8686 - val_recall: 0.6760 - val_fmeasure: 0.7594
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.9814 - acc: 0.7138 - precision: 0.8288 - recall: 0.6113 - fmeasure: 0.7028 - val_loss: 0.8084 - val_acc: 0.7623 - val_precision: 0.8686 - val_recall: 0.6760 - val_fmeasure: 0.7594
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:38 - loss: 0.9928 - acc: 0.7656 - precision: 0.8491 - recall: 0.7031 - fmeasure: 0.7692Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.9095 - acc: 0.7374 - precision: 0.8429 - recall: 0.6441 - fmeasure: 0.7294 - val_loss: 0.7166 - val_acc: 0.7937 - val_precision: 0.8900 - val_recall: 0.7122 - val_fmeasure: 0.7905
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.9095 - acc: 0.7374 - precision: 0.8429 - recall: 0.6441 - fmeasure: 0.7294 - val_loss: 0.7166 - val_acc: 0.7937 - val_precision: 0.8900 - val_recall: 0.7122 - val_fmeasure: 0.7905
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:42 - loss: 0.9525 - acc: 0.7500 - precision: 0.9184 - recall: 0.7031 - fmeasure: 0.7965Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.8397 - acc: 0.7581 - precision: 0.8543 - recall: 0.6724 - fmeasure: 0.7519 - val_loss: 0.7648 - val_acc: 0.7745 - val_precision: 0.8737 - val_recall: 0.6902 - val_fmeasure: 0.7704
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.8397 - acc: 0.7581 - precision: 0.8543 - recall: 0.6724 - fmeasure: 0.7519 - val_loss: 0.7648 - val_acc: 0.7745 - val_precision: 0.8737 - val_recall: 0.6902 - val_fmeasure: 0.7704
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:43 - loss: 0.8141 - acc: 0.7188 - precision: 0.8148 - recall: 0.6875 - fmeasure: 0.7458Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.7893 - acc: 0.7708 - precision: 0.8613 - recall: 0.6959 - fmeasure: 0.7692 - val_loss: 0.6522 - val_acc: 0.8129 - val_precision: 0.8932 - val_recall: 0.7456 - val_fmeasure: 0.8120
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.7893 - acc: 0.7708 - precision: 0.8613 - recall: 0.6959 - fmeasure: 0.7692 - val_loss: 0.6522 - val_acc: 0.8129 - val_precision: 0.8932 - val_recall: 0.7456 - val_fmeasure: 0.8120
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:36 - loss: 0.8224 - acc: 0.7188 - precision: 0.9000 - recall: 0.7031 - fmeasure: 0.7895Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 184s 3ms/step - loss: 0.7511 - acc: 0.7812 - precision: 0.8686 - recall: 0.7104 - fmeasure: 0.7810 - val_loss: 0.6122 - val_acc: 0.8264 - val_precision: 0.9018 - val_recall: 0.7655 - val_fmeasure: 0.8274
# 67200/67200 [==============================] - 184s 3ms/step - loss: 0.7511 - acc: 0.7812 - precision: 0.8686 - recall: 0.7104 - fmeasure: 0.7810 - val_loss: 0.6122 - val_acc: 0.8264 - val_precision: 0.9018 - val_recall: 0.7655 - val_fmeasure: 0.8274
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
#     64/174720 [..............................] - ETA: 7:05 - loss: 1.9401 - acc: 0.6250 - precision: 0.6607 - recall: 0.5781 - fmeasure: 0.6167Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 442s 3ms/step - loss: 1.3639 - acc: 0.6474 - precision: 0.8099 - recall: 0.5365 - fmeasure: 0.6443 - val_loss: 0.7652 - val_acc: 0.7877 - val_precision: 0.9072 - val_recall: 0.6859 - val_fmeasure: 0.7802
# 174720/174720 [==============================] - 442s 3ms/step - loss: 1.3639 - acc: 0.6474 - precision: 0.8099 - recall: 0.5365 - fmeasure: 0.6443 - val_loss: 0.7652 - val_acc: 0.7877 - val_precision: 0.9072 - val_recall: 0.6859 - val_fmeasure: 0.7802
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:40 - loss: 0.9374 - acc: 0.7656 - precision: 0.9111 - recall: 0.6406 - fmeasure: 0.7523Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.7000 - acc: 0.8000 - precision: 0.8888 - recall: 0.7186 - fmeasure: 0.7939 - val_loss: 0.6114 - val_acc: 0.8278 - val_precision: 0.9126 - val_recall: 0.7514 - val_fmeasure: 0.8235
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.7000 - acc: 0.8000 - precision: 0.8888 - recall: 0.7186 - fmeasure: 0.7939 - val_loss: 0.6114 - val_acc: 0.8278 - val_precision: 0.9126 - val_recall: 0.7514 - val_fmeasure: 0.8235
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
#     64/174720 [..............................] - ETA: 7:09 - loss: 1.9271 - acc: 0.5781 - precision: 0.6531 - recall: 0.5000 - fmeasure: 0.5664Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 440s 3ms/step - loss: 1.1849 - acc: 0.6858 - precision: 0.8369 - recall: 0.5844 - fmeasure: 0.6873 - val_loss: 0.7332 - val_acc: 0.7946 - val_precision: 0.9048 - val_recall: 0.7077 - val_fmeasure: 0.7934
# 174720/174720 [==============================] - 440s 3ms/step - loss: 1.1849 - acc: 0.6858 - precision: 0.8369 - recall: 0.5844 - fmeasure: 0.6873 - val_loss: 0.7332 - val_acc: 0.7946 - val_precision: 0.9048 - val_recall: 0.7077 - val_fmeasure: 0.7934
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:40 - loss: 1.0162 - acc: 0.7500 - precision: 0.8200 - recall: 0.6406 - fmeasure: 0.7193Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.6250 - acc: 0.8212 - precision: 0.8980 - recall: 0.7509 - fmeasure: 0.8172 - val_loss: 0.5880 - val_acc: 0.8286 - val_precision: 0.9039 - val_recall: 0.7658 - val_fmeasure: 0.8285
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.6250 - acc: 0.8212 - precision: 0.8980 - recall: 0.7509 - fmeasure: 0.8172 - val_loss: 0.5880 - val_acc: 0.8286 - val_precision: 0.9039 - val_recall: 0.7658 - val_fmeasure: 0.8285
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
#     64/174720 [..............................] - ETA: 7:09 - loss: 1.3987 - acc: 0.6094 - precision: 0.8043 - recall: 0.5781 - fmeasure: 0.6727Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 440s 3ms/step - loss: 1.0818 - acc: 0.7116 - precision: 0.8484 - recall: 0.6196 - fmeasure: 0.7153 - val_loss: 0.6815 - val_acc: 0.8112 - val_precision: 0.9118 - val_recall: 0.7363 - val_fmeasure: 0.8139
# 174720/174720 [==============================] - 440s 3ms/step - loss: 1.0818 - acc: 0.7116 - precision: 0.8484 - recall: 0.6196 - fmeasure: 0.7153 - val_loss: 0.6815 - val_acc: 0.8112 - val_precision: 0.9118 - val_recall: 0.7363 - val_fmeasure: 0.8139
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:42 - loss: 0.8057 - acc: 0.8125 - precision: 0.9184 - recall: 0.7031 - fmeasure: 0.7965Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.5740 - acc: 0.8362 - precision: 0.9046 - recall: 0.7741 - fmeasure: 0.8337 - val_loss: 0.5165 - val_acc: 0.8556 - val_precision: 0.9143 - val_recall: 0.8114 - val_fmeasure: 0.8594
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.5740 - acc: 0.8362 - precision: 0.9046 - recall: 0.7741 - fmeasure: 0.8337 - val_loss: 0.5165 - val_acc: 0.8556 - val_precision: 0.9143 - val_recall: 0.8114 - val_fmeasure: 0.8594
# Train on 174720 samples, validate on 28800 samplesTrain on 174720 samples, validate on 28800 samples
# Epoch 1/1
#     64/174720 [..............................] - ETA: 2:00:06 - loss: 1.1477 - acc: 0.6719 - precision: 0.8000 - recall: 0.6250 - fmeasure: 0.7018
# Epoch 1/1
# 174720/174720 [==============================] - 442s 3ms/step - loss: 0.9979 - acc: 0.7331 - precision: 0.8595 - recall: 0.6488 - fmeasure: 0.7386 - val_loss: 0.6192 - val_acc: 0.8291 - val_precision: 0.9188 - val_recall: 0.7569 - val_fmeasure: 0.8293
# 174720/174720 [==============================] - 442s 3ms/step - loss: 0.9979 - acc: 0.7331 - precision: 0.8595 - recall: 0.6488 - fmeasure: 0.7386 - val_loss: 0.6192 - val_acc: 0.8291 - val_precision: 0.9188 - val_recall: 0.7569 - val_fmeasure: 0.8293
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:42 - loss: 0.6317 - acc: 0.8438 - precision: 0.9400 - recall: 0.7344 - fmeasure: 0.8246Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.5278 - acc: 0.8480 - precision: 0.9118 - recall: 0.7909 - fmeasure: 0.8465 - val_loss: 0.5163 - val_acc: 0.8540 - val_precision: 0.9194 - val_recall: 0.8019 - val_fmeasure: 0.8561
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.5278 - acc: 0.8480 - precision: 0.9118 - recall: 0.7909 - fmeasure: 0.8465 - val_loss: 0.5163 - val_acc: 0.8540 - val_precision: 0.9194 - val_recall: 0.8019 - val_fmeasure: 0.8561
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
#     64/174720 [..............................] - ETA: 7:06 - loss: 1.0468 - acc: 0.7188 - precision: 0.8113 - recall: 0.6719 - fmeasure: 0.7350Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 440s 3ms/step - loss: 0.9355 - acc: 0.7493 - precision: 0.8666 - recall: 0.6701 - fmeasure: 0.7551 - val_loss: 0.6596 - val_acc: 0.8176 - val_precision: 0.9156 - val_recall: 0.7405 - val_fmeasure: 0.8180
# 174720/174720 [==============================] - 440s 3ms/step - loss: 0.9355 - acc: 0.7493 - precision: 0.8666 - recall: 0.6701 - fmeasure: 0.7551 - val_loss: 0.6596 - val_acc: 0.8176 - val_precision: 0.9156 - val_recall: 0.7405 - val_fmeasure: 0.8180
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:41 - loss: 0.6339 - acc: 0.8281 - precision: 0.8929 - recall: 0.7812 - fmeasure: 0.8333Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.4882 - acc: 0.8585 - precision: 0.9166 - recall: 0.8086 - fmeasure: 0.8587 - val_loss: 0.5233 - val_acc: 0.8503 - val_precision: 0.9120 - val_recall: 0.8011 - val_fmeasure: 0.8525
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.4882 - acc: 0.8585 - precision: 0.9166 - recall: 0.8086 - fmeasure: 0.8587 - val_loss: 0.5233 - val_acc: 0.8503 - val_precision: 0.9120 - val_recall: 0.8011 - val_fmeasure: 0.8525
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
#     64/174720 [..............................] - ETA: 7:09 - loss: 1.0108 - acc: 0.7031 - precision: 0.8077 - recall: 0.6562 - fmeasure: 0.7241Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 441s 3ms/step - loss: 0.8782 - acc: 0.7621 - precision: 0.8732 - recall: 0.6888 - fmeasure: 0.7694 - val_loss: 0.6340 - val_acc: 0.8239 - val_precision: 0.9098 - val_recall: 0.7599 - val_fmeasure: 0.8274
# 174720/174720 [==============================] - 441s 3ms/step - loss: 0.8782 - acc: 0.7621 - precision: 0.8732 - recall: 0.6888 - fmeasure: 0.7694 - val_loss: 0.6340 - val_acc: 0.8239 - val_precision: 0.9098 - val_recall: 0.7599 - val_fmeasure: 0.8274
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:39 - loss: 0.7550 - acc: 0.7969 - precision: 0.9600 - recall: 0.7500 - fmeasure: 0.8421Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.4507 - acc: 0.8701 - precision: 0.9223 - recall: 0.8232 - fmeasure: 0.8694 - val_loss: 0.4881 - val_acc: 0.8627 - val_precision: 0.9177 - val_recall: 0.8205 - val_fmeasure: 0.8660
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.4507 - acc: 0.8701 - precision: 0.9223 - recall: 0.8232 - fmeasure: 0.8694 - val_loss: 0.4881 - val_acc: 0.8627 - val_precision: 0.9177 - val_recall: 0.8205 - val_fmeasure: 0.8660
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
#     64/174720 [..............................] - ETA: 7:10 - loss: 0.6796 - acc: 0.8594 - precision: 0.8909 - recall: 0.7656 - fmeasure: 0.8235Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 441s 3ms/step - loss: 0.8361 - acc: 0.7740 - precision: 0.8778 - recall: 0.7052 - fmeasure: 0.7814 - val_loss: 0.6188 - val_acc: 0.8303 - val_precision: 0.9139 - val_recall: 0.7667 - val_fmeasure: 0.8332
# 174720/174720 [==============================] - 441s 3ms/step - loss: 0.8361 - acc: 0.7740 - precision: 0.8778 - recall: 0.7052 - fmeasure: 0.7814 - val_loss: 0.6188 - val_acc: 0.8303 - val_precision: 0.9139 - val_recall: 0.7667 - val_fmeasure: 0.8332
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:40 - loss: 0.6272 - acc: 0.7812 - precision: 0.9592 - recall: 0.7344 - fmeasure: 0.8319Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 182s 3ms/step - loss: 0.4227 - acc: 0.8784 - precision: 0.9265 - recall: 0.8360 - fmeasure: 0.8785 - val_loss: 0.4956 - val_acc: 0.8597 - val_precision: 0.9122 - val_recall: 0.8233 - val_fmeasure: 0.8651
# 67200/67200 [==============================] - 182s 3ms/step - loss: 0.4227 - acc: 0.8784 - precision: 0.9265 - recall: 0.8360 - fmeasure: 0.8785 - val_loss: 0.4956 - val_acc: 0.8597 - val_precision: 0.9122 - val_recall: 0.8233 - val_fmeasure: 0.8651
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
#     64/174720 [..............................] - ETA: 7:07 - loss: 1.0549 - acc: 0.6875 - precision: 0.7451 - recall: 0.5938 - fmeasure: 0.6609Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 440s 3ms/step - loss: 0.7896 - acc: 0.7858 - precision: 0.8821 - recall: 0.7202 - fmeasure: 0.7923 - val_loss: 0.5976 - val_acc: 0.8355 - val_precision: 0.9068 - val_recall: 0.7840 - val_fmeasure: 0.8405
# 174720/174720 [==============================] - 440s 3ms/step - loss: 0.7896 - acc: 0.7858 - precision: 0.8821 - recall: 0.7202 - fmeasure: 0.7923 - val_loss: 0.5976 - val_acc: 0.8355 - val_precision: 0.9068 - val_recall: 0.7840 - val_fmeasure: 0.8405
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:42 - loss: 0.4773 - acc: 0.8594 - precision: 0.9286 - recall: 0.8125 - fmeasure: 0.8667Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.3972 - acc: 0.8843 - precision: 0.9296 - recall: 0.8463 - fmeasure: 0.8857 - val_loss: 0.4892 - val_acc: 0.8635 - val_precision: 0.9098 - val_recall: 0.8322 - val_fmeasure: 0.8689
# 67200/67200 [==============================] - 183s 3ms/step - loss: 0.3972 - acc: 0.8843 - precision: 0.9296 - recall: 0.8463 - fmeasure: 0.8857 - val_loss: 0.4892 - val_acc: 0.8635 - val_precision: 0.9098 - val_recall: 0.8322 - val_fmeasure: 0.8689
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
#     64/174720 [..............................] - ETA: 7:01 - loss: 0.9572 - acc: 0.7656 - precision: 0.7797 - recall: 0.7188 - fmeasure: 0.7480Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 441s 3ms/step - loss: 0.7538 - acc: 0.7955 - precision: 0.8884 - recall: 0.7341 - fmeasure: 0.8033 - val_loss: 0.5607 - val_acc: 0.8484 - val_precision: 0.9126 - val_recall: 0.8042 - val_fmeasure: 0.8546
# 174720/174720 [==============================] - 441s 3ms/step - loss: 0.7538 - acc: 0.7955 - precision: 0.8884 - recall: 0.7341 - fmeasure: 0.8033 - val_loss: 0.5607 - val_acc: 0.8484 - val_precision: 0.9126 - val_recall: 0.8042 - val_fmeasure: 0.8546
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:43 - loss: 0.3970 - acc: 0.8906 - precision: 0.9608 - recall: 0.7656 - fmeasure: 0.8522Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 67200/67200 [==============================] - 182s 3ms/step - loss: 0.3723 - acc: 0.8927 - precision: 0.9342 - recall: 0.8563 - fmeasure: 0.8932 - val_loss: 0.4771 - val_acc: 0.8674 - val_precision: 0.9124 - val_recall: 0.8373 - val_fmeasure: 0.8730
# 67200/67200 [==============================] - 182s 3ms/step - loss: 0.3723 - acc: 0.8927 - precision: 0.9342 - recall: 0.8563 - fmeasure: 0.8932 - val_loss: 0.4771 - val_acc: 0.8674 - val_precision: 0.9124 - val_recall: 0.8373 - val_fmeasure: 0.8730
# Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
#     64/174720 [..............................] - ETA: 7:09 - loss: 0.8977 - acc: 0.7656 - precision: 0.8070 - recall: 0.7188 - fmeasure: 0.7603Train on 174720 samples, validate on 28800 samples
# Epoch 1/1
# 174720/174720 [==============================] - 439s 3ms/step - loss: 0.7183 - acc: 0.8036 - precision: 0.8917 - recall: 0.7460 - fmeasure: 0.8118 - val_loss: 0.5750 - val_acc: 0.8453 - val_precision: 0.9069 - val_recall: 0.8006 - val_fmeasure: 0.8500
# 174720/174720 [==============================] - 439s 3ms/step - loss: 0.7183 - acc: 0.8036 - precision: 0.8917 - recall: 0.7460 - fmeasure: 0.8118 - val_loss: 0.5750 - val_acc: 0.8453 - val_precision: 0.9069 - val_recall: 0.8006 - val_fmeasure: 0.8500
# Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
#    64/67200 [..............................] - ETA: 2:44 - loss: 0.5782 - acc: 0.8594 - precision: 0.9455 - recall: 0.8125 - fmeasure: 0.8739Train on 67200 samples, validate on 28800 samples
# Epoch 1/1
# 31168/67200 [============>.................] - ETA: 1:26 - loss: 0.3628 - acc: 0.8963 - precision: 0.9358 - recall: 0.8566 - fmeasure: 0.8941Buffered data was truncated after reaching the output size limit.Buffered data was truncated after reaching the output size limit.

# %%
import matplotlib.pylab as plt


fig,axs = plt.subplots(1,5,figsize=(30,10))
axs[0].plot(range(NB_EPOCHS),history_DNN_org.history['val_loss'],label='before')
axs[0].plot(range(NB_EPOCHS),history_DNN_val_loss,label='after')
axs[0].set_title('val_loss')

axs[1].plot(range(NB_EPOCHS),history_DNN_org.history['val_acc'],label='before')
axs[1].plot(range(NB_EPOCHS),history_DNN_val_acc,label='after')
axs[1].set_title('val_acc')

axs[2].plot(range(NB_EPOCHS),history_DNN_org.history['val_precision'],label='before')
axs[2].plot(range(NB_EPOCHS),history_DNN_val_precision,label='after')
axs[2].set_title('val_precision')

axs[3].plot(range(NB_EPOCHS),history_DNN_org.history['val_recall'],label='before')
axs[3].plot(range(NB_EPOCHS),history_DNN_val_recall,label='after')
axs[3].set_title('val_recall')

axs[4].plot(range(NB_EPOCHS),history_DNN_org.history['val_fmeasure'],label='before')
axs[4].plot(range(NB_EPOCHS),history_DNN_val_fmeasure,label='after')
axs[4].set_title('val_fmeasure')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center')

plt.show()

# %%
import matplotlib.pylab as plt


fig,axs = plt.subplots(1,5,figsize=(30,10))
axs[0].plot(range(NB_EPOCHS),history_CNN_org.history['val_loss'],label='before')
axs[0].plot(range(NB_EPOCHS),history_CNN_val_loss,label='after')
axs[0].set_title('val_loss')

axs[1].plot(range(NB_EPOCHS),history_CNN_org.history['val_acc'],label='before')
axs[1].plot(range(NB_EPOCHS),history_CNN_val_acc,label='after')
axs[1].set_title('val_acc')

axs[2].plot(range(NB_EPOCHS),history_CNN_org.history['val_precision'],label='before')
axs[2].plot(range(NB_EPOCHS),history_CNN_val_precision,label='after')
axs[2].set_title('val_precision')

axs[3].plot(range(NB_EPOCHS),history_CNN_org.history['val_recall'],label='before')
axs[3].plot(range(NB_EPOCHS),history_CNN_val_recall,label='after')
axs[3].set_title('val_recall')

axs[4].plot(range(NB_EPOCHS),history_CNN_org.history['val_fmeasure'],label='before')
axs[4].plot(range(NB_EPOCHS),history_CNN_val_fmeasure,label='after')
axs[4].set_title('val_fmeasure')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center')

plt.show()
