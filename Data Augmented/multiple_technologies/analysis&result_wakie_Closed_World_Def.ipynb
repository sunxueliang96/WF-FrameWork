# %% [markdown]
# <a href="https://colab.research.google.com/github/sunxueliang96/WF-FrameWork/blob/master/Data%20Augmented/multiple_technologies/analysis%26result_wakie_Closed_World_Def.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#cd /content/drive/'My Drive'/datasets/no_paded/open_world/walkiebatch

# %%
#datatype_Close = False   #Flase is Open_World, True is Closed World.

# %%
cd /content/drive/'My Drive'/datasets/no_paded/close_world/walkiebatch_defended
# Out:
# /content/drive/My Drive/datasets/no_paded/close_world/walkiebatch_defended

# %%
datatype_Close = True   #Flase is Open_World, True is Closed World.

# %%
ls
# Out:
# X_walkiebatch_defended.pkl  y_walkiebatch_defended.pkl

# %%
import numpy as np
import pickle

print('loading data...')
with open('X_walkiebatch_defended.pkl','rb') as handle:
  X = np.array(pickle.load(handle))
with open('y_walkiebatch_defended.pkl','rb') as handle:
  y = np.array(pickle.load(handle))
print('the shape of X',X.shape)
print('the shape of y',y.shape)
# Out:
# loading data...
# the shape of X (10000,)
# the shape of y (10000,)

# %%
import math 
import random
def fun_noise(X,y,PERCENT_NOISE,TIMES_NOISE): 
    X = list(X)
    y = list(y)
    X_sum = []
    y_sum = []
    #X_sum = X.copy()
    #y_sum = y.copy()
    #print("{} samples has beed add to X_train, {}% of noise for each sample".format(math.ceil(len(X)*TIMES_NOISE),PERCENT_NOISE))
    for i in range(math.ceil(len(X)*TIMES_NOISE)): #ADDING NOISE from here 
        while(True):
            p = random.choice(range(len(X)))
            if(y[p]!=-1):
                break
            else:
                pass
        X_new = X[p].copy()
        y_new = y[p]
        for n in range(math.ceil(PERCENT_NOISE*len(X_new)/100)):#dealing X_new
            noise = random.choice([1,-1])       #noise could only be 1 or -1
            pos = random.choice(range(len(X_new)))  #position belong to (0,len(sequence))
            X_new.insert(pos,noise)
            #print('insert {} at position {} in sequence {} now len of sequence is {}, the tag of sequence is {}'.format(noise,pos,p,len(X_new),y_new)) #for test
        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum
def fun_delete(X,y,PERCENT_DELETE,TIMES_DELETE): 
    X = list(X)
    y = list(y)
    X_sum = []
    y_sum = []
    #X_sum = X.copy()
    #y_sum = y.copy()

    for i in range(math.ceil(len(X)*TIMES_DELETE)): #RANDOM DELETE from here
        while(True):
            p = random.choice(range(len(X)))
            if(y[p]!=-1):
                break
            else:
                #print('-1 detected')
                pass
        X_new = X[p].copy()
        y_new = y[p]
        for n in range(math.ceil(PERCENT_DELETE*len(X_new)/100)):#dealing X_new
            pos = random.choice(range(len(X_new)))  #position belong to (0,len(sequence))
            del X_new[pos]
            #print('insert {} at position {} in sequence {} now len of sequence is {}'.format(noise,pos,p,len(X_new))) #for test
        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum
def fun_shuffle(X,y,PERCENT_CHANGED,TIMES_SHUFFLE): 
    X = list(X)
    y = list(y)
    #X_sum = X.copy()
    #y_sum = y.copy()
    X_sum = []
    y_sum = []
    for i in range(math.ceil(len(X)*TIMES_SHUFFLE)):             #LOCALLY CHANGE from here
        while(True):
            p = random.choice(range(len(X)))
            if(y[p]!=-1):
                break
            else:
                #print('-1 detected')
                pass
        X_new = X[p].copy()
        y_new = y[p]
        length = math.ceil(PERCENT_CHANGED*len(X_new)/100)
        start = random.choice(range(len(X_new)-length))
        temp = X_new[start:start+length]
        random.shuffle(temp)
        X_new[start:start+length] = temp

        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum
def fun_transplant(X,y,PERCENT_TRANSPLANT,NB_TIMES):        #Magnificate dataset by adding noising randomly
    global datatype_Close
    X = list(X)
    y = list(y)
    X_sum = []
    y_sum = []
    #X_sum = X.copy()
    #y_sum = y.copy()
    #print("{} samples has beed add to X_train, {}% of noise for each sample".format(math.ceil(len(X)*NB_TIMES),PERCENT_TRANSPLANT))
    for i in range(math.ceil(len(X)*NB_TIMES)):
        #print(datatype_Close)    
        while(datatype_Close):                               # target pos p (sensitive website), pos q (non-sensitive website)
            p = random.choice(range(len(X)))
            q = random.choice(range(len(X)))
            if(p != q):                           # Closed_World
                break
            else:
                #print('-1 detected')
                pass
        while(not datatype_Close):                               # target pos p (sensitive website), pos q (non-sensitive website)
            p = random.choice(range(len(X)))
            q = random.choice(range(len(X)))
            if(y[p]!=-1 and y[q]==-1):               # open_world
                break
            else:
                #print('-1 detected')
                pass
        X_new = X[p].copy()
        target = X[q].copy()
        y_new = y[p]

        length_X = math.ceil(PERCENT_TRANSPLANT*len(X_new)/100)
        length_target =  math.ceil(PERCENT_TRANSPLANT*len(target)/100)
        start_X = random.choice(range(len(X_new)-length_X))
        start_target = random.choice(range(len(target)-length_target))
        temp = target[start_target:start_target+length_target]
        X_new[start_X:start_X+length_X] = temp
     
        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum
'''
def random_launch(X,y,NB_tech):
    X = list(X)
    y = list(y)
    X_sum = X.copy()
    y_sum = y.copy()
    launch_list = random.sample(range(4),NB_tech)             #return [0,1,....]....depending on NB_tech
    for i in launch_list:
        if (i==0):
            print('adding noise...')
            X_new,y_new = fun_noise(X,y,PERCENT_NOISE=20,TIMES_NOISE=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==1):
            print('deleting...')
            X_new,y_new = fun_delete(X,y,PERCENT_DELETE=20,TIMES_DELETE=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==2):
            print('shuffling...')
            X_new,y_new = fun_shuffle(X,y,PERCENT_CHANGED=20,TIMES_SHUFFLE=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==3):
            print('transplanting...')
            X_new,y_new = fun_transplant(X,y,PERCENT_TRANSPLANT=20,NB_TIMES=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
    return np.array(X_sum),np.array(y_sum)                        #return two array of X, y 
    '''
def random_launch(X,y,NB_tech):
    X = list(X)
    y = list(y)
    X_sum = X.copy()
    y_sum = y.copy()
    launch_list = random.sample(range(4),NB_tech)             #return [0,1,....]....depending on NB_tech
    for i in launch_list:
        if (i==0):
            print('adding noise...')
            X_new,y_new = fun_noise(X,y,PERCENT_NOISE=50,TIMES_NOISE=1)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==1):
            print('deleting...')
            X_new,y_new = fun_delete(X,y,PERCENT_DELETE=50,TIMES_DELETE=1)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==2):
            print('shuffling...')
            X_new,y_new = fun_shuffle(X,y,PERCENT_CHANGED=50,TIMES_SHUFFLE=1)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==3):
            print('transplanting...')
            X_new,y_new = fun_transplant(X,y,PERCENT_TRANSPLANT=50,NB_TIMES=1)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
    return np.array(X_sum),np.array(y_sum)                        #return two array of X, y

# %%
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing import sequence
from collections import Counter
#CLASSES_KNN = 101########################################################################################################################################################################################################
#CLASSES_WAKIE = 100########################################################################################################################################################################################################
MAXLEN_KNN = 2000
MAXLEN_WAKIE =5000

maxlen = 6000
NB_CLASSES = 0

def choose():
    global maxlen,NB_CLASSES
    print('if padding, the max of length of seq is {}'.format(maxlen))
    NB_CLASSES = len(Counter(y).keys())
    print('number of classes is {}'.format(NB_CLASSES))

choose()################################################################################################################################################################################################################

print('Average sequence length: {}'.format(np.mean(list(map(len, X)), dtype=int)))
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# if padding, the max of length of seq is 6000
# number of classes is 100
# Average sequence length: 5933

# %%
#FCN
from keras import Sequential
from keras.layers.core import Activation, Flatten, Dense, Dropout
from keras.optimizers import Adamax
def DNN(input_shape,classes):
    model = Sequential()
    model.add(Dense(128, input_shape=(input_shape,)))
    model.add(Activation('relu'))
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dense(512))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dense(classes))
    model.add(Activation('softmax'))
    return model

# %%
#CNN
from keras import Input,Model,Sequential
from keras.layers import Embedding,GlobalAveragePooling1D,Dense,Dropout
from keras.layers import Conv1D, MaxPooling1D, BatchNormalization
from keras.layers.core import Activation, Flatten, Dense, Dropout
from keras.layers.advanced_activations import ELU
from keras.initializers import glorot_uniform
from keras.optimizers import Adamax
def CNN(input_shape, classes):
    model = Sequential()
    #Block1
    filter_num = ['None',32,64,128,256]
    kernel_size = ['None',8,8,8,8]
    conv_stride_size = ['None',1,1,1,1]
    pool_stride_size = ['None',4,4,4,4]
    pool_size = ['None',8,8,8,8]

    model.add(Conv1D(filters=filter_num[1], kernel_size=kernel_size[1], input_shape=(input_shape,1),
                      strides=conv_stride_size[1], padding='same',
                      name='block1_conv1'))
    model.add(BatchNormalization(axis=-1))
    model.add(ELU(alpha=1.0, name='block1_adv_act1'))
    model.add(Conv1D(filters=filter_num[1], kernel_size=kernel_size[1],
                      strides=conv_stride_size[1], padding='same',
                      name='block1_conv2'))
    model.add(BatchNormalization(axis=-1))
    model.add(ELU(alpha=1.0, name='block1_adv_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[1], strides=pool_stride_size[1],
                            padding='same', name='block1_pool'))
    model.add(Dropout(0.1, name='block1_dropout'))

    model.add(Conv1D(filters=filter_num[2], kernel_size=kernel_size[2],
                      strides=conv_stride_size[2], padding='same',
                      name='block2_conv1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block2_act1'))

    model.add(Conv1D(filters=filter_num[2], kernel_size=kernel_size[2],
                      strides=conv_stride_size[2], padding='same',
                      name='block2_conv2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block2_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[2], strides=pool_stride_size[3],
                            padding='same', name='block2_pool'))
    model.add(Dropout(0.1, name='block2_dropout'))

    model.add(Conv1D(filters=filter_num[3], kernel_size=kernel_size[3],
                      strides=conv_stride_size[3], padding='same',
                      name='block3_conv1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block3_act1'))
    model.add(Conv1D(filters=filter_num[3], kernel_size=kernel_size[3],
                      strides=conv_stride_size[3], padding='same',
                      name='block3_conv2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block3_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[3], strides=pool_stride_size[3],
                            padding='same', name='block3_pool'))
    model.add(Dropout(0.1, name='block3_dropout'))

    model.add(Conv1D(filters=filter_num[4], kernel_size=kernel_size[4],
                      strides=conv_stride_size[4], padding='same',
                      name='block4_conv1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block4_act1'))
    model.add(Conv1D(filters=filter_num[4], kernel_size=kernel_size[4],
                      strides=conv_stride_size[4], padding='same',
                      name='block4_conv2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block4_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[4], strides=pool_stride_size[4],
                            padding='same', name='block4_pool'))
    model.add(Dropout(0.1, name='block4_dropout'))

    model.add(Flatten(name='flatten'))
    model.add(Dense(512, kernel_initializer=glorot_uniform(seed=0), name='fc1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='fc1_act'))

    model.add(Dropout(0.7, name='fc1_dropout'))

    model.add(Dense(512, kernel_initializer=glorot_uniform(seed=0), name='fc2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='fc2_act'))

    model.add(Dropout(0.5, name='fc2_dropout'))

    model.add(Dense(classes, kernel_initializer=glorot_uniform(seed=0), name='fc3'))
    model.add(Activation('softmax', name="softmax"))
    return model

# %%
import keras
from keras import backend as K

def precision(y_true, y_pred):
    # Calculates the precision
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    # Calculates the recall
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def fbeta_score(y_true, y_pred, beta=1):
    # Calculates the F score, the weighted harmonic mean of precision and recall.
    if beta < 0:
        raise ValueError('The lowest choosable beta is zero (only precision).')
 
    # If there are no true positives, fix the F score at 0 like sklearn.
    if K.sum(K.round(K.clip(y_true, 0, 1))) == 0:
        return 0

    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    bb = beta ** 2
    fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
    return fbeta_score

def fmeasure(y_true, y_pred):
    # Calculates the f-measure, the harmonic mean of precision and recall.
    return fbeta_score(y_true, y_pred, beta=1)

# %%
#DNN               ############# test for noise adding  , function :: creat_data############

BATCH_SIZE = 64
NB_EPOCHS = 50
VALIDATION_SPLIT = 0.3

OPTIMIZER = Adamax()

historys_DNN = []
NB_tech = [4,4,4,4]

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)


print('Pad sequences to ',maxlen)
print('ready for 4')
X_4,y_4 = random_launch(X_train,y_train,NB_tech[0])
X_4 = sequence.pad_sequences(X_4, maxlen=maxlen,padding='post',truncating='post')
y_4 = np_utils.to_categorical(y_4, NB_CLASSES)
'''
print('ready for 3')
X_3,y_3 = random_launch(X_train,y_train,NB_tech[1])
X_3 = sequence.pad_sequences(X_3, maxlen=maxlen,padding='post',truncating='post')
X_3 = X_3[:,:,np.newaxis]
y_3 = np_utils.to_categorical(y_3, NB_CLASSES)
print('ready for 2')
X_2,y_2 = random_launch(X_train,y_train,NB_tech[2])
X_2 = sequence.pad_sequences(X_2, maxlen=maxlen,padding='post',truncating='post')
X_2 = X_2[:,:,np.newaxis]
y_2 = np_utils.to_categorical(y_2, NB_CLASSES)
print('ready for 1')
X_1,y_1 = random_launch(X_train,y_train,NB_tech[3])
X_1 = sequence.pad_sequences(X_1, maxlen=maxlen,padding='post',truncating='post')
X_1 = X_1[:,:,np.newaxis]
y_1 = np_utils.to_categorical(y_1, NB_CLASSES)

'''
X_train = sequence.pad_sequences(X_train, maxlen=maxlen,padding='post',truncating='post')
y_train = np_utils.to_categorical(y_train, NB_CLASSES)
X_test = sequence.pad_sequences(X_test, maxlen=maxlen,padding='post',truncating='post')
y_test = np_utils.to_categorical(y_test, NB_CLASSES)

print('the shape of x_train',X_train.shape)
print('the shape of y_train',y_train.shape)
print('the shape of x_test',X_test.shape)
print('the shape of y_test',y_test.shape)

model_DNN = DNN(maxlen,NB_CLASSES)
model_DNN.summary()
model_DNN.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])


history_DNN_loss = []
history_DNN_acc = []
history_DNN_precision = []
history_DNN_recall = []
history_DNN_fmeasure = []
history_DNN_val_loss = []
history_DNN_val_acc = []
history_DNN_val_precision = []
history_DNN_val_recall = []
history_DNN_val_fmeasure = []

def recorder_DNN(history):
    history_DNN_loss.append(history.history['loss'][0])
    history_DNN_acc.append(history.history['acc'][0])
    history_DNN_precision.append(history.history['precision'][0])
    history_DNN_recall.append(history.history['recall'][0])
    history_DNN_fmeasure.append(history.history['fmeasure'][0])
    history_DNN_val_loss.append(history.history['val_loss'][0])
    history_DNN_val_acc.append(history.history['val_acc'][0])
    history_DNN_val_precision.append(history.history['val_precision'][0])
    history_DNN_val_recall.append(history.history['val_recall'][0])
    history_DNN_val_fmeasure.append(history.history['val_fmeasure'][0])


for i in range(NB_EPOCHS):
    if (i<=NB_EPOCHS/5):
        history = model_DNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)
    elif (NB_EPOCHS/5<i and i%2==1 and i<(NB_EPOCHS*4/5)):
        history = model_DNN.fit(X_4,y_4,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)
    elif (NB_EPOCHS/5<i and i%2==0 and i<(NB_EPOCHS*4/5)):
        history = model_DNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)
    else:
        history = model_DNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)

print('base_line_now#######################################################################################################################################################################################################')
model_DNN_org = DNN(maxlen,NB_CLASSES)
model_DNN_org.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])
history_DNN_org = model_DNN_org.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=50,validation_data=(X_test,y_test),verbose=1)
# Out:
# Pad sequences to  6000
# ready for 4
# shuffling...
# transplanting...
# adding noise...
# deleting...
# the shape of x_train (7000, 6000)
# the shape of y_train (7000, 100)
# the shape of x_test (3000, 6000)
# the shape of y_test (3000, 100)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               768128
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               131584
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# activation_4 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               51300
# _________________________________________________________________
# activation_6 (Activation)    (None, 100)               0
# =================================================================
# Total params: 2,034,148
# Trainable params: 2,034,148
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 7000/7000 [==============================] - 10s 1ms/step - loss: 4.4867 - acc: 0.0224 - precision: 0.0000e+00 - recall: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 4.1944 - val_acc: 0.0333 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 1s 95us/step - loss: 4.1738 - acc: 0.0374 - precision: 0.0000e+00 - recall: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 3.9892 - val_acc: 0.0433 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 1s 96us/step - loss: 3.9259 - acc: 0.0476 - precision: 0.0000e+00 - recall: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 3.7662 - val_acc: 0.0620 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 1s 96us/step - loss: 3.8196 - acc: 0.0516 - precision: 0.0000e+00 - recall: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 3.6911 - val_acc: 0.0723 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 1s 97us/step - loss:
# 7000/7000 [==============================] - 1s 97us/step - loss: 2.3601 - acc: 0.3407 - precision: 0.5924 - recall: 0.1599 - fmeasure: 0.2496 - val_loss: 3.0471 - val_acc: 0.2413 - val_precision: 0.4030 - val_recall: 0.1147 - val_fmeasure: 0.1778
# Epoch 32/50
# 7000/7000 [==============================] - 1s 98us/step - loss: 2.3180 - acc: 0.3487 - precision: 0.5947 - recall: 0.1630 - fmeasure: 0.2543 - val_loss: 3.0477 - val_acc: 0.2453 - val_precision: 0.4112 - val_recall: 0.1147 - val_fmeasure: 0.1783
# Epoch 33/50
# 7000/7000 [==============================] - 1s 98us/step - loss: 2.3018 - acc: 0.3531 - precision: 0.6021 - recall: 0.1704 - fmeasure: 0.2634 - val_loss: 3.0534 - val_acc: 0.2540 - val_precision: 0.3916 - val_recall: 0.1197 - val_fmeasure: 0.1823
# Epoch 34/50
# 7000/7000 [==============================] - 1s 97us/step - loss: 2.2621 - acc: 0.3577 - precision: 0.5987 - recall: 0.1744 - fmeasure: 0.2685 - val_loss: 3.0153 - val_acc: 0.2463 - val_precision: 0.3892 - val_recall: 0.1153 - val_fmeasure: 0.1769
# Epoch 35/50
# 7000/7000 [==============================] - 1s 99us/step - loss: 2.2308 - acc: 0.3583 - precision: 0.5907 - recall: 0.1759 - fmeasure: 0.2695 - val_loss: 3.0491 - val_acc: 0.2520 - val_precision: 0.4049 - val_recall: 0.1273 - val_fmeasure: 0.1930
# Epoch 36/50
# 7000/7000 [==============================] - 1s 98us/step - loss: 2.2393 - acc: 0.3617 - precision: 0.5993 - recall: 0.1833 - fmeasure: 0.2792 - val_loss: 3.0418 - val_acc: 0.2370 - val_precision: 0.3675 - val_recall: 0.1080 - val_fmeasure: 0.1659
# Epoch 37/50
# 7000/7000 [==============================] - 1s 97us/step - loss: 2.1945 - acc: 0.3717 - precision: 0.6084 - recall: 0.1944 - fmeasure: 0.2925 - val_loss: 3.0535 - val_acc: 0.2450 - val_precision: 0.3643 - val_recall: 0.1067 - val_fmeasure: 0.1644
# Epoch 38/50
# 7000/7000 [==============================] - 1s 99us/step - loss: 2.1900 - acc: 0.3784 - precision: 0.6159 - recall: 0.1911 - fmeasure: 0.2894 - val_loss: 3.0370 - val_acc: 0.2570 - val_precision: 0.4033 - val_recall: 0.1233 - val_fmeasure: 0.1880
# Epoch 39/50
# 7000/7000 [==============================] - 1s 100us/step - loss: 2.1476 - acc: 0.3794 - precision: 0.6112 - recall: 0.2090 - fmeasure: 0.3094 - val_loss: 3.0288 - val_acc: 0.2537 - val_precision: 0.3782 - val_recall: 0.1213 - val_fmeasure: 0.1831
# Epoch 40/50
# 7000/7000 [==============================] - 1s 99us/step - loss: 2.1167 - acc: 0.3837 - precision: 0.6110 - recall: 0.2070 - fmeasure: 0.3074 - val_loss: 3.1023 - val_acc: 0.2517 - val_precision: 0.3724 - val_recall: 0.1303 - val_fmeasure: 0.1921
# Epoch 41/50
# 7000/7000 [==============================] - 1s 99us/step - loss: 2.1158 - acc: 0.3796 - precision: 0.6069 - recall: 0.2124 - fmeasure: 0.3130 - val_loss: 3.0782 - val_acc: 0.2503 - val_precision: 0.3740 - val_recall: 0.1253 - val_fmeasure: 0.1870
# Epoch 42/50
# 7000/7000 [==============================] - 1s 97us/step - loss: 2.1149 - acc: 0.3880 - precision: 0.6167 - recall: 0.2070 - fmeasure: 0.3084 - val_loss: 3.0852 - val_acc: 0.2620 - val_precision: 0.3890 - val_recall: 0.1297 - val_fmeasure: 0.1934
# Epoch 43/50
# 7000/7000 [==============================] - 1s 97us/step - loss: 2.0698 - acc: 0.3996 - precision: 0.6124 - recall: 0.2211 - fmeasure: 0.3228 - val_loss: 3.1912 - val_acc: 0.2440 - val_precision: 0.3589 - val_recall: 0.1247 - val_fmeasure: 0.1843
# Epoch 44/50
# 7000/7000 [==============================] - 1s 98us/step - loss: 2.0440 - acc: 0.4023 - precision: 0.6366 - recall: 0.2327 - fmeasure: 0.3386 - val_loss: 3.1286 - val_acc: 0.2540 - val_precision: 0.3714 - val_recall: 0.1377 - val_fmeasure: 0.2003
# Epoch 45/50
# 7000/7000 [==============================] - 1s 97us/step - loss: 2.0324 - acc: 0.4050 - precision: 0.6404 - recall: 0.2334 - fmeasure: 0.3403 - val_loss: 3.1242 - val_acc: 0.2493 - val_precision: 0.3760 - val_recall: 0.1380 - val_fmeasure: 0.2011
# Epoch 46/50
# 7000/7000 [==============================] - 1s 98us/step - loss: 2.0242 - acc: 0.4076 - precision: 0.6313 - recall: 0.2350 - fmeasure: 0.3410 - val_loss: 3.0813 - val_acc: 0.2500 - val_precision: 0.3728 - val_recall: 0.1267 - val_fmeasure: 0.1887
# Epoch 47/50
# 7000/7000 [==============================] - 1s 99us/step - loss: 1.9659 - acc: 0.4227 - precision: 0.6282 - recall: 0.2437 - fmeasure: 0.3491 - val_loss: 3.0837 - val_acc: 0.2653 - val_precision: 0.3813 - val_recall: 0.1467 - val_fmeasure: 0.2110
# Epoch 48/50
# 7000/7000 [==============================] - 1s 96us/step - loss: 1.9611 - acc: 0.4176 - precision: 0.6346 - recall: 0.2477 - fmeasure: 0.3546 - val_loss: 3.1475 - val_acc: 0.2473 - val_precision: 0.3733 - val_recall: 0.1303 - val_fmeasure: 0.1924
# Epoch 49/50
# 7000/7000 [==============================] - 1s 96us/step - loss: 1.9520 - acc: 0.4127 - precision: 0.6317 - recall: 0.2471 - fmeasure: 0.3536 - val_loss: 3.1205 - val_acc: 0.2603 - val_precision: 0.3786 - val_recall: 0.1483 - val_fmeasure: 0.2119
# Epoch 50/50
# 7000/7000 [==============================] - 1s 99us/step - loss: 1.9357 - acc: 0.4231 - precision: 0.6418 - recall: 0.2611 - fmeasure: 0.3691 - val_loss: 3.1531 - val_acc: 0.2617 - val_precision: 0.3602 - val_recall: 0.1423 - val_fmeasure: 0.2031

# %%
#CNN               ############# test for noise adding  , function :: creat_data############

BATCH_SIZE = 64
NB_EPOCHS = 50
VALIDATION_SPLIT = 0.3

OPTIMIZER = Adamax()

historys_DNN = []
NB_tech = [4,4,4,4]

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)


print('Pad sequences to ',maxlen)
print('ready for 4')
#X_4,y_4 = random_launch(X_train,y_train,NB_tech[0])
#X_4 = sequence.pad_sequences(X_4, maxlen=maxlen,padding='post',truncating='post')
X_4 = X_4[:,:,np.newaxis]
#y_4 = np_utils.to_categorical(y_4, NB_CLASSES)
'''
print('ready for 3')
X_3,y_3 = random_launch(X_train,y_train,NB_tech[1])
X_3 = sequence.pad_sequences(X_3, maxlen=maxlen,padding='post',truncating='post')
X_3 = X_3[:,:,np.newaxis]
y_3 = np_utils.to_categorical(y_3, NB_CLASSES)
print('ready for 2')
X_2,y_2 = random_launch(X_train,y_train,NB_tech[2])
X_2 = sequence.pad_sequences(X_2, maxlen=maxlen,padding='post',truncating='post')
X_2 = X_2[:,:,np.newaxis]
y_2 = np_utils.to_categorical(y_2, NB_CLASSES)
print('ready for 1')
X_1,y_1 = random_launch(X_train,y_train,NB_tech[3])
X_1 = sequence.pad_sequences(X_1, maxlen=maxlen,padding='post',truncating='post')
X_1 = X_1[:,:,np.newaxis]
y_1 = np_utils.to_categorical(y_1, NB_CLASSES)

'''
X_train = sequence.pad_sequences(X_train, maxlen=maxlen,padding='post',truncating='post')
X_train = X_train[:,:,np.newaxis]
y_train = np_utils.to_categorical(y_train, NB_CLASSES)
X_test = sequence.pad_sequences(X_test, maxlen=maxlen,padding='post',truncating='post')
X_test = X_test[:,:,np.newaxis]

y_test = np_utils.to_categorical(y_test, NB_CLASSES)

print('the shape of x_train',X_train.shape)
print('the shape of y_train',y_train.shape)
print('the shape of x_test',X_test.shape)
print('the shape of y_test',y_test.shape)
model_CNN = CNN(maxlen,NB_CLASSES)
model_CNN.summary()
model_CNN.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])




history_CNN_loss = []
history_CNN_acc = []
history_CNN_precision = []
history_CNN_recall = []
history_CNN_fmeasure = []
history_CNN_val_loss = []
history_CNN_val_acc = []
history_CNN_val_precision = []
history_CNN_val_recall = []
history_CNN_val_fmeasure = []

def recorder_CNN(history):
    history_CNN_loss.append(history.history['loss'][0])
    history_CNN_acc.append(history.history['acc'][0])
    history_CNN_precision.append(history.history['precision'][0])
    history_CNN_recall.append(history.history['recall'][0])
    history_CNN_fmeasure.append(history.history['fmeasure'][0])
    history_CNN_val_loss.append(history.history['val_loss'][0])
    history_CNN_val_acc.append(history.history['val_acc'][0])
    history_CNN_val_precision.append(history.history['val_precision'][0])
    history_CNN_val_recall.append(history.history['val_recall'][0])
    history_CNN_val_fmeasure.append(history.history['val_fmeasure'][0])


for i in range(NB_EPOCHS):
    if (i<=NB_EPOCHS/5):
        history = model_CNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)
    elif (NB_EPOCHS/5<i and i%2==1 and i<(NB_EPOCHS*4/5)):
        history = model_CNN.fit(X_4,y_4,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)
    elif (NB_EPOCHS/5<i and i%2==0 and i<(NB_EPOCHS*4/5)):
        history = model_CNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)
    else:
        history = model_CNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)

print('base_line_now')
model_CNN_org = CNN(maxlen,NB_CLASSES)
model_CNN_org.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])
history_CNN_org = model_CNN_org.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=50,validation_data=(X_test,y_test),verbose=1)
# Out:
# Pad sequences to  6000
# ready for 4
# the shape of x_train (7000, 6000, 1)
# the shape of y_train (7000, 100)
# the shape of x_test (3000, 6000, 1)
# the shape of y_test (3000, 100)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv1D)        (None, 6000, 32)          288
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 6000, 32)          128
# _________________________________________________________________
# block1_adv_act1 (ELU)        (None, 6000, 32)          0
# _________________________________________________________________
# block1_conv2 (Conv1D)        (None, 6000, 32)          8224
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 6000, 32)          128
# _________________________________________________________________
# block1_adv_act2 (ELU)        (None, 6000, 32)          0
# _________________________________________________________________
# block1_pool (MaxPooling1D)   (None, 1500, 32)          0
# _________________________________________________________________
# block1_dropout (Dropout)     (None, 1500, 32)          0
# _________________________________________________________________
# block2_conv1 (Conv1D)        (None, 1500, 64)          16448
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1500, 64)          256
# _________________________________________________________________
# block2_act1 (Activation)     (None, 1500, 64)          0
# _________________________________________________________________
# block2_conv2 (Conv1D)        (None, 1500, 64)          32832
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1500, 64)          256
# _________________________________________________________________
# block2_act2 (Activation)     (None, 1500, 64)          0
# _________________________________________________________________
# block2_pool (MaxPooling1D)   (None, 375, 64)           0
# _________________________________________________________________
# block2_dropout (Dropout)     (None, 375, 64)           0
# _________________________________________________________________
# block3_conv1 (Conv1D)        (None, 375, 128)          65664
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 375, 128)          512
# _________________________________________________________________
# block3_act1 (Activation)     (None, 375, 128)          0
# _________________________________________________________________
# block3_conv2 (Conv1D)        (None, 375, 128)          131200
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 375, 128)          512
# _________________________________________________________________
# block3_act2 (Activation)     (None, 375, 128)          0
# _________________________________________________________________
# block3_pool (MaxPooling1D)   (None, 94, 128)           0
# _________________________________________________________________
# block3_dropout (Dropout)     (None, 94, 128)           0
# _________________________________________________________________
# block4_conv1 (Conv1D)        (None, 94, 256)           262400
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 94, 256)           1024
# _________________________________________________________________
# block4_act1 (Activation)     (None, 94, 256)           0
# _________________________________________________________________
# block4_conv2 (Conv1D)        (None, 94, 256)           524544
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 94, 256)           1024
# _________________________________________________________________
# block4_act2 (Activation)     (None, 94, 256)           0
# _________________________________________________________________
# block4_pool (MaxPooling1D)   (None, 24, 256)           0
# _________________________________________________________________
# block4_dropout (Dropout)     (None, 24, 256)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 6144)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 512)               3146240
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 512)               2048
# _________________________________________________________________
# fc1_act (Activation)         (None, 512)               0
# _________________________________________________________________
# fc1_dropout (Dropout)        (None, 512)               0
# _________________________________________________________________
# fc2 (Dense)                  (None, 512)               262656
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# fc2_act (Activation)         (None, 512)               0
# _________________________________________________________________
# fc2_dropout (Dropout)        (None, 512)               0
# _________________________________________________________________
# fc3 (Dense)                  (None, 100)               51300
# _________________________________________________________________
# softmax (Activation)         (None, 100)               0
# =================================================================
# Total params: 4,509,732
# Trainable params: 4,505,764
# Non-trainable params: 3,968
# _________________________________________________________________
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 14s 2ms/step - loss: 4.4086 - acc: 0.0549 - precision: 0.0817 - recall: 0.0034 - fmeasure: 0.0065 - val_loss: 3.3472 - val_acc: 0.2160 - val_precision: 0.0853 - val_recall: 0.0013 - val_fmeasure: 0.0026
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 3.6497 - acc: 0.1193 - precision: 0.2723 - recall: 0.0107 - fmeasure: 0.0204 - val_loss: 3.2399 - val_acc: 0.2183 - val_precision: 0.0853 - val_recall: 0.0013 - val_fmeasure: 0.0026
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 3.3231 - acc: 0.1730 - precision: 0.3524 - recall: 0.0190 - fmeasure: 0.0357 - val_loss: 2.8851 - val_acc: 0.2933 - val_precision: 0.2773 - val_recall: 0.0053 - val_fmeasure: 0.0104
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss:
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.3098 - acc: 0.5817 - precision: 0.6666 - recall: 0.4259 - fmeasure: 0.5189 - val_loss: 1.3897 - val_acc: 0.5423 - val_precision: 0.5745 - val_recall: 0.4133 - val_fmeasure: 0.4801
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.2999 - acc: 0.5820 - precision: 0.6692 - recall: 0.4301 - fmeasure: 0.5229 - val_loss: 1.4493 - val_acc: 0.5410 - val_precision: 0.5808 - val_recall: 0.4307 - val_fmeasure: 0.4940
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.2778 - acc: 0.5830 - precision: 0.6700 - recall: 0.4387 - fmeasure: 0.5293 - val_loss: 1.4504 - val_acc: 0.5300 - val_precision: 0.5643 - val_recall: 0.4200 - val_fmeasure: 0.4810
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.2467 - acc: 0.5916 - precision: 0.6718 - recall: 0.4473 - fmeasure: 0.5361 - val_loss: 1.4806 - val_acc: 0.5257 - val_precision: 0.5564 - val_recall: 0.4257 - val_fmeasure: 0.4817
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.1923 - acc: 0.6097 - precision: 0.6911 - recall: 0.4697 - fmeasure: 0.5583 - val_loss: 1.4745 - val_acc: 0.5233 - val_precision: 0.5591 - val_recall: 0.4187 - val_fmeasure: 0.4780
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.1968 - acc: 0.6067 - precision: 0.6832 - recall: 0.4707 - fmeasure: 0.5564 - val_loss: 1.5170 - val_acc: 0.5113 - val_precision: 0.5343 - val_recall: 0.4153 - val_fmeasure: 0.4669
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.1639 - acc: 0.6164 - precision: 0.7025 - recall: 0.4816 - fmeasure: 0.5706 - val_loss: 1.5509 - val_acc: 0.5133 - val_precision: 0.5372 - val_recall: 0.4223 - val_fmeasure: 0.4722
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.1266 - acc: 0.6239 - precision: 0.7056 - recall: 0.4990 - fmeasure: 0.5837 - val_loss: 1.5531 - val_acc: 0.5123 - val_precision: 0.5377 - val_recall: 0.4277 - val_fmeasure: 0.4760
# base_line_now
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/50
# 7000/7000 [==============================] - 10s 1ms/step - loss: 4.4640 - acc: 0.0559 - precision: 0.0951 - recall: 0.0027 - fmeasure: 0.0052 - val_loss: 3.4334 - val_acc: 0.1580 - val_precision: 0.4046 - val_recall: 0.0113 - val_fmeasure: 0.0219
# Epoch 2/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 3.7054 - acc: 0.1227 - precision: 0.2621 - recall: 0.0103 - fmeasure: 0.0196 - val_loss: 3.0665 - val_acc: 0.2587 - val_precision: 0.3911 - val_recall: 0.0083 - val_fmeasure: 0.0163
# Epoch 3/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 3.3679 - acc: 0.1629 - precision: 0.2814 - recall: 0.0159 - fmeasure: 0.0297 - val_loss: 2.9269 - val_acc: 0.2733 - val_precision: 0.3271 - val_recall: 0.0080 - val_fmeasure: 0.0155
# Epoch 4/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 3.0832 - acc: 0.2181 - precision: 0.4334 - recall: 0.0321 - fmeasure: 0.0591 - val_loss: 2.9623 - val_acc: 0.2633 - val_precision: 0.3093 - val_recall: 0.0070 - val_fmeasure: 0.0136
# Epoch 5/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.9045 - acc: 0.2473 - precision: 0.4974 - recall: 0.0516 - fmeasure: 0.0924 - val_loss: 2.5355 - val_acc: 0.3630 - val_precision: 0.6505 - val_recall: 0.0510 - val_fmeasure: 0.0936
# Epoch 6/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.7557 - acc: 0.2840 - precision: 0.5261 - recall: 0.0684 - fmeasure: 0.1198 - val_loss: 2.4044 - val_acc: 0.3760 - val_precision: 0.5730 - val_recall: 0.0970 - val_fmeasure: 0.1641
# Epoch 7/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.6250 - acc: 0.3091 - precision: 0.5101 - recall: 0.0881 - fmeasure: 0.1490 - val_loss: 2.2645 - val_acc: 0.4077 - val_precision: 0.6018 - val_recall: 0.1303 - val_fmeasure: 0.2126
# Epoch 8/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.5254 - acc: 0.3299 - precision: 0.5266 - recall: 0.1046 - fmeasure: 0.1730 - val_loss: 2.1744 - val_acc: 0.4217 - val_precision: 0.5966 - val_recall: 0.1737 - val_fmeasure: 0.2677
# Epoch 9/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.4151 - acc: 0.3531 - precision: 0.5516 - recall: 0.1254 - fmeasure: 0.2029 - val_loss: 2.1625 - val_acc: 0.4207 - val_precision: 0.5807 - val_recall: 0.2257 - val_fmeasure: 0.3234
# Epoch 10/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.3637 - acc: 0.3544 - precision: 0.5381 - recall: 0.1354 - fmeasure: 0.2150 - val_loss: 2.0643 - val_acc: 0.4407 - val_precision: 0.5976 - val_recall: 0.1930 - val_fmeasure: 0.2904
# Epoch 11/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.3005 - acc: 0.3887 - precision: 0.5593 - recall: 0.1569 - fmeasure: 0.2436 - val_loss: 2.1095 - val_acc: 0.4403 - val_precision: 0.5783 - val_recall: 0.2197 - val_fmeasure: 0.3167
# Epoch 12/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.2204 - acc: 0.3854 - precision: 0.5576 - recall: 0.1657 - fmeasure: 0.2541 - val_loss: 2.1181 - val_acc: 0.4350 - val_precision: 0.5794 - val_recall: 0.1753 - val_fmeasure: 0.2679
# Epoch 13/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.1605 - acc: 0.4037 - precision: 0.5711 - recall: 0.1826 - fmeasure: 0.2753 - val_loss: 2.0094 - val_acc: 0.4480 - val_precision: 0.5846 - val_recall: 0.1973 - val_fmeasure: 0.2937
# Epoch 14/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.1403 - acc: 0.4070 - precision: 0.5702 - recall: 0.1921 - fmeasure: 0.2856 - val_loss: 2.0069 - val_acc: 0.4623 - val_precision: 0.5765 - val_recall: 0.2813 - val_fmeasure: 0.3766
# Epoch 15/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.0883 - acc: 0.4186 - precision: 0.5677 - recall: 0.1946 - fmeasure: 0.2883 - val_loss: 1.9687 - val_acc: 0.4580 - val_precision: 0.5847 - val_recall: 0.2540 - val_fmeasure: 0.3523
# Epoch 16/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.0110 - acc: 0.4304 - precision: 0.5897 - recall: 0.2144 - fmeasure: 0.3131 - val_loss: 1.9558 - val_acc: 0.4643 - val_precision: 0.5607 - val_recall: 0.2573 - val_fmeasure: 0.3516
# Epoch 17/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.9843 - acc: 0.4423 - precision: 0.5920 - recall: 0.2294 - fmeasure: 0.3293 - val_loss: 1.9296 - val_acc: 0.4723 - val_precision: 0.5676 - val_recall: 0.2877 - val_fmeasure: 0.3807
# Epoch 18/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.9676 - acc: 0.4481 - precision: 0.5951 - recall: 0.2283 - fmeasure: 0.3287 - val_loss: 1.9255 - val_acc: 0.4590 - val_precision: 0.5645 - val_recall: 0.2633 - val_fmeasure: 0.3577
# Epoch 19/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.9075 - acc: 0.4570 - precision: 0.6029 - recall: 0.2487 - fmeasure: 0.3506 - val_loss: 1.8773 - val_acc: 0.4777 - val_precision: 0.5576 - val_recall: 0.2770 - val_fmeasure: 0.3691
# Epoch 20/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.8565 - acc: 0.4709 - precision: 0.5925 - recall: 0.2581 - fmeasure: 0.3581 - val_loss: 1.8931 - val_acc: 0.4703 - val_precision: 0.5514 - val_recall: 0.2760 - val_fmeasure: 0.3670
# Epoch 21/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.8372 - acc: 0.4713 - precision: 0.6109 - recall: 0.2643 - fmeasure: 0.3675 - val_loss: 1.8605 - val_acc: 0.4803 - val_precision: 0.5641 - val_recall: 0.3310 - val_fmeasure: 0.4165
# Epoch 22/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.7958 - acc: 0.4867 - precision: 0.6259 - recall: 0.2820 - fmeasure: 0.3876 - val_loss: 1.8619 - val_acc: 0.4790 - val_precision: 0.5573 - val_recall: 0.2967 - val_fmeasure: 0.3856
# Epoch 23/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.7656 - acc: 0.4820 - precision: 0.6256 - recall: 0.2877 - fmeasure: 0.3928 - val_loss: 1.8525 - val_acc: 0.4733 - val_precision: 0.5562 - val_recall: 0.3227 - val_fmeasure: 0.4074
# Epoch 24/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.7590 - acc: 0.4869 - precision: 0.6125 - recall: 0.2929 - fmeasure: 0.3951 - val_loss: 1.8888 - val_acc: 0.4730 - val_precision: 0.5455 - val_recall: 0.3250 - val_fmeasure: 0.4063
# Epoch 25/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.7249 - acc: 0.4984 - precision: 0.6238 - recall: 0.3053 - fmeasure: 0.4089 - val_loss: 1.9370 - val_acc: 0.4607 - val_precision: 0.5349 - val_recall: 0.3050 - val_fmeasure: 0.3872
# Epoch 26/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.6878 - acc: 0.5046 - precision: 0.6194 - recall: 0.3120 - fmeasure: 0.4137 - val_loss: 1.8791 - val_acc: 0.4807 - val_precision: 0.5543 - val_recall: 0.3250 - val_fmeasure: 0.4088
# Epoch 27/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.6483 - acc: 0.5130 - precision: 0.6423 - recall: 0.3236 - fmeasure: 0.4291 - val_loss: 1.8867 - val_acc: 0.4627 - val_precision: 0.5308 - val_recall: 0.3310 - val_fmeasure: 0.4069
# Epoch 28/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.6204 - acc: 0.5219 - precision: 0.6417 - recall: 0.3320 - fmeasure: 0.4363 - val_loss: 1.8812 - val_acc: 0.4723 - val_precision: 0.5295 - val_recall: 0.3320 - val_fmeasure: 0.4072
# Epoch 29/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.5810 - acc: 0.5257 - precision: 0.6430 - recall: 0.3426 - fmeasure: 0.4458 - val_loss: 1.8946 - val_acc: 0.4737 - val_precision: 0.5263 - val_recall: 0.3450 - val_fmeasure: 0.4161
# Epoch 30/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.5621 - acc: 0.5327 - precision: 0.6468 - recall: 0.3511 - fmeasure: 0.4538 - val_loss: 1.9100 - val_acc: 0.4670 - val_precision: 0.5334 - val_recall: 0.3523 - val_fmeasure: 0.4236
# Epoch 31/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.5608 - acc: 0.5204 - precision: 0.6386 - recall: 0.3427 - fmeasure: 0.4448 - val_loss: 1.8922 - val_acc: 0.4707 - val_precision: 0.5171 - val_recall: 0.3397 - val_fmeasure: 0.4092
# Epoch 32/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.5073 - acc: 0.5406 - precision: 0.6556 - recall: 0.3723 - fmeasure: 0.4739 - val_loss: 1.8885 - val_acc: 0.4670 - val_precision: 0.5178 - val_recall: 0.3537 - val_fmeasure: 0.4196
# Epoch 33/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.5103 - acc: 0.5451 - precision: 0.6609 - recall: 0.3823 - fmeasure: 0.4832 - val_loss: 1.8786 - val_acc: 0.4690 - val_precision: 0.5108 - val_recall: 0.3370 - val_fmeasure: 0.4055
# Epoch 34/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.4802 - acc: 0.5483 - precision: 0.6676 - recall: 0.3820 - fmeasure: 0.4844 - val_loss: 1.9057 - val_acc: 0.4610 - val_precision: 0.5016 - val_recall: 0.3320 - val_fmeasure: 0.3988
# Epoch 35/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.4645 - acc: 0.5459 - precision: 0.6497 - recall: 0.3817 - fmeasure: 0.4797 - val_loss: 1.9549 - val_acc: 0.4540 - val_precision: 0.4952 - val_recall: 0.3473 - val_fmeasure: 0.4077
# Epoch 36/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.4217 - acc: 0.5566 - precision: 0.6640 - recall: 0.3921 - fmeasure: 0.4921 - val_loss: 1.9090 - val_acc: 0.4597 - val_precision: 0.5011 - val_recall: 0.3450 - val_fmeasure: 0.4080
# Epoch 37/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.3931 - acc: 0.5659 - precision: 0.6729 - recall: 0.4047 - fmeasure: 0.5043 - val_loss: 1.9496 - val_acc: 0.4657 - val_precision: 0.5070 - val_recall: 0.3713 - val_fmeasure: 0.4281
# Epoch 38/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.3939 - acc: 0.5663 - precision: 0.6683 - recall: 0.4091 - fmeasure: 0.5068 - val_loss: 1.9286 - val_acc: 0.4613 - val_precision: 0.5004 - val_recall: 0.3567 - val_fmeasure: 0.4160
# Epoch 39/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.3671 - acc: 0.5741 - precision: 0.6768 - recall: 0.4207 - fmeasure: 0.5179 - val_loss: 1.9614 - val_acc: 0.4653 - val_precision: 0.5034 - val_recall: 0.3800 - val_fmeasure: 0.4327
# Epoch 40/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.3167 - acc: 0.5904 - precision: 0.6915 - recall: 0.4399 - fmeasure: 0.5367 - val_loss: 1.9679 - val_acc: 0.4580 - val_precision: 0.4960 - val_recall: 0.3583 - val_fmeasure: 0.4155
# Epoch 41/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.3118 - acc: 0.5799 - precision: 0.6809 - recall: 0.4409 - fmeasure: 0.5344 - val_loss: 1.9837 - val_acc: 0.4523 - val_precision: 0.4944 - val_recall: 0.3623 - val_fmeasure: 0.4172
# Epoch 42/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.2959 - acc: 0.6003 - precision: 0.6892 - recall: 0.4474 - fmeasure: 0.5417 - val_loss: 2.0090 - val_acc: 0.4513 - val_precision: 0.4856 - val_recall: 0.3617 - val_fmeasure: 0.4140
# Epoch 43/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.2925 - acc: 0.5830 - precision: 0.6819 - recall: 0.4414 - fmeasure: 0.5350 - val_loss: 1.9669 - val_acc: 0.4557 - val_precision: 0.4877 - val_recall: 0.3543 - val_fmeasure: 0.4098
# Epoch 44/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.2889 - acc: 0.5974 - precision: 0.6902 - recall: 0.4580 - fmeasure: 0.5499 - val_loss: 1.9580 - val_acc: 0.4560 - val_precision: 0.4952 - val_recall: 0.3627 - val_fmeasure: 0.4183
# Epoch 45/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.2811 - acc: 0.5971 - precision: 0.6851 - recall: 0.4517 - fmeasure: 0.5436 - val_loss: 2.0562 - val_acc: 0.4513 - val_precision: 0.4825 - val_recall: 0.3827 - val_fmeasure: 0.4264
# Epoch 46/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.2470 - acc: 0.6054 - precision: 0.6889 - recall: 0.4587 - fmeasure: 0.5498 - val_loss: 2.0486 - val_acc: 0.4393 - val_precision: 0.4678 - val_recall: 0.3533 - val_fmeasure: 0.4023
# Epoch 47/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.2486 - acc: 0.5937 - precision: 0.6867 - recall: 0.4670 - fmeasure: 0.5549 - val_loss: 2.0503 - val_acc: 0.4463 - val_precision: 0.4753 - val_recall: 0.3600 - val_fmeasure: 0.4091
# Epoch 48/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.2448 - acc: 0.6033 - precision: 0.6936 - recall: 0.4637 - fmeasure: 0.5550 - val_loss: 2.0626 - val_acc: 0.4400 - val_precision: 0.4715 - val_recall: 0.3540 - val_fmeasure: 0.4039
# Epoch 49/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.1860 - acc: 0.6210 - precision: 0.7047 - recall: 0.4844 - fmeasure: 0.5734 - val_loss: 2.0126 - val_acc: 0.4447 - val_precision: 0.4694 - val_recall: 0.3503 - val_fmeasure: 0.4007
# Epoch 50/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.1850 - acc: 0.6184 - precision: 0.6990 - recall: 0.4827 - fmeasure: 0.5702 - val_loss: 2.0599 - val_acc: 0.4453 - val_precision: 0.4693 - val_recall: 0.3600 - val_fmeasure: 0.4071

# %%
import matplotlib.pylab as plt


fig,axs = plt.subplots(1,5,figsize=(30,10))
axs[0].plot(range(NB_EPOCHS),history_DNN_org.history['val_loss'],label='before')
axs[0].plot(range(NB_EPOCHS),history_DNN_val_loss,label='after')
axs[0].set_title('val_loss')

axs[1].plot(range(NB_EPOCHS),history_DNN_org.history['val_acc'],label='before')
axs[1].plot(range(NB_EPOCHS),history_DNN_val_acc,label='after')
axs[1].set_title('val_acc')

axs[2].plot(range(NB_EPOCHS),history_DNN_org.history['val_precision'],label='before')
axs[2].plot(range(NB_EPOCHS),history_DNN_val_precision,label='after')
axs[2].set_title('val_precision')

axs[3].plot(range(NB_EPOCHS),history_DNN_org.history['val_recall'],label='before')
axs[3].plot(range(NB_EPOCHS),history_DNN_val_recall,label='after')
axs[3].set_title('val_recall')

axs[4].plot(range(NB_EPOCHS),history_DNN_org.history['val_fmeasure'],label='before')
axs[4].plot(range(NB_EPOCHS),history_DNN_val_fmeasure,label='after')
axs[4].set_title('val_fmeasure')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center')

plt.show()

# %%
import matplotlib.pylab as plt


fig,axs = plt.subplots(1,5,figsize=(30,10))
axs[0].plot(range(NB_EPOCHS),history_CNN_org.history['val_loss'],label='before')
axs[0].plot(range(NB_EPOCHS),history_CNN_val_loss,label='after')
axs[0].set_title('val_loss')

axs[1].plot(range(NB_EPOCHS),history_CNN_org.history['val_acc'],label='before')
axs[1].plot(range(NB_EPOCHS),history_CNN_val_acc,label='after')
axs[1].set_title('val_acc')

axs[2].plot(range(NB_EPOCHS),history_CNN_org.history['val_precision'],label='before')
axs[2].plot(range(NB_EPOCHS),history_CNN_val_precision,label='after')
axs[2].set_title('val_precision')

axs[3].plot(range(NB_EPOCHS),history_CNN_org.history['val_recall'],label='before')
axs[3].plot(range(NB_EPOCHS),history_CNN_val_recall,label='after')
axs[3].set_title('val_recall')

axs[4].plot(range(NB_EPOCHS),history_CNN_org.history['val_fmeasure'],label='before')
axs[4].plot(range(NB_EPOCHS),history_CNN_val_fmeasure,label='after')
axs[4].set_title('val_fmeasure')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center')

plt.show()

# %%
history_CNN_org.history['val_acc']
# Out:
# [0.15800000001986822,
#  0.2586666665871938,
#  0.27333333321412406,
#  0.2633333332538605,
#  0.3629999999205271,
#  0.3759999998807907,
#  0.4076666664282481,
#  0.4216666667461395,
#  0.4206666667461395,
#  0.44066666650772096,
#  0.44033333309491474,
#  0.4349999998410543,
#  0.4480000001589457,
#  0.4623333334128062,
#  0.4579999997615814,
#  0.46433333357175194,
#  0.4723333335717519,
#  0.45900000007947284,
#  0.47766666642824807,
#  0.47033333325386045,
#  0.48033333325386046,
#  0.47900000007947285,
#  0.47333333333333333,
#  0.47299999992052716,
#  0.46066666690508523,
#  0.48066666690508525,
#  0.4626666665871938,
#  0.4723333334128062,
#  0.47366666674613955,
#  0.4670000002384186,
#  0.4706666665871938,
#  0.46700000007947284,
#  0.469,
#  0.46099999992052715,
#  0.4540000000794729,
#  0.4596666665077209,
#  0.4656666666666667,
#  0.4613333334128062,
#  0.4653333334128062,
#  0.45799999992052715,
#  0.4523333331743876,
#  0.4513333331743876,
#  0.45566666666666666,
#  0.45599999984105427,
#  0.4513333333333333,
#  0.4393333331743876,
#  0.4463333332538605,
#  0.43999999984105426,
#  0.44466666666666665,
#  0.4453333334128062]

# %%
history_CNN_val_acc
# Out:
# [0.21600000007947287,
#  0.21833333325386048,
#  0.293333333214124,
#  0.3343333334128062,
#  0.3443333334128062,
#  0.37666666650772096,
#  0.4093333334128062,
#  0.41766666642824807,
#  0.4149999998410543,
#  0.3976666668256124,
#  0.44799999984105426,
#  0.44033333333333335,
#  0.454666666507721,
#  0.4543333332538605,
#  0.47400000007947285,
#  0.48166666642824807,
#  0.48900000023841855,
#  0.4939999999205271,
#  0.5043333334128062,
#  0.5153333330949148,
#  0.5203333332538604,
#  0.5323333332538605,
#  0.5246666665871939,
#  0.5403333330949147,
#  0.5260000001589458,
#  0.5406666664282481,
#  0.5426666668256124,
#  0.5609999997615814,
#  0.5476666664282481,
#  0.5670000001589457,
#  0.5490000001589457,
#  0.5646666666666667,
#  0.556,
#  0.5746666666666667,
#  0.5603333330154419,
#  0.5809999998410543,
#  0.5649999996821086,
#  0.5799999996821086,
#  0.5579999995231628,
#  0.5833333333333334,
#  0.5683333334922791,
#  0.5566666668256124,
#  0.5423333330154418,
#  0.5409999997615814,
#  0.5299999997615814,
#  0.5256666664282481,
#  0.5233333332538604,
#  0.5113333332538604,
#  0.5133333334128062,
#  0.5123333332538604]
