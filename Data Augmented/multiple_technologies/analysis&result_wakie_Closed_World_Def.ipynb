# %% [markdown]
# <a href="https://colab.research.google.com/github/sunxueliang96/WF-FrameWork/blob/master/Data%20Augmented/multiple_technologies/analysis%26result_wakie_Closed_World_Def.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#cd /content/drive/'My Drive'/datasets/no_paded/open_world/walkiebatch

# %%
#datatype_Close = False   #Flase is Open_World, True is Closed World.

# %%
cd /content/drive/'My Drive'/datasets/no_paded/close_world/walkiebatch_defended
# Out:
# /content/drive/My Drive/datasets/no_paded/close_world/walkiebatch_defended

# %%
datatype_Close = True   #Flase is Open_World, True is Closed World.

# %%
ls
# Out:
# X_walkiebatch_defended.pkl  y_walkiebatch_defended.pkl

# %%
import numpy as np
import pickle

print('loading data...')
with open('X_walkiebatch_defended.pkl','rb') as handle:
  X = np.array(pickle.load(handle))
with open('y_walkiebatch_defended.pkl','rb') as handle:
  y = np.array(pickle.load(handle))
print('the shape of X',X.shape)
print('the shape of y',y.shape)
# Out:
# loading data...
# the shape of X (10000,)
# the shape of y (10000,)

# %%
import math 
import random
def fun_noise(X,y,PERCENT_NOISE,TIMES_NOISE): 
    X = list(X)
    y = list(y)
    X_sum = []
    y_sum = []
    #X_sum = X.copy()
    #y_sum = y.copy()
    #print("{} samples has beed add to X_train, {}% of noise for each sample".format(math.ceil(len(X)*TIMES_NOISE),PERCENT_NOISE))
    for i in range(math.ceil(len(X)*TIMES_NOISE)): #ADDING NOISE from here 
        while(True):
            p = random.choice(range(len(X)))
            if(y[p]!=-1):
                break
            else:
                pass
        X_new = X[p].copy()
        y_new = y[p]
        for n in range(math.ceil(PERCENT_NOISE*len(X_new)/100)):#dealing X_new
            noise = random.choice([1,-1])       #noise could only be 1 or -1
            pos = random.choice(range(len(X_new)))  #position belong to (0,len(sequence))
            X_new.insert(pos,noise)
            #print('insert {} at position {} in sequence {} now len of sequence is {}, the tag of sequence is {}'.format(noise,pos,p,len(X_new),y_new)) #for test
        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum
def fun_delete(X,y,PERCENT_DELETE,TIMES_DELETE): 
    X = list(X)
    y = list(y)
    X_sum = []
    y_sum = []
    #X_sum = X.copy()
    #y_sum = y.copy()

    for i in range(math.ceil(len(X)*TIMES_DELETE)): #RANDOM DELETE from here
        while(True):
            p = random.choice(range(len(X)))
            if(y[p]!=-1):
                break
            else:
                #print('-1 detected')
                pass
        X_new = X[p].copy()
        y_new = y[p]
        for n in range(math.ceil(PERCENT_DELETE*len(X_new)/100)):#dealing X_new
            pos = random.choice(range(len(X_new)))  #position belong to (0,len(sequence))
            del X_new[pos]
            #print('insert {} at position {} in sequence {} now len of sequence is {}'.format(noise,pos,p,len(X_new))) #for test
        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum
def fun_shuffle(X,y,PERCENT_CHANGED,TIMES_SHUFFLE): 
    X = list(X)
    y = list(y)
    #X_sum = X.copy()
    #y_sum = y.copy()
    X_sum = []
    y_sum = []
    for i in range(math.ceil(len(X)*TIMES_SHUFFLE)):             #LOCALLY CHANGE from here
        while(True):
            p = random.choice(range(len(X)))
            if(y[p]!=-1):
                break
            else:
                #print('-1 detected')
                pass
        X_new = X[p].copy()
        y_new = y[p]
        length = math.ceil(PERCENT_CHANGED*len(X_new)/100)
        start = random.choice(range(len(X_new)-length))
        temp = X_new[start:start+length]
        random.shuffle(temp)
        X_new[start:start+length] = temp

        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum
def fun_transplant(X,y,PERCENT_TRANSPLANT,NB_TIMES):        #Magnificate dataset by adding noising randomly
    global datatype_Close
    X = list(X)
    y = list(y)
    X_sum = []
    y_sum = []
    #X_sum = X.copy()
    #y_sum = y.copy()
    #print("{} samples has beed add to X_train, {}% of noise for each sample".format(math.ceil(len(X)*NB_TIMES),PERCENT_TRANSPLANT))
    for i in range(math.ceil(len(X)*NB_TIMES)):
        #print(datatype_Close)    
        while(datatype_Close):                               # target pos p (sensitive website), pos q (non-sensitive website)
            p = random.choice(range(len(X)))
            q = random.choice(range(len(X)))
            if(p != q):                           # Closed_World
                break
            else:
                #print('-1 detected')
                pass
        while(not datatype_Close):                               # target pos p (sensitive website), pos q (non-sensitive website)
            p = random.choice(range(len(X)))
            q = random.choice(range(len(X)))
            if(y[p]!=-1 and y[q]==-1):               # open_world
                break
            else:
                #print('-1 detected')
                pass
        X_new = X[p].copy()
        target = X[q].copy()
        y_new = y[p]

        length_X = math.ceil(PERCENT_TRANSPLANT*len(X_new)/100)
        length_target =  math.ceil(PERCENT_TRANSPLANT*len(target)/100)
        start_X = random.choice(range(len(X_new)-length_X))
        start_target = random.choice(range(len(target)-length_target))
        temp = target[start_target:start_target+length_target]
        X_new[start_X:start_X+length_X] = temp
     
        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum
'''
def random_launch(X,y,NB_tech):
    X = list(X)
    y = list(y)
    X_sum = X.copy()
    y_sum = y.copy()
    launch_list = random.sample(range(4),NB_tech)             #return [0,1,....]....depending on NB_tech
    for i in launch_list:
        if (i==0):
            print('adding noise...')
            X_new,y_new = fun_noise(X,y,PERCENT_NOISE=20,TIMES_NOISE=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==1):
            print('deleting...')
            X_new,y_new = fun_delete(X,y,PERCENT_DELETE=20,TIMES_DELETE=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==2):
            print('shuffling...')
            X_new,y_new = fun_shuffle(X,y,PERCENT_CHANGED=20,TIMES_SHUFFLE=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==3):
            print('transplanting...')
            X_new,y_new = fun_transplant(X,y,PERCENT_TRANSPLANT=20,NB_TIMES=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
    return np.array(X_sum),np.array(y_sum)                        #return two array of X, y 
    '''
def random_launch(X,y,NB_tech):
    X = list(X)
    y = list(y)
    X_sum = X.copy()
    y_sum = y.copy()
    launch_list = random.sample(range(4),NB_tech)             #return [0,1,....]....depending on NB_tech
    for i in launch_list:
        if (i==0):
            print('adding noise...')
            X_new,y_new = fun_noise(X,y,PERCENT_NOISE=50,TIMES_NOISE=1)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==1):
            print('deleting...')
            X_new,y_new = fun_delete(X,y,PERCENT_DELETE=50,TIMES_DELETE=1)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==2):
            print('shuffling...')
            X_new,y_new = fun_shuffle(X,y,PERCENT_CHANGED=50,TIMES_SHUFFLE=1)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==3):
            print('transplanting...')
            X_new,y_new = fun_transplant(X,y,PERCENT_TRANSPLANT=50,NB_TIMES=1)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
    return np.array(X_sum),np.array(y_sum)                        #return two array of X, y

# %%
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing import sequence
from collections import Counter
#CLASSES_KNN = 101########################################################################################################################################################################################################
#CLASSES_WAKIE = 100########################################################################################################################################################################################################
MAXLEN_KNN = 2000
MAXLEN_WAKIE =5000

maxlen = 6000
NB_CLASSES = 0

def choose():
    global maxlen,NB_CLASSES
    print('if padding, the max of length of seq is {}'.format(maxlen))
    NB_CLASSES = len(Counter(y).keys())
    print('number of classes is {}'.format(NB_CLASSES))

choose()################################################################################################################################################################################################################

print('Average sequence length: {}'.format(np.mean(list(map(len, X)), dtype=int)))
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# if padding, the max of length of seq is 6000
# number of classes is 100
# Average sequence length: 5933

# %%
#FCN
from keras import Sequential
from keras.layers.core import Activation, Flatten, Dense, Dropout
from keras.optimizers import Adamax
def DNN(input_shape,classes):
    model = Sequential()
    model.add(Dense(128, input_shape=(input_shape,)))
    model.add(Activation('relu'))
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dense(512))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dense(classes))
    model.add(Activation('softmax'))
    return model

# %%
#CNN
from keras import Input,Model,Sequential
from keras.layers import Embedding,GlobalAveragePooling1D,Dense,Dropout
from keras.layers import Conv1D, MaxPooling1D, BatchNormalization
from keras.layers.core import Activation, Flatten, Dense, Dropout
from keras.layers.advanced_activations import ELU
from keras.initializers import glorot_uniform
from keras.optimizers import Adamax
def CNN(input_shape, classes):
    model = Sequential()
    #Block1
    filter_num = ['None',32,64,128,256]
    kernel_size = ['None',8,8,8,8]
    conv_stride_size = ['None',1,1,1,1]
    pool_stride_size = ['None',4,4,4,4]
    pool_size = ['None',8,8,8,8]

    model.add(Conv1D(filters=filter_num[1], kernel_size=kernel_size[1], input_shape=(input_shape,1),
                      strides=conv_stride_size[1], padding='same',
                      name='block1_conv1'))
    model.add(BatchNormalization(axis=-1))
    model.add(ELU(alpha=1.0, name='block1_adv_act1'))
    model.add(Conv1D(filters=filter_num[1], kernel_size=kernel_size[1],
                      strides=conv_stride_size[1], padding='same',
                      name='block1_conv2'))
    model.add(BatchNormalization(axis=-1))
    model.add(ELU(alpha=1.0, name='block1_adv_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[1], strides=pool_stride_size[1],
                            padding='same', name='block1_pool'))
    model.add(Dropout(0.1, name='block1_dropout'))

    model.add(Conv1D(filters=filter_num[2], kernel_size=kernel_size[2],
                      strides=conv_stride_size[2], padding='same',
                      name='block2_conv1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block2_act1'))

    model.add(Conv1D(filters=filter_num[2], kernel_size=kernel_size[2],
                      strides=conv_stride_size[2], padding='same',
                      name='block2_conv2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block2_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[2], strides=pool_stride_size[3],
                            padding='same', name='block2_pool'))
    model.add(Dropout(0.1, name='block2_dropout'))

    model.add(Conv1D(filters=filter_num[3], kernel_size=kernel_size[3],
                      strides=conv_stride_size[3], padding='same',
                      name='block3_conv1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block3_act1'))
    model.add(Conv1D(filters=filter_num[3], kernel_size=kernel_size[3],
                      strides=conv_stride_size[3], padding='same',
                      name='block3_conv2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block3_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[3], strides=pool_stride_size[3],
                            padding='same', name='block3_pool'))
    model.add(Dropout(0.1, name='block3_dropout'))

    model.add(Conv1D(filters=filter_num[4], kernel_size=kernel_size[4],
                      strides=conv_stride_size[4], padding='same',
                      name='block4_conv1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block4_act1'))
    model.add(Conv1D(filters=filter_num[4], kernel_size=kernel_size[4],
                      strides=conv_stride_size[4], padding='same',
                      name='block4_conv2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block4_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[4], strides=pool_stride_size[4],
                            padding='same', name='block4_pool'))
    model.add(Dropout(0.1, name='block4_dropout'))

    model.add(Flatten(name='flatten'))
    model.add(Dense(512, kernel_initializer=glorot_uniform(seed=0), name='fc1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='fc1_act'))

    model.add(Dropout(0.7, name='fc1_dropout'))

    model.add(Dense(512, kernel_initializer=glorot_uniform(seed=0), name='fc2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='fc2_act'))

    model.add(Dropout(0.5, name='fc2_dropout'))

    model.add(Dense(classes, kernel_initializer=glorot_uniform(seed=0), name='fc3'))
    model.add(Activation('softmax', name="softmax"))
    return model

# %%
import keras
from keras import backend as K

def precision(y_true, y_pred):
    # Calculates the precision
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    # Calculates the recall
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def fbeta_score(y_true, y_pred, beta=1):
    # Calculates the F score, the weighted harmonic mean of precision and recall.
    if beta < 0:
        raise ValueError('The lowest choosable beta is zero (only precision).')
 
    # If there are no true positives, fix the F score at 0 like sklearn.
    if K.sum(K.round(K.clip(y_true, 0, 1))) == 0:
        return 0

    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    bb = beta ** 2
    fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
    return fbeta_score

def fmeasure(y_true, y_pred):
    # Calculates the f-measure, the harmonic mean of precision and recall.
    return fbeta_score(y_true, y_pred, beta=1)

# %%
#DNN               ############# test for noise adding  , function :: creat_data############

BATCH_SIZE = 64
NB_EPOCHS = 50
VALIDATION_SPLIT = 0.3

OPTIMIZER = Adamax()

historys_DNN = []
NB_tech = [4,4,4,4]

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)


print('Pad sequences to ',maxlen)
print('ready for 4')
X_4,y_4 = random_launch(X_train,y_train,NB_tech[0])
X_4 = sequence.pad_sequences(X_4, maxlen=maxlen,padding='post',truncating='post')
y_4 = np_utils.to_categorical(y_4, NB_CLASSES)
'''
print('ready for 3')
X_3,y_3 = random_launch(X_train,y_train,NB_tech[1])
X_3 = sequence.pad_sequences(X_3, maxlen=maxlen,padding='post',truncating='post')
X_3 = X_3[:,:,np.newaxis]
y_3 = np_utils.to_categorical(y_3, NB_CLASSES)
print('ready for 2')
X_2,y_2 = random_launch(X_train,y_train,NB_tech[2])
X_2 = sequence.pad_sequences(X_2, maxlen=maxlen,padding='post',truncating='post')
X_2 = X_2[:,:,np.newaxis]
y_2 = np_utils.to_categorical(y_2, NB_CLASSES)
print('ready for 1')
X_1,y_1 = random_launch(X_train,y_train,NB_tech[3])
X_1 = sequence.pad_sequences(X_1, maxlen=maxlen,padding='post',truncating='post')
X_1 = X_1[:,:,np.newaxis]
y_1 = np_utils.to_categorical(y_1, NB_CLASSES)

'''
X_train = sequence.pad_sequences(X_train, maxlen=maxlen,padding='post',truncating='post')
y_train = np_utils.to_categorical(y_train, NB_CLASSES)
X_test = sequence.pad_sequences(X_test, maxlen=maxlen,padding='post',truncating='post')
y_test = np_utils.to_categorical(y_test, NB_CLASSES)

print('the shape of x_train',X_train.shape)
print('the shape of y_train',y_train.shape)
print('the shape of x_test',X_test.shape)
print('the shape of y_test',y_test.shape)

model_DNN = DNN(maxlen,NB_CLASSES)
model_DNN.summary()
model_DNN.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])


history_DNN_loss = []
history_DNN_acc = []
history_DNN_precision = []
history_DNN_recall = []
history_DNN_fmeasure = []
history_DNN_val_loss = []
history_DNN_val_acc = []
history_DNN_val_precision = []
history_DNN_val_recall = []
history_DNN_val_fmeasure = []

def recorder_DNN(history):
    history_DNN_loss.append(history.history['loss'][0])
    history_DNN_acc.append(history.history['acc'][0])
    history_DNN_precision.append(history.history['precision'][0])
    history_DNN_recall.append(history.history['recall'][0])
    history_DNN_fmeasure.append(history.history['fmeasure'][0])
    history_DNN_val_loss.append(history.history['val_loss'][0])
    history_DNN_val_acc.append(history.history['val_acc'][0])
    history_DNN_val_precision.append(history.history['val_precision'][0])
    history_DNN_val_recall.append(history.history['val_recall'][0])
    history_DNN_val_fmeasure.append(history.history['val_fmeasure'][0])


for i in range(NB_EPOCHS):
    if (i<=NB_EPOCHS/5):
        history = model_DNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)
    elif (NB_EPOCHS/5<i and i%2==1 and i<(NB_EPOCHS*4/5)):
        history = model_DNN.fit(X_4,y_4,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)
    elif (NB_EPOCHS/5<i and i%2==0 and i<(NB_EPOCHS*4/5)):
        history = model_DNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)
    else:
        history = model_DNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)

print('base_line_now#######################################################################################################################################################################################################')
model_DNN_org = DNN(maxlen,NB_CLASSES)
model_DNN_org.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])
history_DNN_org = model_DNN_org.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=50,validation_data=(X_test,y_test),verbose=1)
# Out:
# Pad sequences to  6000
# ready for 4
# shuffling...
# transplanting...
# deleting...
# adding noise...
# the shape of x_train (7000, 6000)
# the shape of y_train (7000, 100)
# the shape of x_test (3000, 6000)
# the shape of y_test (3000, 100)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               768128
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               131584
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# activation_4 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               51300
# _________________________________________________________________
# activation_6 (Activation)    (None, 100)               0
# =================================================================
# Total params: 2,034,148
# Trainable params: 2,034,148
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 7000/7000 [==============================] - 2s 251us/step - loss: 4.4607 - acc: 0.0174 - precision: 0.0000e+00 - recall: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 4.2271 - val_acc: 0.0343 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 1s 94us/step - loss: 4.1872 - acc: 0.0384 - precision: 0.0000e+00 - recall: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 4.0348 - val_acc: 0.0553 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 1s 96us/step - loss: 3.9948 - acc: 0.0409 - precision: 0.0000e+00 - recall: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 3.8182 - val_acc: 0.0553 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 1s 96us/step - loss: 3.8377 - acc: 0.0543 - precision: 0.0000e+00 - recall: 0.0000e+00 - fmeasure: 0.0000e+00 - val_loss: 3.6640 - val_acc: 0.0770 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 1s
# 7000/7000 [==============================] - 1s 95us/step - loss: 3.1180 - acc: 0.1866 - precision: 0.4798 - recall: 0.0249 - fmeasure: 0.0467 - val_loss: 3.2425 - val_acc: 0.1850 - val_precision: 0.5328 - val_recall: 0.0183 - val_fmeasure: 0.0351
# Epoch 17/50
# 7000/7000 [==============================] - 1s 97us/step - loss: 3.0759 - acc: 0.1946 - precision: 0.5094 - recall: 0.0293 - fmeasure: 0.0548 - val_loss: 3.1787 - val_acc: 0.1987 - val_precision: 0.5243 - val_recall: 0.0233 - val_fmeasure: 0.0443
# Epoch 18/50
# 7000/7000 [==============================] - 1s 102us/step - loss: 3.0321 - acc: 0.2021 - precision: 0.5063 - recall: 0.0320 - fmeasure: 0.0594 - val_loss: 3.1485 - val_acc: 0.2063 - val_precision: 0.5144 - val_recall: 0.0353 - val_fmeasure: 0.0656
# Epoch 19/50
# 7000/7000 [==============================] - 1s 95us/step - loss: 3.0000 - acc: 0.2027 - precision: 0.5005 - recall: 0.0361 - fmeasure: 0.0666 - val_loss: 3.1723 - val_acc: 0.1937 - val_precision: 0.4840 - val_recall: 0.0217 - val_fmeasure: 0.0411
# Epoch 20/50
# 7000/7000 [==============================] - 1s 96us/step - loss: 2.9655 - acc: 0.2166 - precision: 0.5559 - recall: 0.0456 - fmeasure: 0.0831 - val_loss: 3.1495 - val_acc: 0.2120 - val_precision: 0.5447 - val_recall: 0.0333 - val_fmeasure: 0.0621
# Epoch 21/50
# 7000/7000 [==============================] - 1s 99us/step - loss: 2.9205 - acc: 0.2289 - precision: 0.5075 - recall: 0.0486 - fmeasure: 0.0878 - val_loss: 3.1674 - val_acc: 0.1927 - val_precision: 0.5615 - val_recall: 0.0320 - val_fmeasure: 0.0600
# Epoch 22/50
# 7000/7000 [==============================] - 1s 96us/step - loss: 2.8805 - acc: 0.2316 - precision: 0.5146 - recall: 0.0476 - fmeasure: 0.0860 - val_loss: 3.1407 - val_acc: 0.2030 - val_precision: 0.5525 - val_recall: 0.0450 - val_fmeasure: 0.0824
# Epoch 23/50
# 7000/7000 [==============================] - 1s 94us/step - loss: 2.8652 - acc: 0.2400 - precision: 0.5363 - recall: 0.0524 - fmeasure: 0.0944 - val_loss: 3.1211 - val_acc: 0.2180 - val_precision: 0.4923 - val_recall: 0.0450 - val_fmeasure: 0.0818
# Epoch 24/50
# 7000/7000 [==============================] - 1s 98us/step - loss: 2.8340 - acc: 0.2396 - precision: 0.5398 - recall: 0.0567 - fmeasure: 0.1009 - val_loss: 3.1248 - val_acc: 0.2203 - val_precision: 0.4981 - val_recall: 0.0453 - val_fmeasure: 0.0826
# Epoch 25/50
# 7000/7000 [==============================] - 1s 96us/step - loss: 2.8072 - acc: 0.2469 - precision: 0.5341 - recall: 0.0596 - fmeasure: 0.1060 - val_loss: 3.0654 - val_acc: 0.2373 - val_precision: 0.4966 - val_recall: 0.0443 - val_fmeasure: 0.0805
# Epoch 26/50
# 7000/7000 [==============================] - 1s 97us/step - loss: 2.7639 - acc: 0.2543 - precision: 0.5383 - recall: 0.0684 - fmeasure: 0.1203 - val_loss: 3.0692 - val_acc: 0.2287 - val_precision: 0.5260 - val_recall: 0.0600 - val_fmeasure: 0.1067
# Epoch 27/50
# 7000/7000 [==============================] - 1s 93us/step - loss: 2.7422 - acc: 0.2560 - precision: 0.5207 - recall: 0.0664 - fmeasure: 0.1164 - val_loss: 3.0628 - val_acc: 0.2243 - val_precision: 0.4851 - val_recall: 0.0693 - val_fmeasure: 0.1204
# Epoch 28/50
# 7000/7000 [==============================] - 1s 98us/step - loss: 2.6960 - acc: 0.2721 - precision: 0.5440 - recall: 0.0717 - fmeasure: 0.1254 - val_loss: 3.0411 - val_acc: 0.2373 - val_precision: 0.4590 - val_recall: 0.0640 - val_fmeasure: 0.1115
# Epoch 29/50
# 7000/7000 [==============================] - 1s 108us/step - loss: 2.6987 - acc: 0.2616 - precision: 0.5403 - recall: 0.0763 - fmeasure: 0.1322 - val_loss: 3.0444 - val_acc: 0.2290 - val_precision: 0.4745 - val_recall: 0.0603 - val_fmeasure: 0.1064
# Epoch 30/50
# 7000/7000 [==============================] - 1s 108us/step - loss: 2.6392 - acc: 0.2857 - precision: 0.5667 - recall: 0.0873 - fmeasure: 0.1498 - val_loss: 3.0287 - val_acc: 0.2327 - val_precision: 0.4682 - val_recall: 0.0720 - val_fmeasure: 0.1238
# Epoch 31/50
# 7000/7000 [==============================] - 1s 96us/step - loss: 2.6097 - acc: 0.2850 - precision: 0.5616 - recall: 0.0897 - fmeasure: 0.1532 - val_loss: 3.0609 - val_acc: 0.2220 - val_precision: 0.4290 - val_recall: 0.0813 - val_fmeasure: 0.1359
# Epoch 32/50
# 7000/7000 [==============================] - 1s 101us/step - loss: 2.6018 - acc: 0.2824 - precision: 0.5488 - recall: 0.0889 - fmeasure: 0.1511 - val_loss: 3.0778 - val_acc: 0.2260 - val_precision: 0.4639 - val_recall: 0.0770 - val_fmeasure: 0.1308
# Epoch 33/50
# 7000/7000 [==============================] - 1s 96us/step - loss: 2.5583 - acc: 0.2959 - precision: 0.5795 - recall: 0.1046 - fmeasure: 0.1756 - val_loss: 3.0222 - val_acc: 0.2417 - val_precision: 0.4777 - val_recall: 0.0907 - val_fmeasure: 0.1513
# Epoch 34/50
# 7000/7000 [==============================] - 1s 102us/step - loss: 2.5516 - acc: 0.2977 - precision: 0.5626 - recall: 0.1051 - fmeasure: 0.1757 - val_loss: 3.0615 - val_acc: 0.2347 - val_precision: 0.4456 - val_recall: 0.0877 - val_fmeasure: 0.1451
# Epoch 35/50
# 7000/7000 [==============================] - 1s 99us/step - loss: 2.5229 - acc: 0.3019 - precision: 0.5536 - recall: 0.1009 - fmeasure: 0.1690 - val_loss: 3.0219 - val_acc: 0.2413 - val_precision: 0.4608 - val_recall: 0.0967 - val_fmeasure: 0.1591
# Epoch 36/50
# 7000/7000 [==============================] - 1s 102us/step - loss: 2.5053 - acc: 0.3067 - precision: 0.5515 - recall: 0.1057 - fmeasure: 0.1754 - val_loss: 3.0733 - val_acc: 0.2433 - val_precision: 0.4253 - val_recall: 0.0993 - val_fmeasure: 0.1599
# Epoch 37/50
# 7000/7000 [==============================] - 1s 99us/step - loss: 2.4723 - acc: 0.3221 - precision: 0.5592 - recall: 0.1206 - fmeasure: 0.1966 - val_loss: 3.0563 - val_acc: 0.2410 - val_precision: 0.4536 - val_recall: 0.0930 - val_fmeasure: 0.1534
# Epoch 38/50
# 7000/7000 [==============================] - 1s 99us/step - loss: 2.4505 - acc: 0.3184 - precision: 0.5778 - recall: 0.1223 - fmeasure: 0.1999 - val_loss: 3.0664 - val_acc: 0.2353 - val_precision: 0.4351 - val_recall: 0.1003 - val_fmeasure: 0.1622
# Epoch 39/50
# 7000/7000 [==============================] - 1s 97us/step - loss: 2.4446 - acc: 0.3224 - precision: 0.5752 - recall: 0.1224 - fmeasure: 0.1998 - val_loss: 3.0894 - val_acc: 0.2367 - val_precision: 0.4418 - val_recall: 0.1067 - val_fmeasure: 0.1706
# Epoch 40/50
# 7000/7000 [==============================] - 1s 100us/step - loss: 2.4111 - acc: 0.3226 - precision: 0.5851 - recall: 0.1290 - fmeasure: 0.2096 - val_loss: 3.1146 - val_acc: 0.2320 - val_precision: 0.4238 - val_recall: 0.1093 - val_fmeasure: 0.1730
# Epoch 41/50
# 7000/7000 [==============================] - 1s 111us/step - loss: 2.3800 - acc: 0.3314 - precision: 0.5708 - recall: 0.1333 - fmeasure: 0.2141 - val_loss: 3.0951 - val_acc: 0.2387 - val_precision: 0.3983 - val_recall: 0.1023 - val_fmeasure: 0.1620
# Epoch 42/50
# 7000/7000 [==============================] - 1s 102us/step - loss: 2.3893 - acc: 0.3257 - precision: 0.5750 - recall: 0.1279 - fmeasure: 0.2075 - val_loss: 3.2308 - val_acc: 0.2253 - val_precision: 0.4088 - val_recall: 0.1060 - val_fmeasure: 0.1671
# Epoch 43/50
# 7000/7000 [==============================] - 1s 99us/step - loss: 2.3561 - acc: 0.3361 - precision: 0.5687 - recall: 0.1433 - fmeasure: 0.2274 - val_loss: 3.0584 - val_acc: 0.2440 - val_precision: 0.4434 - val_recall: 0.1103 - val_fmeasure: 0.1756
# Epoch 44/50
# 7000/7000 [==============================] - 1s 100us/step - loss: 2.3459 - acc: 0.3339 - precision: 0.5936 - recall: 0.1433 - fmeasure: 0.2287 - val_loss: 3.0521 - val_acc: 0.2410 - val_precision: 0.4295 - val_recall: 0.1077 - val_fmeasure: 0.1710
# Epoch 45/50
# 7000/7000 [==============================] - 1s 99us/step - loss: 2.3464 - acc: 0.3456 - precision: 0.5793 - recall: 0.1440 - fmeasure: 0.2289 - val_loss: 3.1148 - val_acc: 0.2330 - val_precision: 0.3952 - val_recall: 0.1020 - val_fmeasure: 0.1606
# Epoch 46/50
# 7000/7000 [==============================] - 1s 99us/step - loss: 2.2723 - acc: 0.3567 - precision: 0.5965 - recall: 0.1561 - fmeasure: 0.2451 - val_loss: 3.1444 - val_acc: 0.2407 - val_precision: 0.4129 - val_recall: 0.1227 - val_fmeasure: 0.1876
# Epoch 47/50
# 7000/7000 [==============================] - 1s 100us/step - loss: 2.2864 - acc: 0.3529 - precision: 0.5815 - recall: 0.1594 - fmeasure: 0.2487 - val_loss: 3.0912 - val_acc: 0.2440 - val_precision: 0.4214 - val_recall: 0.1230 - val_fmeasure: 0.1892
# Epoch 48/50
# 7000/7000 [==============================] - 1s 99us/step - loss: 2.2718 - acc: 0.3491 - precision: 0.5844 - recall: 0.1496 - fmeasure: 0.2364 - val_loss: 3.1522 - val_acc: 0.2390 - val_precision: 0.4153 - val_recall: 0.1160 - val_fmeasure: 0.1801
# Epoch 49/50
# 7000/7000 [==============================] - 1s 99us/step - loss: 2.2506 - acc: 0.3620 - precision: 0.5884 - recall: 0.1639 - fmeasure: 0.2545 - val_loss: 3.0616 - val_acc: 0.2487 - val_precision: 0.4248 - val_recall: 0.1227 - val_fmeasure: 0.1894
# Epoch 50/50
# 7000/7000 [==============================] - 1s 102us/step - loss: 2.2287 - acc: 0.3620 - precision: 0.6008 - recall: 0.1700 - fmeasure: 0.2635 - val_loss: 3.0960 - val_acc: 0.2483 - val_precision: 0.3973 - val_recall: 0.1187 - val_fmeasure: 0.1819

# %%
#CNN               ############# test for noise adding  , function :: creat_data############

BATCH_SIZE = 64
NB_EPOCHS = 50
VALIDATION_SPLIT = 0.3

OPTIMIZER = Adamax()

historys_DNN = []
NB_tech = [4,4,4,4]

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)


print('Pad sequences to ',maxlen)
print('ready for 4')
X_4,y_4 = random_launch(X_train,y_train,NB_tech[0])
X_4 = sequence.pad_sequences(X_4, maxlen=maxlen,padding='post',truncating='post')
X_4 = X_4[:,:,np.newaxis]
y_4 = np_utils.to_categorical(y_4, NB_CLASSES)
'''
print('ready for 3')
X_3,y_3 = random_launch(X_train,y_train,NB_tech[1])
X_3 = sequence.pad_sequences(X_3, maxlen=maxlen,padding='post',truncating='post')
X_3 = X_3[:,:,np.newaxis]
y_3 = np_utils.to_categorical(y_3, NB_CLASSES)
print('ready for 2')
X_2,y_2 = random_launch(X_train,y_train,NB_tech[2])
X_2 = sequence.pad_sequences(X_2, maxlen=maxlen,padding='post',truncating='post')
X_2 = X_2[:,:,np.newaxis]
y_2 = np_utils.to_categorical(y_2, NB_CLASSES)
print('ready for 1')
X_1,y_1 = random_launch(X_train,y_train,NB_tech[3])
X_1 = sequence.pad_sequences(X_1, maxlen=maxlen,padding='post',truncating='post')
X_1 = X_1[:,:,np.newaxis]
y_1 = np_utils.to_categorical(y_1, NB_CLASSES)

'''
X_train = sequence.pad_sequences(X_train, maxlen=maxlen,padding='post',truncating='post')
X_train = X_train[:,:,np.newaxis]
y_train = np_utils.to_categorical(y_train, NB_CLASSES)
X_test = sequence.pad_sequences(X_test, maxlen=maxlen,padding='post',truncating='post')
X_test = X_test[:,:,np.newaxis]

y_test = np_utils.to_categorical(y_test, NB_CLASSES)

print('the shape of x_train',X_train.shape)
print('the shape of y_train',y_train.shape)
print('the shape of x_test',X_test.shape)
print('the shape of y_test',y_test.shape)
model_CNN = CNN(maxlen,NB_CLASSES)
model_CNN.summary()
model_CNN.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])




history_CNN_loss = []
history_CNN_acc = []
history_CNN_precision = []
history_CNN_recall = []
history_CNN_fmeasure = []
history_CNN_val_loss = []
history_CNN_val_acc = []
history_CNN_val_precision = []
history_CNN_val_recall = []
history_CNN_val_fmeasure = []

def recorder_CNN(history):
    history_CNN_loss.append(history.history['loss'][0])
    history_CNN_acc.append(history.history['acc'][0])
    history_CNN_precision.append(history.history['precision'][0])
    history_CNN_recall.append(history.history['recall'][0])
    history_CNN_fmeasure.append(history.history['fmeasure'][0])
    history_CNN_val_loss.append(history.history['val_loss'][0])
    history_CNN_val_acc.append(history.history['val_acc'][0])
    history_CNN_val_precision.append(history.history['val_precision'][0])
    history_CNN_val_recall.append(history.history['val_recall'][0])
    history_CNN_val_fmeasure.append(history.history['val_fmeasure'][0])


for i in range(NB_EPOCHS):
    if (i<=NB_EPOCHS/5):
        history = model_CNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)
    elif (NB_EPOCHS/5<i and i%2==1 and i<(NB_EPOCHS*4/5)):
        history = model_CNN.fit(X_4,y_4,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)
    elif (NB_EPOCHS/5<i and i%2==0 and i<(NB_EPOCHS*4/5)):
        history = model_CNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)
    else:
        history = model_CNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)

print('base_line_now')
model_CNN_org = CNN(maxlen,NB_CLASSES)
model_CNN_org.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])
history_CNN_org = model_CNN_org.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=50,validation_data=(X_test,y_test),verbose=1)
# Out:
# Pad sequences to  6000
# ready for 4
# shuffling...
# adding noise...
# transplanting...
# deleting...
# the shape of x_train (7000, 6000, 1)
# the shape of y_train (7000, 100)
# the shape of x_test (3000, 6000, 1)
# the shape of y_test (3000, 100)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv1D)        (None, 6000, 32)          288
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 6000, 32)          128
# _________________________________________________________________
# block1_adv_act1 (ELU)        (None, 6000, 32)          0
# _________________________________________________________________
# block1_conv2 (Conv1D)        (None, 6000, 32)          8224
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 6000, 32)          128
# _________________________________________________________________
# block1_adv_act2 (ELU)        (None, 6000, 32)          0
# _________________________________________________________________
# block1_pool (MaxPooling1D)   (None, 1500, 32)          0
# _________________________________________________________________
# block1_dropout (Dropout)     (None, 1500, 32)          0
# _________________________________________________________________
# block2_conv1 (Conv1D)        (None, 1500, 64)          16448
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1500, 64)          256
# _________________________________________________________________
# block2_act1 (Activation)     (None, 1500, 64)          0
# _________________________________________________________________
# block2_conv2 (Conv1D)        (None, 1500, 64)          32832
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1500, 64)          256
# _________________________________________________________________
# block2_act2 (Activation)     (None, 1500, 64)          0
# _________________________________________________________________
# block2_pool (MaxPooling1D)   (None, 375, 64)           0
# _________________________________________________________________
# block2_dropout (Dropout)     (None, 375, 64)           0
# _________________________________________________________________
# block3_conv1 (Conv1D)        (None, 375, 128)          65664
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 375, 128)          512
# _________________________________________________________________
# block3_act1 (Activation)     (None, 375, 128)          0
# _________________________________________________________________
# block3_conv2 (Conv1D)        (None, 375, 128)          131200
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 375, 128)          512
# _________________________________________________________________
# block3_act2 (Activation)     (None, 375, 128)          0
# _________________________________________________________________
# block3_pool (MaxPooling1D)   (None, 94, 128)           0
# _________________________________________________________________
# block3_dropout (Dropout)     (None, 94, 128)           0
# _________________________________________________________________
# block4_conv1 (Conv1D)        (None, 94, 256)           262400
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 94, 256)           1024
# _________________________________________________________________
# block4_act1 (Activation)     (None, 94, 256)           0
# _________________________________________________________________
# block4_conv2 (Conv1D)        (None, 94, 256)           524544
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 94, 256)           1024
# _________________________________________________________________
# block4_act2 (Activation)     (None, 94, 256)           0
# _________________________________________________________________
# block4_pool (MaxPooling1D)   (None, 24, 256)           0
# _________________________________________________________________
# block4_dropout (Dropout)     (None, 24, 256)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 6144)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 512)               3146240
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 512)               2048
# _________________________________________________________________
# fc1_act (Activation)         (None, 512)               0
# _________________________________________________________________
# fc1_dropout (Dropout)        (None, 512)               0
# _________________________________________________________________
# fc2 (Dense)                  (None, 512)               262656
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# fc2_act (Activation)         (None, 512)               0
# _________________________________________________________________
# fc2_dropout (Dropout)        (None, 512)               0
# _________________________________________________________________
# fc3 (Dense)                  (None, 100)               51300
# _________________________________________________________________
# softmax (Activation)         (None, 100)               0
# =================================================================
# Total params: 4,509,732
# Trainable params: 4,505,764
# Non-trainable params: 3,968
# _________________________________________________________________
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 11s 2ms/step - loss: 4.3744 - acc: 0.0607 - precision: 0.1469 - recall: 0.0047 - fmeasure: 0.0090 - val_loss: 3.3961 - val_acc: 0.1500 - val_precision: 0.3794 - val_recall: 0.0147 - val_fmeasure: 0.0280
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 3.6567 - acc: 0.1203 - precision: 0.2648 - recall: 0.0123 - fmeasure: 0.0233 - val_loss: 3.1425 - val_acc: 0.2280 - val_precision: 0.3840 - val_recall: 0.0070 - val_fmeasure: 0.0137
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 3.3069 - acc: 0.1780 - precision: 0.3870 - recall: 0.0207 - fmeasure: 0.0388 - val_loss: 2.9929 - val_acc: 0.2523 - val_precision: 0.4453 - val_recall: 0.0100 - val_fmeasure: 0.0195
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 3.0717 - acc: 0.2194 - precision: 0.4198 - recall: 0.0379 - fmeasure: 0.0688 - val_loss: 3.0558 - val_acc: 0.2433 - val_precision: 0.5147 - val_recall: 0.0123 - val_fmeasure: 0.0240
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.8954 - acc: 0.2469 - precision: 0.4685 - recall: 0.0509 - fmeasure: 0.0908 - val_loss: 2.4501 - val_acc: 0.3647 - val_precision: 0.6188 - val_recall: 0.0753 - val_fmeasure: 0.1331
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.7577 - acc: 0.2844 - precision: 0.4976 - recall: 0.0719 - fmeasure: 0.1246 - val_loss: 2.3728 - val_acc: 0.3730 - val_precision: 0.6161 - val_recall: 0.0877 - val_fmeasure: 0.1519
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.6066 - acc: 0.3114 - precision: 0.5170 - recall: 0.0884 - fmeasure: 0.1499 - val_loss: 2.3046 - val_acc: 0.4003 - val_precision: 0.6146 - val_recall: 0.0897 - val_fmeasure: 0.1551
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.5096 - acc: 0.3339 - precision: 0.5469 - recall: 0.1113 - fmeasure: 0.1837 - val_loss: 2.2493 - val_acc: 0.4093 - val_precision: 0.6016 - val_recall: 0.1580 - val_fmeasure: 0.2488
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.4155 - acc: 0.3514 - precision: 0.5558 - recall: 0.1303 - fmeasure: 0.2099 - val_loss: 2.1582 - val_acc: 0.4223 - val_precision: 0.5923 - val_recall: 0.1850 - val_fmeasure: 0.2804
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.0391 - acc: 0.6553 - precision: 0.7254 - recall: 0.5353 - fmeasure: 0.6149 - val_loss: 2.0259 - val_acc: 0.4310 - val_precision: 0.4570 - val_recall: 0.3570 - val_fmeasure: 0.4003
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/1
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.0282 - acc: 0.6516 - precision: 0.7346 - recall: 0.5443 - fmeasure: 0.6245 - val_loss: 2.1142 - val_acc: 0.4293 - val_precision: 0.4492 - val_recall: 0.3640 - val_fmeasure: 0.4017
# base_line_now
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/50
# 7000/7000 [==============================] - 10s 1ms/step - loss: 4.4914 - acc: 0.0497 - precision: 0.0998 - recall: 0.0029 - fmeasure: 0.0055 - val_loss: 3.4804 - val_acc: 0.1443 - val_precision: 0.4462 - val_recall: 0.0140 - val_fmeasure: 0.0270
# Epoch 2/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 3.7182 - acc: 0.1201 - precision: 0.2954 - recall: 0.0113 - fmeasure: 0.0215 - val_loss: 3.1488 - val_acc: 0.2423 - val_precision: 0.4822 - val_recall: 0.0120 - val_fmeasure: 0.0233
# Epoch 3/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 3.3838 - acc: 0.1681 - precision: 0.3334 - recall: 0.0190 - fmeasure: 0.0356 - val_loss: 3.1487 - val_acc: 0.2340 - val_precision: 0.3280 - val_recall: 0.0057 - val_fmeasure: 0.0111
# Epoch 4/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 3.1178 - acc: 0.2167 - precision: 0.4237 - recall: 0.0339 - fmeasure: 0.0621 - val_loss: 2.7379 - val_acc: 0.3150 - val_precision: 0.6042 - val_recall: 0.0223 - val_fmeasure: 0.0427
# Epoch 5/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.9129 - acc: 0.2573 - precision: 0.4249 - recall: 0.0469 - fmeasure: 0.0834 - val_loss: 2.6318 - val_acc: 0.3270 - val_precision: 0.6312 - val_recall: 0.0293 - val_fmeasure: 0.0555
# Epoch 6/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.7763 - acc: 0.2789 - precision: 0.4929 - recall: 0.0664 - fmeasure: 0.1161 - val_loss: 2.5256 - val_acc: 0.3400 - val_precision: 0.5550 - val_recall: 0.0777 - val_fmeasure: 0.1352
# Epoch 7/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.6319 - acc: 0.3059 - precision: 0.5001 - recall: 0.0834 - fmeasure: 0.1421 - val_loss: 2.2516 - val_acc: 0.4083 - val_precision: 0.5941 - val_recall: 0.1540 - val_fmeasure: 0.2425
# Epoch 8/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.5160 - acc: 0.3287 - precision: 0.5478 - recall: 0.1131 - fmeasure: 0.1858 - val_loss: 2.2844 - val_acc: 0.4013 - val_precision: 0.5987 - val_recall: 0.1220 - val_fmeasure: 0.2012
# Epoch 9/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.4376 - acc: 0.3459 - precision: 0.5374 - recall: 0.1231 - fmeasure: 0.1991 - val_loss: 2.1319 - val_acc: 0.4283 - val_precision: 0.5909 - val_recall: 0.1700 - val_fmeasure: 0.2621
# Epoch 10/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.3597 - acc: 0.3683 - precision: 0.5580 - recall: 0.1354 - fmeasure: 0.2164 - val_loss: 2.1810 - val_acc: 0.4097 - val_precision: 0.5729 - val_recall: 0.1727 - val_fmeasure: 0.2631
# Epoch 11/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.3027 - acc: 0.3771 - precision: 0.5552 - recall: 0.1557 - fmeasure: 0.2416 - val_loss: 2.0903 - val_acc: 0.4403 - val_precision: 0.5716 - val_recall: 0.1797 - val_fmeasure: 0.2714
# Epoch 12/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.2188 - acc: 0.3947 - precision: 0.5644 - recall: 0.1650 - fmeasure: 0.2535 - val_loss: 2.0420 - val_acc: 0.4523 - val_precision: 0.5722 - val_recall: 0.2317 - val_fmeasure: 0.3283
# Epoch 13/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.1670 - acc: 0.4056 - precision: 0.5727 - recall: 0.1781 - fmeasure: 0.2702 - val_loss: 2.0190 - val_acc: 0.4543 - val_precision: 0.5646 - val_recall: 0.2510 - val_fmeasure: 0.3463
# Epoch 14/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.1441 - acc: 0.4134 - precision: 0.5749 - recall: 0.1960 - fmeasure: 0.2911 - val_loss: 2.0164 - val_acc: 0.4640 - val_precision: 0.5753 - val_recall: 0.1957 - val_fmeasure: 0.2903
# Epoch 15/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.0706 - acc: 0.4287 - precision: 0.6000 - recall: 0.2096 - fmeasure: 0.3090 - val_loss: 2.0304 - val_acc: 0.4470 - val_precision: 0.5787 - val_recall: 0.2377 - val_fmeasure: 0.3354
# Epoch 16/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.0291 - acc: 0.4310 - precision: 0.5856 - recall: 0.2170 - fmeasure: 0.3147 - val_loss: 1.9351 - val_acc: 0.4703 - val_precision: 0.5578 - val_recall: 0.2710 - val_fmeasure: 0.3633
# Epoch 17/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 2.0093 - acc: 0.4397 - precision: 0.5865 - recall: 0.2261 - fmeasure: 0.3248 - val_loss: 1.9201 - val_acc: 0.4697 - val_precision: 0.5657 - val_recall: 0.2947 - val_fmeasure: 0.3861
# Epoch 18/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.9548 - acc: 0.4459 - precision: 0.5943 - recall: 0.2356 - fmeasure: 0.3360 - val_loss: 1.9433 - val_acc: 0.4537 - val_precision: 0.5494 - val_recall: 0.2807 - val_fmeasure: 0.3703
# Epoch 19/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.9257 - acc: 0.4557 - precision: 0.5929 - recall: 0.2487 - fmeasure: 0.3489 - val_loss: 1.9414 - val_acc: 0.4480 - val_precision: 0.5416 - val_recall: 0.2767 - val_fmeasure: 0.3649
# Epoch 20/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.8900 - acc: 0.4653 - precision: 0.6056 - recall: 0.2556 - fmeasure: 0.3583 - val_loss: 1.9049 - val_acc: 0.4747 - val_precision: 0.5563 - val_recall: 0.2927 - val_fmeasure: 0.3825
# Epoch 21/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.8436 - acc: 0.4763 - precision: 0.6097 - recall: 0.2724 - fmeasure: 0.3754 - val_loss: 1.9162 - val_acc: 0.4563 - val_precision: 0.5472 - val_recall: 0.2703 - val_fmeasure: 0.3607
# Epoch 22/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.8415 - acc: 0.4696 - precision: 0.5991 - recall: 0.2696 - fmeasure: 0.3706 - val_loss: 1.9258 - val_acc: 0.4640 - val_precision: 0.5505 - val_recall: 0.3173 - val_fmeasure: 0.4013
# Epoch 23/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.7690 - acc: 0.4941 - precision: 0.6249 - recall: 0.2944 - fmeasure: 0.3989 - val_loss: 1.8665 - val_acc: 0.4673 - val_precision: 0.5393 - val_recall: 0.3033 - val_fmeasure: 0.3872
# Epoch 24/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.7194 - acc: 0.4949 - precision: 0.6300 - recall: 0.3039 - fmeasure: 0.4088 - val_loss: 1.8762 - val_acc: 0.4823 - val_precision: 0.5415 - val_recall: 0.3380 - val_fmeasure: 0.4152
# Epoch 25/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.7225 - acc: 0.5024 - precision: 0.6282 - recall: 0.3084 - fmeasure: 0.4121 - val_loss: 1.8820 - val_acc: 0.4683 - val_precision: 0.5329 - val_recall: 0.3247 - val_fmeasure: 0.4027
# Epoch 26/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.6944 - acc: 0.4983 - precision: 0.6223 - recall: 0.3146 - fmeasure: 0.4169 - val_loss: 1.8675 - val_acc: 0.4667 - val_precision: 0.5283 - val_recall: 0.3447 - val_fmeasure: 0.4163
# Epoch 27/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.6519 - acc: 0.5124 - precision: 0.6340 - recall: 0.3286 - fmeasure: 0.4316 - val_loss: 1.8952 - val_acc: 0.4680 - val_precision: 0.5326 - val_recall: 0.3243 - val_fmeasure: 0.4024
# Epoch 28/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.6200 - acc: 0.5179 - precision: 0.6439 - recall: 0.3281 - fmeasure: 0.4333 - val_loss: 1.9312 - val_acc: 0.4513 - val_precision: 0.5230 - val_recall: 0.2993 - val_fmeasure: 0.3800
# Epoch 29/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.5928 - acc: 0.5293 - precision: 0.6471 - recall: 0.3496 - fmeasure: 0.4527 - val_loss: 1.8912 - val_acc: 0.4603 - val_precision: 0.5197 - val_recall: 0.3363 - val_fmeasure: 0.4074
# Epoch 30/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.5675 - acc: 0.5324 - precision: 0.6409 - recall: 0.3514 - fmeasure: 0.4528 - val_loss: 1.8841 - val_acc: 0.4630 - val_precision: 0.5196 - val_recall: 0.3463 - val_fmeasure: 0.4149
# Epoch 31/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.5486 - acc: 0.5283 - precision: 0.6492 - recall: 0.3596 - fmeasure: 0.4615 - val_loss: 1.9274 - val_acc: 0.4607 - val_precision: 0.5207 - val_recall: 0.3383 - val_fmeasure: 0.4095
# Epoch 32/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.5238 - acc: 0.5331 - precision: 0.6503 - recall: 0.3673 - fmeasure: 0.4685 - val_loss: 1.8638 - val_acc: 0.4627 - val_precision: 0.5223 - val_recall: 0.3430 - val_fmeasure: 0.4132
# Epoch 33/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.5070 - acc: 0.5487 - precision: 0.6590 - recall: 0.3786 - fmeasure: 0.4795 - val_loss: 1.9241 - val_acc: 0.4470 - val_precision: 0.4968 - val_recall: 0.3133 - val_fmeasure: 0.3834
# Epoch 34/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.4713 - acc: 0.5510 - precision: 0.6611 - recall: 0.3876 - fmeasure: 0.4877 - val_loss: 1.9129 - val_acc: 0.4537 - val_precision: 0.5119 - val_recall: 0.3397 - val_fmeasure: 0.4075
# Epoch 35/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.4615 - acc: 0.5581 - precision: 0.6627 - recall: 0.3907 - fmeasure: 0.4905 - val_loss: 1.9190 - val_acc: 0.4617 - val_precision: 0.5065 - val_recall: 0.3583 - val_fmeasure: 0.4191
# Epoch 36/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.4169 - acc: 0.5631 - precision: 0.6647 - recall: 0.3973 - fmeasure: 0.4960 - val_loss: 1.9488 - val_acc: 0.4547 - val_precision: 0.5020 - val_recall: 0.3540 - val_fmeasure: 0.4145
# Epoch 37/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.4004 - acc: 0.5671 - precision: 0.6742 - recall: 0.4089 - fmeasure: 0.5080 - val_loss: 1.9938 - val_acc: 0.4380 - val_precision: 0.4790 - val_recall: 0.3207 - val_fmeasure: 0.3834
# Epoch 38/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.3853 - acc: 0.5741 - precision: 0.6734 - recall: 0.4140 - fmeasure: 0.5118 - val_loss: 1.9865 - val_acc: 0.4480 - val_precision: 0.4905 - val_recall: 0.3567 - val_fmeasure: 0.4124
# Epoch 39/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.3603 - acc: 0.5759 - precision: 0.6712 - recall: 0.4206 - fmeasure: 0.5160 - val_loss: 1.9675 - val_acc: 0.4523 - val_precision: 0.4928 - val_recall: 0.3600 - val_fmeasure: 0.4154
# Epoch 40/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.3709 - acc: 0.5700 - precision: 0.6672 - recall: 0.4216 - fmeasure: 0.5156 - val_loss: 1.9863 - val_acc: 0.4523 - val_precision: 0.4984 - val_recall: 0.3623 - val_fmeasure: 0.4190
# Epoch 41/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.3416 - acc: 0.5804 - precision: 0.6739 - recall: 0.4293 - fmeasure: 0.5232 - val_loss: 1.9516 - val_acc: 0.4433 - val_precision: 0.4878 - val_recall: 0.3530 - val_fmeasure: 0.4090
# Epoch 42/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.3317 - acc: 0.5784 - precision: 0.6766 - recall: 0.4356 - fmeasure: 0.5288 - val_loss: 1.9771 - val_acc: 0.4430 - val_precision: 0.4820 - val_recall: 0.3573 - val_fmeasure: 0.4100
# Epoch 43/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.3120 - acc: 0.5814 - precision: 0.6745 - recall: 0.4339 - fmeasure: 0.5270 - val_loss: 1.9899 - val_acc: 0.4470 - val_precision: 0.4862 - val_recall: 0.3677 - val_fmeasure: 0.4182
# Epoch 44/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.2730 - acc: 0.5997 - precision: 0.6886 - recall: 0.4537 - fmeasure: 0.5461 - val_loss: 2.0085 - val_acc: 0.4437 - val_precision: 0.4751 - val_recall: 0.3607 - val_fmeasure: 0.4094
# Epoch 45/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.2493 - acc: 0.5964 - precision: 0.6823 - recall: 0.4571 - fmeasure: 0.5465 - val_loss: 2.0481 - val_acc: 0.4337 - val_precision: 0.4683 - val_recall: 0.3533 - val_fmeasure: 0.4022
# Epoch 46/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.2539 - acc: 0.5953 - precision: 0.6876 - recall: 0.4616 - fmeasure: 0.5516 - val_loss: 2.0201 - val_acc: 0.4423 - val_precision: 0.4741 - val_recall: 0.3707 - val_fmeasure: 0.4156
# Epoch 47/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.2319 - acc: 0.6020 - precision: 0.6805 - recall: 0.4584 - fmeasure: 0.5468 - val_loss: 2.0150 - val_acc: 0.4350 - val_precision: 0.4687 - val_recall: 0.3487 - val_fmeasure: 0.3993
# Epoch 48/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.1940 - acc: 0.6154 - precision: 0.6999 - recall: 0.4741 - fmeasure: 0.5644 - val_loss: 2.0626 - val_acc: 0.4307 - val_precision: 0.4541 - val_recall: 0.3540 - val_fmeasure: 0.3974
# Epoch 49/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.1793 - acc: 0.6167 - precision: 0.7065 - recall: 0.4860 - fmeasure: 0.5749 - val_loss: 2.0609 - val_acc: 0.4230 - val_precision: 0.4546 - val_recall: 0.3477 - val_fmeasure: 0.3936
# Epoch 50/50
# 7000/7000 [==============================] - 7s 1ms/step - loss: 1.1726 - acc: 0.6204 - precision: 0.7064 - recall: 0.5003 - fmeasure: 0.5850 - val_loss: 2.0704 - val_acc: 0.4350 - val_precision: 0.4655 - val_recall: 0.3630 - val_fmeasure: 0.4072

# %%
import matplotlib.pylab as plt


fig,axs = plt.subplots(1,5,figsize=(30,10))
axs[0].plot(range(NB_EPOCHS),history_DNN_org.history['val_loss'],label='before')
axs[0].plot(range(NB_EPOCHS),history_DNN_val_loss,label='after')
axs[0].set_title('val_loss')

axs[1].plot(range(NB_EPOCHS),history_DNN_org.history['val_acc'],label='before')
axs[1].plot(range(NB_EPOCHS),history_DNN_val_acc,label='after')
axs[1].set_title('val_acc')

axs[2].plot(range(NB_EPOCHS),history_DNN_org.history['val_precision'],label='before')
axs[2].plot(range(NB_EPOCHS),history_DNN_val_precision,label='after')
axs[2].set_title('val_precision')

axs[3].plot(range(NB_EPOCHS),history_DNN_org.history['val_recall'],label='before')
axs[3].plot(range(NB_EPOCHS),history_DNN_val_recall,label='after')
axs[3].set_title('val_recall')

axs[4].plot(range(NB_EPOCHS),history_DNN_org.history['val_fmeasure'],label='before')
axs[4].plot(range(NB_EPOCHS),history_DNN_val_fmeasure,label='after')
axs[4].set_title('val_fmeasure')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center')

plt.show()

# %%
import matplotlib.pylab as plt


fig,axs = plt.subplots(1,5,figsize=(30,10))
axs[0].plot(range(NB_EPOCHS),history_CNN_org.history['val_loss'],label='before')
axs[0].plot(range(NB_EPOCHS),history_CNN_val_loss,label='after')
axs[0].set_title('val_loss')

axs[1].plot(range(NB_EPOCHS),history_CNN_org.history['val_acc'],label='before')
axs[1].plot(range(NB_EPOCHS),history_CNN_val_acc,label='after')
axs[1].set_title('val_acc')

axs[2].plot(range(NB_EPOCHS),history_CNN_org.history['val_precision'],label='before')
axs[2].plot(range(NB_EPOCHS),history_CNN_val_precision,label='after')
axs[2].set_title('val_precision')

axs[3].plot(range(NB_EPOCHS),history_CNN_org.history['val_recall'],label='before')
axs[3].plot(range(NB_EPOCHS),history_CNN_val_recall,label='after')
axs[3].set_title('val_recall')

axs[4].plot(range(NB_EPOCHS),history_CNN_org.history['val_fmeasure'],label='before')
axs[4].plot(range(NB_EPOCHS),history_CNN_val_fmeasure,label='after')
axs[4].set_title('val_fmeasure')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center')

plt.show()

# %%
history_CNN_org.history['val_fmeasure']
# Out:
# [0.02697197949886322,
#  0.023293094466129937,
#  0.011127696593602498,
#  0.04268472689390183,
#  0.055539496580759684,
#  0.13523706034819286,
#  0.2425416553815206,
#  0.20120734643936158,
#  0.2621066954135895,
#  0.2631422384579976,
#  0.271438516775767,
#  0.32830748812357585,
#  0.34626459248860675,
#  0.29025111134847004,
#  0.33536569992701215,
#  0.3633064183394114,
#  0.38614548230171203,
#  0.37033087674776716,
#  0.3649471392631531,
#  0.3824715017477671,
#  0.3607378787199656,
#  0.40133512250582376,
#  0.38716528431574504,
#  0.41523705609639483,
#  0.4026928497950236,
#  0.41626678498586017,
#  0.40235353231430054,
#  0.3800172673861186,
#  0.4073950960636139,
#  0.41487833062807716,
#  0.40945706526438397,
#  0.4132357620398204,
#  0.3834091631571452,
#  0.40747019910812377,
#  0.4191030344168345,
#  0.41449293049176533,
#  0.38343574810028075,
#  0.4124187164306641,
#  0.41538066999117534,
#  0.4189592829545339,
#  0.4089961259365082,
#  0.41002982409795125,
#  0.4181954578558604,
#  0.40944737974802653,
#  0.4022348503271739,
#  0.41557519920667013,
#  0.3992645632425944,
#  0.39739994700749715,
#  0.39359910917282104,
#  0.40720620385805767]

# %%
history_CNN_val_fmeasure
# Out:
# [0.027962859352429707,
#  0.013724940021832784,
#  0.019454843203226727,
#  0.02396686762571335,
#  0.13309956792990366,
#  0.15191036907831829,
#  0.15511335968971252,
#  0.24877668770154318,
#  0.2804158612092336,
#  0.31230832513173423,
#  0.3247434187730153,
#  0.18228580407301584,
#  0.2666955442428589,
#  0.22419675397872924,
#  0.3314415613015493,
#  0.26969138475259147,
#  0.32992735266685486,
#  0.3258905433019002,
#  0.3578979566891988,
#  0.35477503649393716,
#  0.3860460856755575,
#  0.37461011672019956,
#  0.39123237880071005,
#  0.3601878734429677,
#  0.3860144740740458,
#  0.3755889564355214,
#  0.39735043557484945,
#  0.40050802342096964,
#  0.38857925724983217,
#  0.3911257708867391,
#  0.39078416148821515,
#  0.4255787739753723,
#  0.4160749453703562,
#  0.4158729730447133,
#  0.420770201921463,
#  0.4137549022038778,
#  0.4049334732691447,
#  0.40837835041681925,
#  0.40426518774032594,
#  0.3998574965000153,
#  0.39806832472483317,
#  0.39148830231030785,
#  0.398538587808609,
#  0.4058526865641276,
#  0.40206458044052124,
#  0.3934751934210459,
#  0.4039870183467865,
#  0.40316410597165425,
#  0.4003496081829071,
#  0.4016647396882375]
