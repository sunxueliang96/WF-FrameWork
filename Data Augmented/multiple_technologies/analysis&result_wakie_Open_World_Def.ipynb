# %% [markdown]
# <a href="https://colab.research.google.com/github/sunxueliang96/WF-FrameWork/blob/master/Data%20Augmented/multiple_technologies/analysis%26result_wakie_Open_World_Def.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/'My Drive'/deep_firger/dataset/OpenWorld/WalkieTalkie
# Out:
# /content/drive/My Drive/deep_firger/dataset/OpenWorld/WalkieTalkie

# %%
datatype_Close = False   #Flase is Open_World, True is Closed World.

# %%
#cd /content/drive/'My Drive'/datasets/no_paded/close_world/walkiebatch

# %%
#datatype_Close = True   #Flase is Open_World, True is Closed World.

# %%
ls
# Out:
# X_test_Mon_WalkieTalkie.pkl    y_test_Mon_WalkieTalkie.pkl
# X_test_Unmon_WalkieTalkie.pkl  y_test_Unmon_WalkieTalkie.pkl
# X_train_WalkieTalkie.pkl       y_train_WalkieTalkie.pkl
# X_valid_WalkieTalkie.pkl       y_valid_WalkieTalkie.pkl

# %%
import numpy as np
import pickle

print('loading data...')
with open('X_train_WalkieTalkie.pkl','rb') as handle:
    X_1 = np.array(pickle.load(handle,encoding='iso-8859-1'))
with open('X_valid_WalkieTalkie.pkl','rb') as handle:
    X_2 = np.array(pickle.load(handle,encoding='iso-8859-1'))
with open('y_train_WalkieTalkie.pkl','rb') as handle:
    y_1 = np.array(pickle.load(handle,encoding='iso-8859-1'))
with open('y_valid_WalkieTalkie.pkl','rb') as handle:
    y_2 = np.array(pickle.load(handle,encoding='iso-8859-1'))

print('the shape of X_1',X_1.shape)
print('the shape of X_2',X_2.shape)
print('the shape of y_1',y_1.shape)
print('the shape of y_2',y_2.shape)
# Out:
# loading data...
# the shape of X_1 (99000, 5000)
# the shape of X_2 (2000, 5000)
# the shape of y_1 (99000,)
# the shape of y_2 (2000,)

# %%
X = []
y = []
X.extend(X_1)
X.extend(X_2)
y.extend(y_1)
y.extend(y_2)

# %%
k = 0 
for seq,i in zip(X,range(len(X))):
    X[i] = list(filter(lambda x:x!=0, seq))
    if(i in list(range(0,len(X),len(X)//10))):
        print("{}0% data has been dealed".format(k),flush = True)
        k +=1
y = [-1 if x==100 else x for x in y]
print ('shape of X',np.shape(X))
print ('shape of y',np.shape(y))
# Out:
# 00% data has been dealed
# 10% data has been dealed
# 20% data has been dealed
# 30% data has been dealed
# 40% data has been dealed
# 50% data has been dealed
# 60% data has been dealed
# 70% data has been dealed
# 80% data has been dealed
# 90% data has been dealed
# shape of X (101000,)
# shape of y (101000,)

# %%
import math 
import random
def fun_noise(X,y,PERCENT_NOISE,TIMES_NOISE): 
    X = list(X)
    y = list(y)
    X_sum = []
    y_sum = []
    #X_sum = X.copy()
    #y_sum = y.copy()
    #print("{} samples has beed add to X_train, {}% of noise for each sample".format(math.ceil(len(X)*TIMES_NOISE),PERCENT_NOISE))
    k=0
    for i in range(math.ceil(len(X)*TIMES_NOISE)): #ADDING NOISE from here 
        if(i in list(range(0,math.ceil(len(X)*TIMES_NOISE),math.ceil(len(X)*TIMES_NOISE)//10))):
            print("{}0% data has been dealed".format(k),flush = True)
            k +=1
        while(True):
            p = random.choice(range(len(X)))
            if(y[p]!=-1):
                break
            else:
                pass
        X_new = X[p].copy()
        y_new = y[p]
        for n in range(math.ceil(PERCENT_NOISE*len(X_new)/100)):#dealing X_new
            noise = random.choice([1,-1])       #noise could only be 1 or -1
            pos = random.choice(range(len(X_new)))  #position belong to (0,len(sequence))
            X_new.insert(pos,noise)
            #print('insert {} at position {} in sequence {} now len of sequence is {}, the tag of sequence is {}'.format(noise,pos,p,len(X_new),y_new)) #for test
        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum
def fun_delete(X,y,PERCENT_DELETE,TIMES_DELETE): 
    X = list(X)
    y = list(y)
    X_sum = []
    y_sum = []
    #X_sum = X.copy()
    #y_sum = y.copy()
    k = 0
    for i in range(math.ceil(len(X)*TIMES_DELETE)): #RANDOM DELETE from here
        if(i in list(range(0,math.ceil(len(X)*TIMES_DELETE),math.ceil(len(X)*TIMES_DELETE)//10))):
            print("{}0% data has been dealed".format(k),flush = True)
            k +=1
        while(True):
            p = random.choice(range(len(X)))
            if(y[p]!=-1):
                break
            else:
                #print('-1 detected')
                pass
        X_new = X[p].copy()
        y_new = y[p]
        for n in range(math.ceil(PERCENT_DELETE*len(X_new)/100)):#dealing X_new
            pos = random.choice(range(len(X_new)))  #position belong to (0,len(sequence))
            del X_new[pos]
            #print('insert {} at position {} in sequence {} now len of sequence is {}'.format(noise,pos,p,len(X_new))) #for test
        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum
def fun_shuffle(X,y,PERCENT_CHANGED,TIMES_SHUFFLE): 
    X = list(X)
    y = list(y)
    #X_sum = X.copy()
    #y_sum = y.copy()
    X_sum = []
    y_sum = []
    k=0
    for i in range(math.ceil(len(X)*TIMES_SHUFFLE)):             #LOCALLY CHANGE from here
        if(i in list(range(0,math.ceil(len(X)*TIMES_SHUFFLE),math.ceil(len(X)*TIMES_SHUFFLE)//10))):
            print("{}0% data has been dealed".format(k),flush = True)
            k +=1
        while(True):
            p = random.choice(range(len(X)))
            if(y[p]!=-1):
                break
            else:
                #print('-1 detected')
                pass
        X_new = X[p].copy()
        y_new = y[p]
        length = math.ceil(PERCENT_CHANGED*len(X_new)/100)
        start = random.choice(range(len(X_new)-length))
        temp = X_new[start:start+length]
        random.shuffle(temp)
        X_new[start:start+length] = temp

        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum
def fun_transplant(X,y,PERCENT_TRANSPLANT,NB_TIMES):        #Magnificate dataset by adding noising randomly
    global datatype_Close
    X = list(X)
    y = list(y)
    X_sum = []
    y_sum = []
    #X_sum = X.copy()
    #y_sum = y.copy()
    #print("{} samples has beed add to X_train, {}% of noise for each sample".format(math.ceil(len(X)*NB_TIMES),PERCENT_TRANSPLANT))
    k=0
    print('When the process freezing, please check that datatype_Close has been set correctly')
    for i in range(math.ceil(len(X)*NB_TIMES)):
        if(i in list(range(0,math.ceil(len(X)*NB_TIMES),math.ceil(len(X)*NB_TIMES)//10))):
            print("{}0% data has been dealed".format(k),flush = True)
            k +=1
        #print(datatype_Close)    
        while(datatype_Close):                               # target pos p (sensitive website), pos q (non-sensitive website)
            p = random.choice(range(len(X)))
            q = random.choice(range(len(X)))
            if(p != q):                           # Closed_World
                break
            else:
                #print('-1 detected')
                pass
        while(not datatype_Close):                               # target pos p (sensitive website), pos q (non-sensitive website)
            p = random.choice(range(len(X)))
            q = random.choice(range(len(X)))
            if(y[p]!=-1 and y[q]==-1):               # open_world
                break
            else:
                #print('-1 detected')
                pass
        X_new = X[p].copy()
        target = X[q].copy()
        y_new = y[p]

        length_X = math.ceil(PERCENT_TRANSPLANT*len(X_new)/100)
        length_target =  math.ceil(PERCENT_TRANSPLANT*len(target)/100)
        start_X = random.choice(range(len(X_new)-length_X))
        start_target = random.choice(range(len(target)-length_target))
        temp = target[start_target:start_target+length_target]
        X_new[start_X:start_X+length_X] = temp
     
        X_sum.append(X_new)
        y_sum.append(y_new)
    return X_sum,y_sum

def random_launch(X,y,NB_tech):
    X = list(X)
    y = list(y)
    X_sum = X.copy()
    y_sum = y.copy()
    launch_list = random.sample(range(4),NB_tech)             #return [0,1,....]....depending on NB_tech
    for i in launch_list:
        if (i==0):
            print('adding noise...')
            X_new,y_new = fun_noise(X,y,PERCENT_NOISE=20,TIMES_NOISE=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==1):
            print('deleting...')
            X_new,y_new = fun_delete(X,y,PERCENT_DELETE=20,TIMES_DELETE=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==2):
            print('shuffling...')
            X_new,y_new = fun_shuffle(X,y,PERCENT_CHANGED=20,TIMES_SHUFFLE=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
        if (i==3):
            print('transplanting...')
            X_new,y_new = fun_transplant(X,y,PERCENT_TRANSPLANT=20,NB_TIMES=0.4)
            X_sum.extend(X_new)
            y_sum.extend(y_new)
    return np.array(X_sum),np.array(y_sum)                        #return two array of X, y

# %%
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing import sequence
from collections import Counter
#CLASSES_KNN = 101########################################################################################################################################################################################################
#CLASSES_WAKIE = 100########################################################################################################################################################################################################
MAXLEN_KNN = 2000
MAXLEN_WAKIE =5000

maxlen = 5000
NB_CLASSES = 0

def choose():
    global maxlen,NB_CLASSES
    print('if padding, the max of length of seq is {}'.format(maxlen))
    NB_CLASSES = len(Counter(y).keys())
    print('number of classes is {}'.format(NB_CLASSES))

choose()################################################################################################################################################################################################################

print('Average sequence length: {}'.format(np.mean(list(map(len, X)), dtype=int)))
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# if padding, the max of length of seq is 5000
# number of classes is 101
# Average sequence length: 4234

# %%
#FCN
from keras import Sequential
from keras.layers.core import Activation, Flatten, Dense, Dropout
from keras.optimizers import Adamax
def DNN(input_shape,classes):
    model = Sequential()
    model.add(Dense(128, input_shape=(input_shape,)))
    model.add(Activation('relu'))
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dense(512))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dense(classes))
    model.add(Activation('softmax'))
    return model

# %%
#CNN
from keras import Input,Model,Sequential
from keras.layers import Embedding,GlobalAveragePooling1D,Dense,Dropout
from keras.layers import Conv1D, MaxPooling1D, BatchNormalization
from keras.layers.core import Activation, Flatten, Dense, Dropout
from keras.layers.advanced_activations import ELU
from keras.initializers import glorot_uniform
from keras.optimizers import Adamax
def CNN(input_shape, classes):
    model = Sequential()
    #Block1
    filter_num = ['None',32,64,128,256]
    kernel_size = ['None',8,8,8,8]
    conv_stride_size = ['None',1,1,1,1]
    pool_stride_size = ['None',4,4,4,4]
    pool_size = ['None',8,8,8,8]

    model.add(Conv1D(filters=filter_num[1], kernel_size=kernel_size[1], input_shape=(input_shape,1),
                      strides=conv_stride_size[1], padding='same',
                      name='block1_conv1'))
    model.add(BatchNormalization(axis=-1))
    model.add(ELU(alpha=1.0, name='block1_adv_act1'))
    model.add(Conv1D(filters=filter_num[1], kernel_size=kernel_size[1],
                      strides=conv_stride_size[1], padding='same',
                      name='block1_conv2'))
    model.add(BatchNormalization(axis=-1))
    model.add(ELU(alpha=1.0, name='block1_adv_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[1], strides=pool_stride_size[1],
                            padding='same', name='block1_pool'))
    model.add(Dropout(0.1, name='block1_dropout'))

    model.add(Conv1D(filters=filter_num[2], kernel_size=kernel_size[2],
                      strides=conv_stride_size[2], padding='same',
                      name='block2_conv1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block2_act1'))

    model.add(Conv1D(filters=filter_num[2], kernel_size=kernel_size[2],
                      strides=conv_stride_size[2], padding='same',
                      name='block2_conv2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block2_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[2], strides=pool_stride_size[3],
                            padding='same', name='block2_pool'))
    model.add(Dropout(0.1, name='block2_dropout'))

    model.add(Conv1D(filters=filter_num[3], kernel_size=kernel_size[3],
                      strides=conv_stride_size[3], padding='same',
                      name='block3_conv1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block3_act1'))
    model.add(Conv1D(filters=filter_num[3], kernel_size=kernel_size[3],
                      strides=conv_stride_size[3], padding='same',
                      name='block3_conv2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block3_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[3], strides=pool_stride_size[3],
                            padding='same', name='block3_pool'))
    model.add(Dropout(0.1, name='block3_dropout'))

    model.add(Conv1D(filters=filter_num[4], kernel_size=kernel_size[4],
                      strides=conv_stride_size[4], padding='same',
                      name='block4_conv1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block4_act1'))
    model.add(Conv1D(filters=filter_num[4], kernel_size=kernel_size[4],
                      strides=conv_stride_size[4], padding='same',
                      name='block4_conv2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='block4_act2'))
    model.add(MaxPooling1D(pool_size=pool_size[4], strides=pool_stride_size[4],
                            padding='same', name='block4_pool'))
    model.add(Dropout(0.1, name='block4_dropout'))

    model.add(Flatten(name='flatten'))
    model.add(Dense(512, kernel_initializer=glorot_uniform(seed=0), name='fc1'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='fc1_act'))

    model.add(Dropout(0.7, name='fc1_dropout'))

    model.add(Dense(512, kernel_initializer=glorot_uniform(seed=0), name='fc2'))
    model.add(BatchNormalization())
    model.add(Activation('relu', name='fc2_act'))

    model.add(Dropout(0.5, name='fc2_dropout'))

    model.add(Dense(classes, kernel_initializer=glorot_uniform(seed=0), name='fc3'))
    model.add(Activation('softmax', name="softmax"))
    return model

# %%
import keras
from keras import backend as K

def precision(y_true, y_pred):
    # Calculates the precision
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    # Calculates the recall
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def fbeta_score(y_true, y_pred, beta=1):
    # Calculates the F score, the weighted harmonic mean of precision and recall.
    if beta < 0:
        raise ValueError('The lowest choosable beta is zero (only precision).')
 
    # If there are no true positives, fix the F score at 0 like sklearn.
    if K.sum(K.round(K.clip(y_true, 0, 1))) == 0:
        return 0

    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    bb = beta ** 2
    fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
    return fbeta_score

def fmeasure(y_true, y_pred):
    # Calculates the f-measure, the harmonic mean of precision and recall.
    return fbeta_score(y_true, y_pred, beta=1)

# %%
import gc
del X_1
del X_2
del y_1
del y_2
gc.collect()
# Out:
# 84

# %%
#DNN               ############# test for noise adding  , function :: creat_data############

BATCH_SIZE = 64
NB_EPOCHS = 50
VALIDATION_SPLIT = 0.3

OPTIMIZER = Adamax()

historys_DNN = []
NB_tech = [4,4,4,4]

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)


print('Pad sequences to ',maxlen)
print('ready for 4')
X_4,y_4 = random_launch(X_train,y_train,NB_tech[0])
X_4 = sequence.pad_sequences(X_4, maxlen=maxlen,padding='post',truncating='post')
y_4 = np_utils.to_categorical(y_4, NB_CLASSES)
'''
print('ready for 3')
X_3,y_3 = random_launch(X_train,y_train,NB_tech[1])
X_3 = sequence.pad_sequences(X_3, maxlen=maxlen,padding='post',truncating='post')
X_3 = X_3[:,:,np.newaxis]
y_3 = np_utils.to_categorical(y_3, NB_CLASSES)
print('ready for 2')
X_2,y_2 = random_launch(X_train,y_train,NB_tech[2])
X_2 = sequence.pad_sequences(X_2, maxlen=maxlen,padding='post',truncating='post')
X_2 = X_2[:,:,np.newaxis]
y_2 = np_utils.to_categorical(y_2, NB_CLASSES)
print('ready for 1')
X_1,y_1 = random_launch(X_train,y_train,NB_tech[3])
X_1 = sequence.pad_sequences(X_1, maxlen=maxlen,padding='post',truncating='post')
X_1 = X_1[:,:,np.newaxis]
y_1 = np_utils.to_categorical(y_1, NB_CLASSES)

'''
X_train = sequence.pad_sequences(X_train, maxlen=maxlen,padding='post',truncating='post')
y_train = np_utils.to_categorical(y_train, NB_CLASSES)
X_test = sequence.pad_sequences(X_test, maxlen=maxlen,padding='post',truncating='post')
y_test = np_utils.to_categorical(y_test, NB_CLASSES)

print('the shape of x_train',X_train.shape)
print('the shape of y_train',y_train.shape)
print('the shape of x_test',X_test.shape)
print('the shape of y_test',y_test.shape)

model_DNN = DNN(maxlen,NB_CLASSES)
model_DNN.summary()
model_DNN.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])


history_DNN_loss = []
history_DNN_acc = []
history_DNN_precision = []
history_DNN_recall = []
history_DNN_fmeasure = []
history_DNN_val_loss = []
history_DNN_val_acc = []
history_DNN_val_precision = []
history_DNN_val_recall = []
history_DNN_val_fmeasure = []

def recorder_DNN(history):
    history_DNN_loss.append(history.history['loss'][0])
    history_DNN_acc.append(history.history['acc'][0])
    history_DNN_precision.append(history.history['precision'][0])
    history_DNN_recall.append(history.history['recall'][0])
    history_DNN_fmeasure.append(history.history['fmeasure'][0])
    history_DNN_val_loss.append(history.history['val_loss'][0])
    history_DNN_val_acc.append(history.history['val_acc'][0])
    history_DNN_val_precision.append(history.history['val_precision'][0])
    history_DNN_val_recall.append(history.history['val_recall'][0])
    history_DNN_val_fmeasure.append(history.history['val_fmeasure'][0])


for i in range(NB_EPOCHS):
    if (i<=NB_EPOCHS/5):
        history = model_DNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)
    elif (NB_EPOCHS/5<i and i%2==1 and i<(NB_EPOCHS*4/5)):
        history = model_DNN.fit(X_4,y_4,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)
    elif (NB_EPOCHS/5<i and i%2==0 and i<(NB_EPOCHS*4/5)):
        history = model_DNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)
    else:
        history = model_DNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_DNN(history)

print('base_line_now#######################################################################################################################################################################################################')
model_DNN_org = DNN(maxlen,NB_CLASSES)
model_DNN_org.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])
history_DNN_org = model_DNN_org.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=50,validation_data=(X_test,y_test),verbose=1)
# Out:
# Pad sequences to  5000
# ready for 4
# transplanting...
# When the process freezing, please check that datatype_Close has been set correctly
# 00% data has been dealed
# 10% data has been dealed
# 20% data has been dealed
# 30% data has been dealed
# 40% data has been dealed
# 50% data has been dealed
# 60% data has been dealed
# 70% data has been dealed
# 80% data has been dealed
# 90% data has been dealed
# shuffling...
# 00% data has been dealed
# 10% data has been dealed
# 20% data has been dealed
# 30% data has been dealed
# 40% data has been dealed
# 50% data has been dealed
# 60% data has been dealed
# 70% data has been dealed
# 80% data has been dealed
# 90% data has been dealed
# adding noise...
# 00% data has been dealed
# 10% data has been dealed
# 20% data has been dealed
# 30% data has been dealed
# 40% data has been dealed
# 50% data has been dealed
# 60% data has been dealed
# 70% data has been dealed
# 80% data has been dealed
# 90% data has been dealed
# deleting...
# 00% data has been dealed
# 10% data has been dealed
# 20% data has been dealed
# 30% data has been dealed
# 40% data has been dealed
# 50% data has been dealed
# 60% data has been dealed
# 70% data has been dealed
# 80% data has been dealed
# 90% data has been dealed
# the shape of x_train (70700, 5000)
# the shape of y_train (70700, 101)
# the shape of x_test (30300, 5000)
# the shape of y_test (30300, 101)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               640128
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               131584
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# activation_4 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 101)               51813
# _________________________________________________________________
# activation_6 (Activation)    (None, 101)               0
# =================================================================
# Total params: 1,906,661
# Trainable params: 1,906,661
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 70700/70700 [==============================] - 19s 263us/step - loss: 4.1253 - acc: 0.1957 - precision: 0.0556 - recall: 0.0016 - fmeasure: 0.0031 - val_loss: 4.0166 - val_acc: 0.2001 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 123us/step - loss: 4.0159 - acc: 0.1961 - precision: 0.0476 - recall: 8.7694e-04 - fmeasure: 0.0017 - val_loss: 3.9542 - val_acc: 0.2008 - val_precision: 0.0211 - val_recall: 3.6304e-04 - val_fmeasure: 7.1293e-04
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 122us/step - loss: 3.9583 - acc: 0.1960 - precision: 0.0444 - recall: 8.0622e-04 - fmeasure: 0.0016 - val_loss: 3.8898 - val_acc: 0.2009 - val_precision: 0.0148 - val_recall: 2.3102e-04 - val_fmeasure: 4.5494e-04
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 121us/step - loss: 3.8780 - acc: 0.1968 - precision: 0.0786 - recall: 0.0014 - fmeasure: 0.0027 - val_loss: 3.8524 - val_acc: 0.2012 - val_precision: 0.0127 - val_recall: 1.9802e-04 - val_fmeasure: 3.8995e-04
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 122us/step - loss: 3.8282 - acc: 0.1971 - precision: 0.0788 - recall: 0.0013 - fmeasure: 0.0026 - val_loss: 3.8065 - val_acc: 0.2018 - val_precision: 0.0658 - val_recall: 0.0012 - val_fmeasure: 0.0023
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 8s 120us/step - loss: 3.7943 - acc: 0.1980 - precision: 0.0988 - recall: 0.0018 - fmeasure: 0.0036 - val_loss: 3.8000 - val_acc: 0.2031 - val_precision: 0.1162 - val_recall: 0.0021 - val_fmeasure: 0.0041
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 121us/step - loss: 3.7657 - acc: 0.2001 - precision: 0.1798 - recall: 0.0033 - fmeasure: 0.0065 - val_loss: 3.7907 - val_acc: 0.2028 - val_precision: 0.1422 - val_recall: 0.0027 - val_fmeasure: 0.0054
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 123us/step - loss: 3.7409 - acc: 0.2006 - precision: 0.2215 - recall: 0.0044 - fmeasure: 0.0087 - val_loss: 3.7748 - val_acc: 0.2033 - val_precision: 0.1862 - val_recall: 0.0036 - val_fmeasure: 0.0070
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 121us/step - loss: 3.7173 - acc: 0.2022 - precision: 0.2789 - recall: 0.0057 - fmeasure: 0.0111 - val_loss: 3.7738 - val_acc: 0.2053 - val_precision: 0.1943 - val_recall: 0.0038 - val_fmeasure: 0.0074
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 8s 120us/step - loss: 3.6989 - acc: 0.2040 - precision: 0.3411 - recall: 0.0076 - fmeasure: 0.0148 - val_loss: 3.8250 - val_acc: 0.2053 - val_precision: 0.2357 - val_recall: 0.0050 - val_fmeasure: 0.0097
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 122us/step - loss: 3.6777 - acc: 0.2068 - precision: 0.4071 - recall: 0.0100 - fmeasure: 0.0193 - val_loss: 3.8061 - val_acc: 0.2051 - val_precision: 0.2552 - val_recall: 0.0055 - val_fmeasure: 0.0107
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 20s 110us/step - loss: 4.1096 - acc: 0.0887 - precision: 0.2574 - recall: 0.0051 - fmeasure: 0.0099 - val_loss: 3.8964 - val_acc: 0.1950 - val_precision: 0.2832 - val_recall: 0.0058 - val_fmeasure: 0.0113
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 123us/step - loss: 3.6625 - acc: 0.2097 - precision: 0.4560 - recall: 0.0122 - fmeasure: 0.0235 - val_loss: 3.7806 - val_acc: 0.2074 - val_precision: 0.3163 - val_recall: 0.0071 - val_fmeasure: 0.0139
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 20s 109us/step - loss: 4.0543 - acc: 0.0946 - precision: 0.3560 - recall: 0.0077 - fmeasure: 0.0151 - val_loss: 3.8116 - val_acc: 0.1994 - val_precision: 0.3035 - val_recall: 0.0068 - val_fmeasure: 0.0132
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 126us/step - loss: 3.6204 - acc: 0.2123 - precision: 0.5237 - recall: 0.0153 - fmeasure: 0.0295 - val_loss: 3.7352 - val_acc: 0.2070 - val_precision: 0.3301 - val_recall: 0.0088 - val_fmeasure: 0.0170
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 20s 109us/step - loss: 3.9964 - acc: 0.1023 - precision: 0.4326 - recall: 0.0105 - fmeasure: 0.0205 - val_loss: 3.7963 - val_acc: 0.1949 - val_precision: 0.2809 - val_recall: 0.0060 - val_fmeasure: 0.0117
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 120us/step - loss: 3.5690 - acc: 0.2168 - precision: 0.5784 - recall: 0.0183 - fmeasure: 0.0352 - val_loss: 3.7122 - val_acc: 0.2085 - val_precision: 0.3282 - val_recall: 0.0086 - val_fmeasure: 0.0167
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 20s 110us/step - loss: 3.9478 - acc: 0.1093 - precision: 0.4752 - recall: 0.0126 - fmeasure: 0.0244 - val_loss: 3.7491 - val_acc: 0.1979 - val_precision: 0.3154 - val_recall: 0.0078 - val_fmeasure: 0.0150
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 122us/step - loss: 3.5174 - acc: 0.2205 - precision: 0.6120 - recall: 0.0215 - fmeasure: 0.0412 - val_loss: 3.6734 - val_acc: 0.2089 - val_precision: 0.3172 - val_recall: 0.0087 - val_fmeasure: 0.0169
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 20s 110us/step - loss: 3.9053 - acc: 0.1146 - precision: 0.5138 - recall: 0.0147 - fmeasure: 0.0284 - val_loss: 3.7101 - val_acc: 0.1973 - val_precision: 0.3106 - val_recall: 0.0081 - val_fmeasure: 0.0157
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 124us/step - loss: 3.4738 - acc: 0.2248 - precision: 0.6599 - recall: 0.0259 - fmeasure: 0.0494 - val_loss: 3.6801 - val_acc: 0.2088 - val_precision: 0.3400 - val_recall: 0.0109 - val_fmeasure: 0.0209
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 20s 110us/step - loss: 3.8629 - acc: 0.1192 - precision: 0.5591 - recall: 0.0177 - fmeasure: 0.0340 - val_loss: 3.7060 - val_acc: 0.1948 - val_precision: 0.3367 - val_recall: 0.0090 - val_fmeasure: 0.0174
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 122us/step - loss: 3.4359 - acc: 0.2282 - precision: 0.6883 - recall: 0.0290 - fmeasure: 0.0551 - val_loss: 3.6753 - val_acc: 0.2100 - val_precision: 0.3463 - val_recall: 0.0105 - val_fmeasure: 0.0203
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 20s 110us/step - loss: 3.8231 - acc: 0.1265 - precision: 0.6064 - recall: 0.0206 - fmeasure: 0.0394 - val_loss: 3.6986 - val_acc: 0.1905 - val_precision: 0.3384 - val_recall: 0.0098 - val_fmeasure: 0.0189
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 8s 120us/step - loss: 3.3962 - acc: 0.2319 - precision: 0.6945 - recall: 0.0322 - fmeasure: 0.0608 - val_loss: 3.6479 - val_acc: 0.2118 - val_precision: 0.3556 - val_recall: 0.0124 - val_fmeasure: 0.0237
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 20s 109us/step - loss: 3.7874 - acc: 0.1340 - precision: 0.6315 - recall: 0.0236 - fmeasure: 0.0450 - val_loss: 3.7046 - val_acc: 0.1876 - val_precision: 0.3444 - val_recall: 0.0114 - val_fmeasure: 0.0218
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 122us/step - loss: 3.3589 - acc: 0.2371 - precision: 0.7018 - recall: 0.0364 - fmeasure: 0.0685 - val_loss: 3.6524 - val_acc: 0.2094 - val_precision: 0.3316 - val_recall: 0.0125 - val_fmeasure: 0.0238
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 20s 109us/step - loss: 3.7529 - acc: 0.1387 - precision: 0.6442 - recall: 0.0265 - fmeasure: 0.0504 - val_loss: 3.7043 - val_acc: 0.1825 - val_precision: 0.4006 - val_recall: 0.0124 - val_fmeasure: 0.0239
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 123us/step - loss: 3.3290 - acc: 0.2401 - precision: 0.7193 - recall: 0.0403 - fmeasure: 0.0755 - val_loss: 3.6836 - val_acc: 0.2092 - val_precision: 0.3340 - val_recall: 0.0127 - val_fmeasure: 0.0243
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 20s 109us/step - loss: 3.7185 - acc: 0.1443 - precision: 0.6607 - recall: 0.0290 - fmeasure: 0.0549 - val_loss: 3.7302 - val_acc: 0.1773 - val_precision: 0.3783 - val_recall: 0.0131 - val_fmeasure: 0.0251
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 122us/step - loss: 3.2983 - acc: 0.2450 - precision: 0.7265 - recall: 0.0435 - fmeasure: 0.0811 - val_loss: 3.6301 - val_acc: 0.2108 - val_precision: 0.3636 - val_recall: 0.0144 - val_fmeasure: 0.0274
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 20s 109us/step - loss: 3.6899 - acc: 0.1494 - precision: 0.6809 - recall: 0.0318 - fmeasure: 0.0600 - val_loss: 3.6893 - val_acc: 0.1778 - val_precision: 0.3748 - val_recall: 0.0132 - val_fmeasure: 0.0253
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 8s 120us/step - loss: 3.2620 - acc: 0.2493 - precision: 0.7260 - recall: 0.0469 - fmeasure: 0.0870 - val_loss: 3.6287 - val_acc: 0.2110 - val_precision: 0.3762 - val_recall: 0.0166 - val_fmeasure: 0.0315
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 20s 108us/step - loss: 3.6610 - acc: 0.1545 - precision: 0.6930 - recall: 0.0347 - fmeasure: 0.0653 - val_loss: 3.6693 - val_acc: 0.1840 - val_precision: 0.3886 - val_recall: 0.0147 - val_fmeasure: 0.0280
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 121us/step - loss: 3.2280 - acc: 0.2547 - precision: 0.7210 - recall: 0.0512 - fmeasure: 0.0945 - val_loss: 3.6349 - val_acc: 0.2124 - val_precision: 0.3545 - val_recall: 0.0157 - val_fmeasure: 0.0297
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 20s 111us/step - loss: 3.6341 - acc: 0.1591 - precision: 0.6893 - recall: 0.0372 - fmeasure: 0.0697 - val_loss: 3.6871 - val_acc: 0.1755 - val_precision: 0.3872 - val_recall: 0.0142 - val_fmeasure: 0.0270
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 122us/step - loss: 3.1974 - acc: 0.2564 - precision: 0.7213 - recall: 0.0545 - fmeasure: 0.1002 - val_loss: 3.6280 - val_acc: 0.2130 - val_precision: 0.3872 - val_recall: 0.0172 - val_fmeasure: 0.0326
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 20s 109us/step - loss: 3.6016 - acc: 0.1655 - precision: 0.7040 - recall: 0.0395 - fmeasure: 0.0739 - val_loss: 3.6820 - val_acc: 0.1784 - val_precision: 0.3778 - val_recall: 0.0175 - val_fmeasure: 0.0331
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 123us/step - loss: 3.1583 - acc: 0.2639 - precision: 0.7421 - recall: 0.0584 - fmeasure: 0.1070 - val_loss: 3.6648 - val_acc: 0.2121 - val_precision: 0.3582 - val_recall: 0.0180 - val_fmeasure: 0.0339
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 20s 108us/step - loss: 3.5795 - acc: 0.1696 - precision: 0.7008 - recall: 0.0421 - fmeasure: 0.0785 - val_loss: 3.6668 - val_acc: 0.1768 - val_precision: 0.3852 - val_recall: 0.0167 - val_fmeasure: 0.0315
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 123us/step - loss: 3.1414 - acc: 0.2656 - precision: 0.7290 - recall: 0.0608 - fmeasure: 0.1108 - val_loss: 3.6242 - val_acc: 0.2118 - val_precision: 0.3826 - val_recall: 0.0192 - val_fmeasure: 0.0361
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 122us/step - loss: 3.0970 - acc: 0.2723 - precision: 0.7402 - recall: 0.0661 - fmeasure: 0.1199 - val_loss: 3.6426 - val_acc: 0.2122 - val_precision: 0.3746 - val_recall: 0.0214 - val_fmeasure: 0.0400
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 126us/step - loss: 3.0739 - acc: 0.2755 - precision: 0.7558 - recall: 0.0703 - fmeasure: 0.1271 - val_loss: 3.7026 - val_acc: 0.2076 - val_precision: 0.3648 - val_recall: 0.0219 - val_fmeasure: 0.0409
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 124us/step - loss: 3.0494 - acc: 0.2783 - precision: 0.7439 - recall: 0.0721 - fmeasure: 0.1300 - val_loss: 3.6489 - val_acc: 0.2126 - val_precision: 0.3709 - val_recall: 0.0228 - val_fmeasure: 0.0424
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 8s 120us/step - loss: 3.0263 - acc: 0.2820 - precision: 0.7529 - recall: 0.0759 - fmeasure: 0.1363 - val_loss: 3.6957 - val_acc: 0.2086 - val_precision: 0.3500 - val_recall: 0.0225 - val_fmeasure: 0.0417
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 122us/step - loss: 3.0094 - acc: 0.2839 - precision: 0.7465 - recall: 0.0777 - fmeasure: 0.1390 - val_loss: 3.7028 - val_acc: 0.2084 - val_precision: 0.3725 - val_recall: 0.0229 - val_fmeasure: 0.0426
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 124us/step - loss: 2.9844 - acc: 0.2873 - precision: 0.7517 - recall: 0.0802 - fmeasure: 0.1433 - val_loss: 3.7022 - val_acc: 0.2084 - val_precision: 0.3591 - val_recall: 0.0247 - val_fmeasure: 0.0456
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 124us/step - loss: 2.9690 - acc: 0.2902 - precision: 0.7375 - recall: 0.0825 - fmeasure: 0.1467 - val_loss: 3.7152 - val_acc: 0.2074 - val_precision: 0.3462 - val_recall: 0.0253 - val_fmeasure: 0.0466
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 122us/step - loss: 2.9532 - acc: 0.2905 - precision: 0.7498 - recall: 0.0855 - fmeasure: 0.1517 - val_loss: 3.7136 - val_acc: 0.2115 - val_precision: 0.3463 - val_recall: 0.0249 - val_fmeasure: 0.0458
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 9s 124us/step - loss: 2.9293 - acc: 0.2976 - precision: 0.7488 - recall: 0.0888 - fmeasure: 0.1570 - val_loss: 3.7076 - val_acc: 0.2083 - val_precision: 0.3548 - val_recall: 0.0239 - val_fmeasure: 0.0442
# base_line_now#######################################################################################################################################################################################################
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/50
# 70700/70700 [==============================] - 9s 133us/step - loss: 4.1237 - acc: 0.1957 - precision: 0.0663 - recall: 0.0019 - fmeasure: 0.0037 - val_loss: 4.0179 - val_acc: 0.2009 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fmeasure: 0.0000e+00
# Epoch 2/50
# 70700/70700 [==============================] - 9s 125us/step - loss: 4.0072 - acc: 0.1954 - precision: 0.0426 - recall: 8.3451e-04 - fmeasure: 0.0016 - val_loss: 3.9366 - val_acc: 0.2009 - val_precision: 0.0021 - val_recall: 3.3003e-05 - val_fmeasure: 6.4991e-05
# Epoch 3/50
# 70700/70700 [==============================] - 9s 129us/step - loss: 3.9095 - acc: 0.1963 - precision: 0.0372 - recall: 6.9307e-04 - fmeasure: 0.0014 - val_loss: 3.8418 - val_acc: 0.2010 - val_precision: 0.0021 - val_recall: 3.3003e-05 - val_fmeasure: 6.4991e-05
# Epoch 4/50
# 70700/70700 [==============================] - 9s 127us/step - loss: 3.8412 - acc: 0.1962 - precision: 0.0587 - recall: 9.9010e-04 - fmeasure: 0.0019 - val_loss: 3.8016 - val_acc: 0.2015 - val_precision: 0.0084 - val_recall: 1.3201e-04 - val_fmeasure: 2.5996e-04
# Epoch 5/50
# 70700/70700 [==============================] - 9s 129us/step - loss: 3.7758 - acc: 0.1979 - precision: 0.1058 - recall: 0.0018 - fmeasure: 0.0036 - val_loss: 3.7400 - val_acc: 0.2042 - val_precision: 0.0943 - val_recall: 0.0017 - val_fmeasure: 0.0034
# Epoch 6/50
# 70700/70700 [==============================] - 9s 128us/step - loss: 3.7226 - acc: 0.2005 - precision: 0.1623 - recall: 0.0032 - fmeasure: 0.0062 - val_loss: 3.7138 - val_acc: 0.2050 - val_precision: 0.0570 - val_recall: 9.5710e-04 - val_fmeasure: 0.0019
# Epoch 7/50
# 70700/70700 [==============================] - 9s 126us/step - loss: 3.6778 - acc: 0.2023 - precision: 0.2252 - recall: 0.0045 - fmeasure: 0.0088 - val_loss: 3.7065 - val_acc: 0.2057 - val_precision: 0.0739 - val_recall: 0.0013 - val_fmeasure: 0.0026
# Epoch 8/50
# 70700/70700 [==============================] - 9s 128us/step - loss: 3.6361 - acc: 0.2044 - precision: 0.2800 - recall: 0.0058 - fmeasure: 0.0114 - val_loss: 3.6856 - val_acc: 0.2063 - val_precision: 0.1676 - val_recall: 0.0032 - val_fmeasure: 0.0063
# Epoch 9/50
# 70700/70700 [==============================] - 9s 127us/step - loss: 3.5977 - acc: 0.2074 - precision: 0.3324 - recall: 0.0079 - fmeasure: 0.0153 - val_loss: 3.6811 - val_acc: 0.2083 - val_precision: 0.2147 - val_recall: 0.0045 - val_fmeasure: 0.0087
# Epoch 10/50
# 70700/70700 [==============================] - 9s 127us/step - loss: 3.5633 - acc: 0.2101 - precision: 0.4104 - recall: 0.0103 - fmeasure: 0.0199 - val_loss: 3.6429 - val_acc: 0.2105 - val_precision: 0.2993 - val_recall: 0.0070 - val_fmeasure: 0.0137
# Epoch 11/50
# 70700/70700 [==============================] - 9s 128us/step - loss: 3.5308 - acc: 0.2142 - precision: 0.4572 - recall: 0.0126 - fmeasure: 0.0243 - val_loss: 3.6324 - val_acc: 0.2099 - val_precision: 0.2851 - val_recall: 0.0068 - val_fmeasure: 0.0132
# Epoch 12/50
# 70700/70700 [==============================] - 9s 126us/step - loss: 3.4983 - acc: 0.2158 - precision: 0.5035 - recall: 0.0149 - fmeasure: 0.0286 - val_loss: 3.6106 - val_acc: 0.2113 - val_precision: 0.3165 - val_recall: 0.0080 - val_fmeasure: 0.0154
# Epoch 13/50
# 70700/70700 [==============================] - 9s 125us/step - loss: 3.4632 - acc: 0.2189 - precision: 0.5172 - recall: 0.0166 - fmeasure: 0.0319 - val_loss: 3.6212 - val_acc: 0.2095 - val_precision: 0.3077 - val_recall: 0.0078 - val_fmeasure: 0.0150
# Epoch 14/50
# 70700/70700 [==============================] - 9s 126us/step - loss: 3.4309 - acc: 0.2217 - precision: 0.5623 - recall: 0.0193 - fmeasure: 0.0370 - val_loss: 3.5894 - val_acc: 0.2109 - val_precision: 0.3512 - val_recall: 0.0086 - val_fmeasure: 0.0166
# Epoch 15/50
# 70700/70700 [==============================] - 9s 125us/step - loss: 3.4051 - acc: 0.2246 - precision: 0.5767 - recall: 0.0209 - fmeasure: 0.0399 - val_loss: 3.5862 - val_acc: 0.2131 - val_precision: 0.3435 - val_recall: 0.0089 - val_fmeasure: 0.0172
# Epoch 16/50
# 70700/70700 [==============================] - 9s 126us/step - loss: 3.3782 - acc: 0.2271 - precision: 0.6027 - recall: 0.0224 - fmeasure: 0.0427 - val_loss: 3.6815 - val_acc: 0.2082 - val_precision: 0.3578 - val_recall: 0.0115 - val_fmeasure: 0.0221
# Epoch 17/50
# 70700/70700 [==============================] - 9s 125us/step - loss: 3.3504 - acc: 0.2303 - precision: 0.6080 - recall: 0.0257 - fmeasure: 0.0487 - val_loss: 3.5890 - val_acc: 0.2127 - val_precision: 0.3827 - val_recall: 0.0117 - val_fmeasure: 0.0225
# Epoch 18/50
# 70700/70700 [==============================] - 9s 130us/step - loss: 3.3263 - acc: 0.2326 - precision: 0.6163 - recall: 0.0274 - fmeasure: 0.0519 - val_loss: 3.6016 - val_acc: 0.2126 - val_precision: 0.3817 - val_recall: 0.0115 - val_fmeasure: 0.0221
# Epoch 19/50
# 70700/70700 [==============================] - 9s 127us/step - loss: 3.3052 - acc: 0.2352 - precision: 0.6490 - recall: 0.0298 - fmeasure: 0.0564 - val_loss: 3.6119 - val_acc: 0.2122 - val_precision: 0.3852 - val_recall: 0.0142 - val_fmeasure: 0.0271
# Epoch 20/50
# 70700/70700 [==============================] - 9s 124us/step - loss: 3.2766 - acc: 0.2390 - precision: 0.6566 - recall: 0.0329 - fmeasure: 0.0620 - val_loss: 3.5802 - val_acc: 0.2156 - val_precision: 0.3761 - val_recall: 0.0139 - val_fmeasure: 0.0266
# Epoch 21/50
# 70700/70700 [==============================] - 9s 126us/step - loss: 3.2560 - acc: 0.2424 - precision: 0.6818 - recall: 0.0359 - fmeasure: 0.0674 - val_loss: 3.6223 - val_acc: 0.2120 - val_precision: 0.3769 - val_recall: 0.0153 - val_fmeasure: 0.0292
# Epoch 22/50
# 70700/70700 [==============================] - 9s 124us/step - loss: 3.2318 - acc: 0.2460 - precision: 0.6749 - recall: 0.0381 - fmeasure: 0.0713 - val_loss: 3.6028 - val_acc: 0.2130 - val_precision: 0.3582 - val_recall: 0.0129 - val_fmeasure: 0.0247
# Epoch 23/50
# 70700/70700 [==============================] - 9s 127us/step - loss: 3.2166 - acc: 0.2455 - precision: 0.6872 - recall: 0.0401 - fmeasure: 0.0748 - val_loss: 3.6282 - val_acc: 0.2126 - val_precision: 0.3927 - val_recall: 0.0166 - val_fmeasure: 0.0315
# Epoch 24/50
# 70700/70700 [==============================] - 9s 126us/step - loss: 3.1923 - acc: 0.2501 - precision: 0.6837 - recall: 0.0441 - fmeasure: 0.0818 - val_loss: 3.6498 - val_acc: 0.2135 - val_precision: 0.3914 - val_recall: 0.0173 - val_fmeasure: 0.0328
# Epoch 25/50
# 70700/70700 [==============================] - 9s 127us/step - loss: 3.1682 - acc: 0.2535 - precision: 0.6954 - recall: 0.0460 - fmeasure: 0.0853 - val_loss: 3.6162 - val_acc: 0.2137 - val_precision: 0.3971 - val_recall: 0.0185 - val_fmeasure: 0.0350
# Epoch 26/50
# 70700/70700 [==============================] - 9s 125us/step - loss: 3.1472 - acc: 0.2557 - precision: 0.6932 - recall: 0.0496 - fmeasure: 0.0915 - val_loss: 3.6476 - val_acc: 0.2127 - val_precision: 0.3865 - val_recall: 0.0179 - val_fmeasure: 0.0339
# Epoch 27/50
# 70700/70700 [==============================] - 9s 129us/step - loss: 3.1377 - acc: 0.2585 - precision: 0.6980 - recall: 0.0499 - fmeasure: 0.0921 - val_loss: 3.5912 - val_acc: 0.2166 - val_precision: 0.3925 - val_recall: 0.0181 - val_fmeasure: 0.0342
# Epoch 28/50
# 70700/70700 [==============================] - 9s 133us/step - loss: 3.1094 - acc: 0.2614 - precision: 0.7024 - recall: 0.0532 - fmeasure: 0.0976 - val_loss: 3.6353 - val_acc: 0.2132 - val_precision: 0.3816 - val_recall: 0.0206 - val_fmeasure: 0.0387
# Epoch 29/50
# 70700/70700 [==============================] - 9s 125us/step - loss: 3.1015 - acc: 0.2617 - precision: 0.7028 - recall: 0.0548 - fmeasure: 0.1005 - val_loss: 3.6402 - val_acc: 0.2095 - val_precision: 0.3726 - val_recall: 0.0208 - val_fmeasure: 0.0390
# Epoch 30/50
# 70700/70700 [==============================] - 9s 126us/step - loss: 3.0762 - acc: 0.2672 - precision: 0.7039 - recall: 0.0579 - fmeasure: 0.1058 - val_loss: 3.6498 - val_acc: 0.2101 - val_precision: 0.3767 - val_recall: 0.0197 - val_fmeasure: 0.0369
# Epoch 31/50
# 70700/70700 [==============================] - 9s 128us/step - loss: 3.0654 - acc: 0.2667 - precision: 0.7106 - recall: 0.0598 - fmeasure: 0.1090 - val_loss: 3.6721 - val_acc: 0.2106 - val_precision: 0.3707 - val_recall: 0.0207 - val_fmeasure: 0.0387
# Epoch 32/50
# 70700/70700 [==============================] - 9s 128us/step - loss: 3.0439 - acc: 0.2693 - precision: 0.7083 - recall: 0.0626 - fmeasure: 0.1137 - val_loss: 3.7328 - val_acc: 0.2106 - val_precision: 0.3580 - val_recall: 0.0199 - val_fmeasure: 0.0373
# Epoch 33/50
# 70700/70700 [==============================] - 9s 125us/step - loss: 3.0297 - acc: 0.2723 - precision: 0.7176 - recall: 0.0640 - fmeasure: 0.1162 - val_loss: 3.7119 - val_acc: 0.2057 - val_precision: 0.3609 - val_recall: 0.0239 - val_fmeasure: 0.0443
# Epoch 34/50
# 70700/70700 [==============================] - 9s 125us/step - loss: 3.0108 - acc: 0.2741 - precision: 0.7193 - recall: 0.0676 - fmeasure: 0.1222 - val_loss: 3.6896 - val_acc: 0.2091 - val_precision: 0.3780 - val_recall: 0.0237 - val_fmeasure: 0.0442
# Epoch 35/50
# 70700/70700 [==============================] - 9s 122us/step - loss: 2.9984 - acc: 0.2768 - precision: 0.7239 - recall: 0.0689 - fmeasure: 0.1242 - val_loss: 3.7222 - val_acc: 0.2086 - val_precision: 0.3603 - val_recall: 0.0232 - val_fmeasure: 0.0431
# Epoch 36/50
# 70700/70700 [==============================] - 9s 125us/step - loss: 2.9798 - acc: 0.2803 - precision: 0.7162 - recall: 0.0735 - fmeasure: 0.1319 - val_loss: 3.6946 - val_acc: 0.2112 - val_precision: 0.3820 - val_recall: 0.0207 - val_fmeasure: 0.0388
# Epoch 37/50
# 70700/70700 [==============================] - 9s 122us/step - loss: 2.9607 - acc: 0.2836 - precision: 0.7256 - recall: 0.0755 - fmeasure: 0.1352 - val_loss: 3.7406 - val_acc: 0.2083 - val_precision: 0.3634 - val_recall: 0.0251 - val_fmeasure: 0.0465
# Epoch 38/50
# 70700/70700 [==============================] - 9s 123us/step - loss: 2.9494 - acc: 0.2849 - precision: 0.7246 - recall: 0.0765 - fmeasure: 0.1368 - val_loss: 3.7213 - val_acc: 0.2084 - val_precision: 0.3785 - val_recall: 0.0235 - val_fmeasure: 0.0437
# Epoch 39/50
# 70700/70700 [==============================] - 9s 121us/step - loss: 2.9374 - acc: 0.2885 - precision: 0.7371 - recall: 0.0801 - fmeasure: 0.1429 - val_loss: 3.7294 - val_acc: 0.2085 - val_precision: 0.3548 - val_recall: 0.0249 - val_fmeasure: 0.0459
# Epoch 40/50
# 70700/70700 [==============================] - 9s 123us/step - loss: 2.9238 - acc: 0.2901 - precision: 0.7298 - recall: 0.0813 - fmeasure: 0.1448 - val_loss: 3.7235 - val_acc: 0.2078 - val_precision: 0.3613 - val_recall: 0.0235 - val_fmeasure: 0.0436
# Epoch 41/50
# 70700/70700 [==============================] - 9s 123us/step - loss: 2.9057 - acc: 0.2923 - precision: 0.7308 - recall: 0.0836 - fmeasure: 0.1484 - val_loss: 3.7518 - val_acc: 0.2034 - val_precision: 0.3526 - val_recall: 0.0252 - val_fmeasure: 0.0465
# Epoch 42/50
# 70700/70700 [==============================] - 9s 121us/step - loss: 2.8844 - acc: 0.2954 - precision: 0.7338 - recall: 0.0876 - fmeasure: 0.1549 - val_loss: 3.7646 - val_acc: 0.2077 - val_precision: 0.3375 - val_recall: 0.0237 - val_fmeasure: 0.0438
# Epoch 43/50
# 70700/70700 [==============================] - 9s 123us/step - loss: 2.8843 - acc: 0.2957 - precision: 0.7390 - recall: 0.0885 - fmeasure: 0.1564 - val_loss: 3.7680 - val_acc: 0.2058 - val_precision: 0.3576 - val_recall: 0.0256 - val_fmeasure: 0.0472
# Epoch 44/50
# 70700/70700 [==============================] - 9s 122us/step - loss: 2.8706 - acc: 0.2981 - precision: 0.7295 - recall: 0.0897 - fmeasure: 0.1581 - val_loss: 3.8061 - val_acc: 0.2035 - val_precision: 0.3325 - val_recall: 0.0267 - val_fmeasure: 0.0489
# Epoch 45/50
# 70700/70700 [==============================] - 9s 123us/step - loss: 2.8524 - acc: 0.3007 - precision: 0.7399 - recall: 0.0934 - fmeasure: 0.1640 - val_loss: 3.7943 - val_acc: 0.2048 - val_precision: 0.3401 - val_recall: 0.0267 - val_fmeasure: 0.0490
# Epoch 46/50
# 70700/70700 [==============================] - 9s 121us/step - loss: 2.8444 - acc: 0.3039 - precision: 0.7390 - recall: 0.0953 - fmeasure: 0.1671 - val_loss: 3.8088 - val_acc: 0.2031 - val_precision: 0.3309 - val_recall: 0.0279 - val_fmeasure: 0.0508
# Epoch 47/50
# 70700/70700 [==============================] - 9s 122us/step - loss: 2.8215 - acc: 0.3061 - precision: 0.7469 - recall: 0.0983 - fmeasure: 0.1718 - val_loss: 3.8542 - val_acc: 0.2023 - val_precision: 0.3189 - val_recall: 0.0305 - val_fmeasure: 0.0551
# Epoch 48/50
# 70700/70700 [==============================] - 9s 122us/step - loss: 2.8119 - acc: 0.3077 - precision: 0.7423 - recall: 0.0996 - fmeasure: 0.1738 - val_loss: 3.8795 - val_acc: 0.2009 - val_precision: 0.3066 - val_recall: 0.0267 - val_fmeasure: 0.0487
# Epoch 49/50
# 70700/70700 [==============================] - 9s 122us/step - loss: 2.8076 - acc: 0.3089 - precision: 0.7419 - recall: 0.1005 - fmeasure: 0.1751 - val_loss: 3.8723 - val_acc: 0.1984 - val_precision: 0.3114 - val_recall: 0.0267 - val_fmeasure: 0.0485
# Epoch 50/50
# 70700/70700 [==============================] - 9s 122us/step - loss: 2.7905 - acc: 0.3106 - precision: 0.7427 - recall: 0.1034 - fmeasure: 0.1796 - val_loss: 3.8600 - val_acc: 0.1963 - val_precision: 0.3221 - val_recall: 0.0284 - val_fmeasure: 0.0516

# %%
#CNN               ############# test for noise adding  , function :: creat_data############

BATCH_SIZE = 64
NB_EPOCHS = 50
VALIDATION_SPLIT = 0.3

OPTIMIZER = Adamax()

historys_DNN = []
NB_tech = [4,4,4,4]

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)


print('Pad sequences to ',maxlen)
print('ready for 4')

#X_4,y_4 = random_launch(X_train,y_train,NB_tech[0])
#X_4 = sequence.pad_sequences(X_4, maxlen=maxlen,padding='post',truncating='post')
X_4 = X_4[:,:,np.newaxis]
#y_4 = np_utils.to_categorical(y_4, NB_CLASSES)
'''
print('ready for 3')
X_3,y_3 = random_launch(X_train,y_train,NB_tech[1])
X_3 = sequence.pad_sequences(X_3, maxlen=maxlen,padding='post',truncating='post')
X_3 = X_3[:,:,np.newaxis]
y_3 = np_utils.to_categorical(y_3, NB_CLASSES)
print('ready for 2')
X_2,y_2 = random_launch(X_train,y_train,NB_tech[2])
X_2 = sequence.pad_sequences(X_2, maxlen=maxlen,padding='post',truncating='post')
X_2 = X_2[:,:,np.newaxis]
y_2 = np_utils.to_categorical(y_2, NB_CLASSES)
print('ready for 1')
X_1,y_1 = random_launch(X_train,y_train,NB_tech[3])
X_1 = sequence.pad_sequences(X_1, maxlen=maxlen,padding='post',truncating='post')
X_1 = X_1[:,:,np.newaxis]
y_1 = np_utils.to_categorical(y_1, NB_CLASSES)

'''
X_train = sequence.pad_sequences(X_train, maxlen=maxlen,padding='post',truncating='post')
X_train = X_train[:,:,np.newaxis]
y_train = np_utils.to_categorical(y_train, NB_CLASSES)
X_test = sequence.pad_sequences(X_test, maxlen=maxlen,padding='post',truncating='post')
X_test = X_test[:,:,np.newaxis]

y_test = np_utils.to_categorical(y_test, NB_CLASSES)

print('the shape of x_train',X_train.shape)
print('the shape of y_train',y_train.shape)
print('the shape of x_test',X_test.shape)
print('the shape of y_test',y_test.shape)
model_CNN = CNN(maxlen,NB_CLASSES)
model_CNN.summary()
model_CNN.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])




history_CNN_loss = []
history_CNN_acc = []
history_CNN_precision = []
history_CNN_recall = []
history_CNN_fmeasure = []
history_CNN_val_loss = []
history_CNN_val_acc = []
history_CNN_val_precision = []
history_CNN_val_recall = []
history_CNN_val_fmeasure = []

def recorder_CNN(history):
    history_CNN_loss.append(history.history['loss'][0])
    history_CNN_acc.append(history.history['acc'][0])
    history_CNN_precision.append(history.history['precision'][0])
    history_CNN_recall.append(history.history['recall'][0])
    history_CNN_fmeasure.append(history.history['fmeasure'][0])
    history_CNN_val_loss.append(history.history['val_loss'][0])
    history_CNN_val_acc.append(history.history['val_acc'][0])
    history_CNN_val_precision.append(history.history['val_precision'][0])
    history_CNN_val_recall.append(history.history['val_recall'][0])
    history_CNN_val_fmeasure.append(history.history['val_fmeasure'][0])


for i in range(NB_EPOCHS):
    if (i<=NB_EPOCHS/5):
        history = model_CNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)
    elif (NB_EPOCHS/5<i and i%2==1 and i<(NB_EPOCHS*4/5)):
        history = model_CNN.fit(X_4,y_4,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)
    elif (NB_EPOCHS/5<i and i%2==0 and i<(NB_EPOCHS*4/5)):
        history = model_CNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)
    else:
        history = model_CNN.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(X_test,y_test),verbose=1)
        recorder_CNN(history)

print('base_line_now')
model_CNN_org = CNN(maxlen,NB_CLASSES)
model_CNN_org.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy', precision, recall, fmeasure])
history_CNN_org = model_CNN_org.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=50,validation_data=(X_test,y_test),verbose=1)
# Out:
# Pad sequences to  5000
# ready for 4
# the shape of x_train (70700, 5000, 1)
# the shape of y_train (70700, 101)
# the shape of x_test (30300, 5000, 1)
# the shape of y_test (30300, 101)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv1D)        (None, 5000, 32)          288
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 5000, 32)          128
# _________________________________________________________________
# block1_adv_act1 (ELU)        (None, 5000, 32)          0
# _________________________________________________________________
# block1_conv2 (Conv1D)        (None, 5000, 32)          8224
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 5000, 32)          128
# _________________________________________________________________
# block1_adv_act2 (ELU)        (None, 5000, 32)          0
# _________________________________________________________________
# block1_pool (MaxPooling1D)   (None, 1250, 32)          0
# _________________________________________________________________
# block1_dropout (Dropout)     (None, 1250, 32)          0
# _________________________________________________________________
# block2_conv1 (Conv1D)        (None, 1250, 64)          16448
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1250, 64)          256
# _________________________________________________________________
# block2_act1 (Activation)     (None, 1250, 64)          0
# _________________________________________________________________
# block2_conv2 (Conv1D)        (None, 1250, 64)          32832
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1250, 64)          256
# _________________________________________________________________
# block2_act2 (Activation)     (None, 1250, 64)          0
# _________________________________________________________________
# block2_pool (MaxPooling1D)   (None, 313, 64)           0
# _________________________________________________________________
# block2_dropout (Dropout)     (None, 313, 64)           0
# _________________________________________________________________
# block3_conv1 (Conv1D)        (None, 313, 128)          65664
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 313, 128)          512
# _________________________________________________________________
# block3_act1 (Activation)     (None, 313, 128)          0
# _________________________________________________________________
# block3_conv2 (Conv1D)        (None, 313, 128)          131200
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 313, 128)          512
# _________________________________________________________________
# block3_act2 (Activation)     (None, 313, 128)          0
# _________________________________________________________________
# block3_pool (MaxPooling1D)   (None, 79, 128)           0
# _________________________________________________________________
# block3_dropout (Dropout)     (None, 79, 128)           0
# _________________________________________________________________
# block4_conv1 (Conv1D)        (None, 79, 256)           262400
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 79, 256)           1024
# _________________________________________________________________
# block4_act1 (Activation)     (None, 79, 256)           0
# _________________________________________________________________
# block4_conv2 (Conv1D)        (None, 79, 256)           524544
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 79, 256)           1024
# _________________________________________________________________
# block4_act2 (Activation)     (None, 79, 256)           0
# _________________________________________________________________
# block4_pool (MaxPooling1D)   (None, 20, 256)           0
# _________________________________________________________________
# block4_dropout (Dropout)     (None, 20, 256)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 5120)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 512)               2621952
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 512)               2048
# _________________________________________________________________
# fc1_act (Activation)         (None, 512)               0
# _________________________________________________________________
# fc1_dropout (Dropout)        (None, 512)               0
# _________________________________________________________________
# fc2 (Dense)                  (None, 512)               262656
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# fc2_act (Activation)         (None, 512)               0
# _________________________________________________________________
# fc2_dropout (Dropout)        (None, 512)               0
# _________________________________________________________________
# fc3 (Dense)                  (None, 101)               51813
# _________________________________________________________________
# softmax (Activation)         (None, 101)               0
# =================================================================
# Total params: 3,985,957
# Trainable params: 3,981,989
# Non-trainable params: 3,968
# _________________________________________________________________
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 77s 1ms/step - loss: 3.9064 - acc: 0.1746 - precision: 0.1851 - recall: 0.0064 - fmeasure: 0.0122 - val_loss: 3.0916 - val_acc: 0.2619 - val_precision: 0.5012 - val_recall: 0.0162 - val_fmeasure: 0.0312
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 69s 975us/step - loss: 3.1636 - acc: 0.2243 - precision: 0.4451 - recall: 0.0200 - fmeasure: 0.0379 - val_loss: 2.7537 - val_acc: 0.2977 - val_precision: 0.5379 - val_recall: 0.0626 - val_fmeasure: 0.1110
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 69s 972us/step - loss: 2.8273 - acc: 0.2732 - precision: 0.5582 - recall: 0.0523 - fmeasure: 0.0946 - val_loss: 2.5340 - val_acc: 0.3449 - val_precision: 0.6271 - val_recall: 0.0969 - val_fmeasure: 0.1663
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 69s 971us/step - loss: 2.5944 - acc: 0.3132 - precision: 0.5850 - recall: 0.0854 - fmeasure: 0.1476 - val_loss: 2.2419 - val_acc: 0.4102 - val_precision: 0.6670 - val_recall: 0.1736 - val_fmeasure: 0.2736
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 69s 972us/step - loss: 2.4297 - acc: 0.3461 - precision: 0.6119 - recall: 0.1167 - fmeasure: 0.1944 - val_loss: 2.1948 - val_acc: 0.4214 - val_precision: 0.6775 - val_recall: 0.1685 - val_fmeasure: 0.2679
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 69s 969us/step - loss: 2.3014 - acc: 0.3717 - precision: 0.6256 - recall: 0.1471 - fmeasure: 0.2365 - val_loss: 2.0290 - val_acc: 0.4649 - val_precision: 0.6771 - val_recall: 0.2291 - val_fmeasure: 0.3404
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 68s 969us/step - loss: 2.1883 - acc: 0.3994 - precision: 0.6426 - recall: 0.1765 - fmeasure: 0.2751 - val_loss: 1.9566 - val_acc: 0.4794 - val_precision: 0.6810 - val_recall: 0.2541 - val_fmeasure: 0.3683
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 69s 970us/step - loss: 2.0914 - acc: 0.4200 - precision: 0.6523 - recall: 0.1978 - fmeasure: 0.3018 - val_loss: 1.8912 - val_acc: 0.4863 - val_precision: 0.6832 - val_recall: 0.2641 - val_fmeasure: 0.3793
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 69s 971us/step - loss: 2.0159 - acc: 0.4345 - precision: 0.6575 - recall: 0.2213 - fmeasure: 0.3294 - val_loss: 1.7916 - val_acc: 0.5216 - val_precision: 0.6930 - val_recall: 0.3136 - val_fmeasure: 0.4300
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 69s 970us/step - loss: 1.9355 - acc: 0.4560 - precision: 0.6705 - recall: 0.2442 - fmeasure: 0.3565 - val_loss: 1.7674 - val_acc: 0.5240 - val_precision: 0.6936 - val_recall: 0.3182 - val_fmeasure: 0.4345
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 68s 969us/step - loss: 1.8603 - acc: 0.4718 - precision: 0.6830 - recall: 0.2655 - fmeasure: 0.3808 - val_loss: 1.7352 - val_acc: 0.5295 - val_precision: 0.6971 - val_recall: 0.3265 - val_fmeasure: 0.4430
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 166s 901us/step - loss: 2.5303 - acc: 0.3768 - precision: 0.6863 - recall: 0.1855 - fmeasure: 0.2904 - val_loss: 1.7568 - val_acc: 0.5408 - val_precision: 0.7069 - val_recall: 0.3603 - val_fmeasure: 0.4757
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 70s 984us/step - loss: 1.7932 - acc: 0.4927 - precision: 0.7002 - recall: 0.2767 - fmeasure: 0.3947 - val_loss: 1.6061 - val_acc: 0.5651 - val_precision: 0.7082 - val_recall: 0.3838 - val_fmeasure: 0.4963
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 167s 909us/step - loss: 2.2849 - acc: 0.4288 - precision: 0.7151 - recall: 0.2375 - fmeasure: 0.3547 - val_loss: 1.6644 - val_acc: 0.5657 - val_precision: 0.7230 - val_recall: 0.4113 - val_fmeasure: 0.5229
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 69s 976us/step - loss: 1.6838 - acc: 0.5167 - precision: 0.7094 - recall: 0.3152 - fmeasure: 0.4348 - val_loss: 1.5230 - val_acc: 0.5858 - val_precision: 0.7189 - val_recall: 0.4163 - val_fmeasure: 0.5258
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 170s 926us/step - loss: 2.1320 - acc: 0.4633 - precision: 0.7314 - recall: 0.2779 - fmeasure: 0.4011 - val_loss: 1.5475 - val_acc: 0.5863 - val_precision: 0.7339 - val_recall: 0.4403 - val_fmeasure: 0.5491
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 71s 1ms/step - loss: 1.5955 - acc: 0.5387 - precision: 0.7188 - recall: 0.3479 - fmeasure: 0.4673 - val_loss: 1.4466 - val_acc: 0.6016 - val_precision: 0.7300 - val_recall: 0.4369 - val_fmeasure: 0.5452
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 172s 933us/step - loss: 2.0066 - acc: 0.4898 - precision: 0.7471 - recall: 0.3116 - fmeasure: 0.4381 - val_loss: 1.4841 - val_acc: 0.6045 - val_precision: 0.7295 - val_recall: 0.4795 - val_fmeasure: 0.5775
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 70s 994us/step - loss: 1.5113 - acc: 0.5582 - precision: 0.7271 - recall: 0.3794 - fmeasure: 0.4972 - val_loss: 1.3729 - val_acc: 0.6180 - val_precision: 0.7338 - val_recall: 0.4671 - val_fmeasure: 0.5695
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 167s 910us/step - loss: 1.9057 - acc: 0.5119 - precision: 0.7593 - recall: 0.3391 - fmeasure: 0.4673 - val_loss: 1.4273 - val_acc: 0.6167 - val_precision: 0.7464 - val_recall: 0.4967 - val_fmeasure: 0.5953
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 69s 978us/step - loss: 1.4402 - acc: 0.5776 - precision: 0.7370 - recall: 0.4055 - fmeasure: 0.5218 - val_loss: 1.3089 - val_acc: 0.6387 - val_precision: 0.7443 - val_recall: 0.5010 - val_fmeasure: 0.5978
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 168s 914us/step - loss: 1.8158 - acc: 0.5317 - precision: 0.7691 - recall: 0.3668 - fmeasure: 0.4952 - val_loss: 1.4260 - val_acc: 0.6291 - val_precision: 0.7403 - val_recall: 0.5298 - val_fmeasure: 0.6167
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 70s 990us/step - loss: 1.3768 - acc: 0.5930 - precision: 0.7446 - recall: 0.4321 - fmeasure: 0.5455 - val_loss: 1.2832 - val_acc: 0.6417 - val_precision: 0.7472 - val_recall: 0.5072 - val_fmeasure: 0.6031
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 167s 911us/step - loss: 1.7435 - acc: 0.5479 - precision: 0.7777 - recall: 0.3888 - fmeasure: 0.5169 - val_loss: 1.2987 - val_acc: 0.6498 - val_precision: 0.7568 - val_recall: 0.5444 - val_fmeasure: 0.6323
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 69s 982us/step - loss: 1.3173 - acc: 0.6060 - precision: 0.7514 - recall: 0.4517 - fmeasure: 0.5629 - val_loss: 1.2289 - val_acc: 0.6567 - val_precision: 0.7550 - val_recall: 0.5398 - val_fmeasure: 0.6285
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 167s 910us/step - loss: 1.6681 - acc: 0.5657 - precision: 0.7850 - recall: 0.4108 - fmeasure: 0.5379 - val_loss: 1.2782 - val_acc: 0.6568 - val_precision: 0.7603 - val_recall: 0.5585 - val_fmeasure: 0.6431
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 69s 982us/step - loss: 1.2641 - acc: 0.6191 - precision: 0.7593 - recall: 0.4740 - fmeasure: 0.5825 - val_loss: 1.2003 - val_acc: 0.6619 - val_precision: 0.7606 - val_recall: 0.5490 - val_fmeasure: 0.6367
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
# 183820/183820 [==============================] - 168s 912us/step - loss: 1.6059 - acc: 0.5803 - precision: 0.7917 - recall: 0.4314 - fmeasure: 0.5571 - val_loss: 1.2858 - val_acc: 0.6596 - val_precision: 0.7631 - val_recall: 0.5705 - val_fmeasure: 0.6520
# Train on 70700 samples, validate on 30300 samples
# Epoch 1/1
# 70700/70700 [==============================] - 69s 981us/step - loss: 1.2219 - acc: 0.6332 - precision: 0.7620 - recall: 0.4922 - fmeasure: 0.5970 - val_loss: 1.1775 - val_acc: 0.6713 - val_precision: 0.7621 - val_recall: 0.5672 - val_fmeasure: 0.6495
# Train on 183820 samples, validate on 30300 samples
# Epoch 1/1
#  57856/183820 [========>.....................] - ETA: 1:49 - loss: 1.5553 - acc: 0.5914 - precision: 0.7975 - recall: 0.4501 - fmeasure: 0.5741Buffered data was truncated after reaching the output size limit.

# %%
import matplotlib.pylab as plt


fig,axs = plt.subplots(1,5,figsize=(30,10))
axs[0].plot(range(NB_EPOCHS),history_DNN_org.history['val_loss'],label='before')
axs[0].plot(range(NB_EPOCHS),history_DNN_val_loss,label='after')
axs[0].set_title('val_loss')

axs[1].plot(range(NB_EPOCHS),history_DNN_org.history['val_acc'],label='before')
axs[1].plot(range(NB_EPOCHS),history_DNN_val_acc,label='after')
axs[1].set_title('val_acc')

axs[2].plot(range(NB_EPOCHS),history_DNN_org.history['val_precision'],label='before')
axs[2].plot(range(NB_EPOCHS),history_DNN_val_precision,label='after')
axs[2].set_title('val_precision')

axs[3].plot(range(NB_EPOCHS),history_DNN_org.history['val_recall'],label='before')
axs[3].plot(range(NB_EPOCHS),history_DNN_val_recall,label='after')
axs[3].set_title('val_recall')

axs[4].plot(range(NB_EPOCHS),history_DNN_org.history['val_fmeasure'],label='before')
axs[4].plot(range(NB_EPOCHS),history_DNN_val_fmeasure,label='after')
axs[4].set_title('val_fmeasure')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center')

plt.show()

# %%
import matplotlib.pylab as plt


fig,axs = plt.subplots(1,5,figsize=(30,10))
axs[0].plot(range(NB_EPOCHS),history_CNN_org.history['val_loss'],label='before')
axs[0].plot(range(NB_EPOCHS),history_CNN_val_loss,label='after')
axs[0].set_title('val_loss')

axs[1].plot(range(NB_EPOCHS),history_CNN_org.history['val_acc'],label='before')
axs[1].plot(range(NB_EPOCHS),history_CNN_val_acc,label='after')
axs[1].set_title('val_acc')

axs[2].plot(range(NB_EPOCHS),history_CNN_org.history['val_precision'],label='before')
axs[2].plot(range(NB_EPOCHS),history_CNN_val_precision,label='after')
axs[2].set_title('val_precision')

axs[3].plot(range(NB_EPOCHS),history_CNN_org.history['val_recall'],label='before')
axs[3].plot(range(NB_EPOCHS),history_CNN_val_recall,label='after')
axs[3].set_title('val_recall')

axs[4].plot(range(NB_EPOCHS),history_CNN_org.history['val_fmeasure'],label='before')
axs[4].plot(range(NB_EPOCHS),history_CNN_val_fmeasure,label='after')
axs[4].set_title('val_fmeasure')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center')

plt.show()

# %%
history_CNN_val_loss

# %%
history_CNN_org.history['val_loss']
